# %%
#  Load the "autoreload" extension so that code can change
# %load_ext autoreload
# %reload_ext autoreload
from pathlib import Path

#  always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append('../')
from src.imports import *
from src.data.download_data import *
from src.data.read_data import *
from src.data.fire_data import *
from src.data.vn_data import *
from src.data.weather_data import *
from src.gen_functions import *
from src.features.dataset import Dataset

import scrapy
from scrapy.crawler import CrawlerProcess
from twisted.internet import reactor
import scrapy
from scrapy.crawler import CrawlerRunner
from crochet import setup

import logging

# %% [markdown]
# Scrape location of VN power plants using scrapy

# %%
setup()

# %% [markdown]
# # Example

# %%
class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('quoteresult.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
import logging

class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
        'http://quotes.toscrape.com/page/1/',
        'http://quotes.toscrape.com/page/2/',
    ]
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.ret': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': '../data/hanoi/plants_info.json'                        # Used for pipeline 2
    }
    
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {
                'text': quote.css('span.text::text').extract_first(),
                'author': quote.css('span small::text').extract_first(),
                'tags': quote.css('div.tags a.tag::text').extract(),
            }

# %%
runner = CrawlerRunner()   #from Scrapy docs
runner.crawl(QuotesSpider)

# %% [markdown]
# # Wikipedia Page on Coal Power Plants in Vietnam

# %%
class WikiSpider(scrapy.Spider):
    name = "wiki"
    
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': '../data/hanoi/plants_info.json' }
    
     
    start_urls = ['https://en.wikipedia.org/wiki/List_of_power_stations_in_Vietnam#For_gas,_coal-fired_power_plants']
        
    
    def parse(self, response):
         
        links = response.xpath('//*[@id="mw-content-text"]/div[1]/div[3]/div/ol/li/span[2]/cite[1]/a[1]/@href')
        idxs = np.arange(len(links)) + 1
        for i, link in zip(idxs, links):
            if 'sourcewatch.org' in link.get():
                yield scrapy.Request(link.get(), callback=self.re_direct, cb_kwargs=dict(ref=i))
                
    def re_direct(self, response, ref):
    
        link = response.xpath('//*[@id="softredirect"]/a/@href').get()
        print(ref, link)
        yield scrapy.Request(link, callback=self.parse_loc, cb_kwargs=dict(ref=ref))
    
    def parse_loc(self, response, ref):
        info = response.xpath('//*[@id="mw-content-text"]/div/ul[1]/li')
        plant_info = {'ref':str(ref)} 
        for sub_info in info:
            k = sub_info.xpath('b/text()').get()
            k = k.replace(':','')
            try: 
                content = sub_info.xpath('text()').get().lstrip()
            except:
                content = ''
            plant_info[k] = content 
        print(plant_info)
        yield plant_info

# %%
runner = CrawlerRunner()   #from Scrapy docs
runner.crawl(WikiSpider)
# Out:
# 29 https://www.gem.wiki/Dung_Quat_power_station
# 40 https://www.gem.wiki/Duc_Giang_-_Lao_Cai_Chemicals_power_station
# 33 https://www.gem.wiki/Nam_Dinh_power_station
# 4 https://www.gem.wiki/An_Khanh_power_station
# 38 https://www.gem.wiki/Tan_Thanh_power_station
# 27 https://www.gem.wiki/Binh_Dinh_power_station
# 39 https://www.gem.wiki/Van_Phong_power_station
# 34 https://www.gem.wiki/Ninh_Binh_power_station
# {'ref': '29', 'Sponsor': 'Sembcorp Utilities Vietnam', 'Parent company': '', 'Location': 'Bình Sơn district, Quảng Ngãi province, Vietnam', 'Coordinates': '15.35790, 108.80911 (approximate)', 'Status': 'Cancelled', 'Gross Capacity': '1,200 MW'}
# {'ref': '40', 'Sponsor': 'Duc Giang - Lao Cai Chemicals Joint Stock Company', 'Parent company': '', 'Location': 'Duc Giang Lao Cai chemical plant, Tằng Loỏng town, Bảo Thắng district, Lào Cai province, Vietnam', 'Coordinates': '22.3043761, 104.1469831 (exact)', 'Status': 'Construction', 'Gross Capacity': '100 MW (2 x 50 MW)', 'Type': '', 'Projected in service': '2019-20', 'Coal Type': '', 'Coal Source': 'Quang Ninh Coal (expected type 6) or China, by waterway and road', 'Source of financing': '30% internal capital; 70% loan of VND1,400 billion borrowed from Vietcombank'}
# {'ref': '4', 'Sponsor': 'An Khánh Thermo-Power Joint Stock Company', 'Parent company': '', 'Location': 'An Khánh commune, Dai Tu district, Thái Nguyên province, Vietnam', 'Coordinates': '21.596912, 105.766609 (exact)', 'Status': 'Operating (An Khánh-1 Unit 1); Operating (An Khánh-1 Unit 2); Cancelled (An Khánh-2)', 'Gross Capacity': '100 MW (An Khánh-1 Units 1 & 2: 50 MW)', 'Type': '', 'In service': '4/2015 (An Khánh-1 Unit 1); 8/2015 (An Khánh-1 Unit 2)', 'Coal Type': '', 'Coal Source': 'An Khanh mine, Vietnam', 'Source of financing': 'Bank for Investment and Development of Vietnam, Bank of China'}
# {'ref': '34', 'Sponsor': 'Ninh Binh Thermal Power JSC', 'Parent company': '', 'Location': 'Thanh Bình ward, Ninh Bình city, Ninh Bình province, Vietnam', 'Coordinates': '20.25267, 105.98447 (exact)', 'Status': 'Cancelled', 'Gross Capacity': '330 MW', 'Type': '', 'Projected in service': 'N/A', 'Coal Type': 'Anthracite', 'Coal Source': '', 'Source of financing': ''}
# {'ref': '27', 'Sponsor': '', 'Parent company': '', 'Location': 'Bình Định province, Vietnam', 'Coordinates': '14.079, 109.205 (approximate)', 'Status': 'Cancelled', 'Gross Capacity': '3,200 MW', 'Type': '', 'Projected in service': '2026-29', 'Coal Type': '', 'Coal Source': '', 'Source of financing': ''}
# {'ref': '38', 'Sponsor': 'Electricity Power Development Company (', 'Parent company': '', 'Location': 'Tân Thành district, Bà Rịa–Vũng Tàu province, Vietnam', 'Coordinates': '10.58158, 107.06872 (approximate)', 'Status': 'Cancelled', 'Gross Capacity': '1,200-2,400 MW', 'Type': '', 'Projected in service': '', 'Coal Type': '', 'Coal Source': '', 'Source of financing': ''}
# {'ref': '39', 'Sponsor': '', 'Parent company': '', 'Location': 'Ninh Phước commune, Ninh Hòa township, Khánh Hòa province, Vietnam', 'Coordinates': '12.47704, 109.29244 (exact)', 'Status': 'Permitted (Vân Phong-1); Cancelled (Vân Phong-2)', 'Gross Capacity': 'Vân Phong-1: 2 x 660 MW; Vân Phong-2: 2 x 660 MW', 'Type': '', 'Projected in service': 'Vân Phong-1 Unit 1: 2023; Vân Phong-1 Unit 2: 2024', 'Coal Type': 'Bituminous', 'Coal Source': '', 'Source of financing': 'Vân Phong-1: '}
# 25 https://www.gem.wiki/Vung_Ang_power_station
# 24 https://www.gem.wiki/Vinh_Tan_power_station
# 15 https://www.gem.wiki/Na_Duong_power_station
# 22 https://www.gem.wiki/Uong_Bi_power_station
# 21 https://www.gem.wiki/Son_Dong_power_station
# 18 https://www.gem.wiki/Nong_Son_power_station
# 16 https://www.gem.wiki/Nghi_Son_power_station
# 20 https://www.gem.wiki/Quang_Ninh_power_station
# {'ref': '20', 'Owner': 'Quang Ninh Thermal Power Joint Stock Company', 'Parent company': '', 'Location': 'Hà Khánh ward, Hạ Long city, Quảng Ninh province, Vietnam', 'Coordinates': '21.01182, 107.12883 (exact)', 'Status': 'Quang Ninh-1 and Quang Ninh-2: Operating; Quang Ninh-3: Shelved', 'Gross Capacity': 'Quang Ninh-1: 600 MW (2 x 300 MW); Quang Ninh-2: 600 MW (2 x 300 MW); Quang Ninh-3: 1,200 MW (2 x 600 MW)', 'In Service': '', 'Type': '', 'Coal Type': 'Anthracite', 'Coal Source': '', 'Source of financing': ''}
# {'ref': '15', 'Owner': '', 'Parent company': '', 'Location': 'Na Dương township, Lộc Bình district, Lạng Sơn province, Vietnam', 'Coordinates': '21.69829, 106.97604 (exact)', 'Status': 'Shelved', 'Gross Capacity': '110 MW planned (Na Dương-2)', 'Type': '', 'Projected in service': '2022', 'Coal Type': 'lignite', 'Coal Source': 'Na Dương mine, Lạng Sơn province, Vietnam', 'Source of financing': ''}
# {'ref': '16', 'Sponsor': '', 'Location': 'Hải Hà commune, Tĩnh Gia district, Thanh Hoa province, Vietnam', 'Coordinates': '19.31581, 105.80026 (exact)', 'Status': 'Operating (Nghi Sơn-1); Construction (Nghi Sơn-2)', 'Gross Capacity': '1,920 MW (Nghi Sơn-1 Units 1 & 2: 2 x 300 MW; Nghi Sơn-2 Units 1 & 2: 2 x 660 MW)', 'Type': 'Nghi Sơn-1: ', 'In service': '', 'Coal Type': 'Anthracite', 'Coal Source': 'Hon Gai – Cam Pha coal mine, Quang Ninh province, Vietnam', 'Source of financing': ''}
# {'ref': '24', 'Sponsor': '', 'Parent company': '', 'Location': 'Vĩnh Tân commune, Tuy Phong district, Bình Thuận province, Vietnam', 'Coordinates': '11.32082, 108.80630 (exact)', 'Status': '', 'Gross Capacity': '6,225 MW (1,200 MW (Vĩnh Tân-1); 1,245 MW (Vĩnh Tân-2); 1,980 MW (Vĩnh Tân-3); 1,200 MW (Vĩnh Tân-4); 600 MW ((Vĩnh Tân-4 extension))', 'Type': '', 'Projected in service': '', 'Coal Type': 'Vinh Tan 1 and 2: Domestic Anthracite; Vinh Tan 3: Mixture of domestic bituminous coal and bituminous coal from Indonesia and Australia shipped in 100,000 DWT vessels; Vinh Tan 4: bituminous/sub-bituminous coal from Indonesia and Australia', 'Coal Source': 'PT Berau and Maintime (Indonesia) (Vĩnh Tân-1)', 'Source of financing': ''}
# {'ref': '22', 'Sponsor': '', 'Parent company': '', 'Location': 'Uông Bí township, Quảng Ninh province, Vietnam', 'Coordinates': '21.03906, 106.78555 (exact)', 'Status': 'Operating', 'Gross Capacity': '735 MW (Units 5: 50 MW; Unit 6: 55 MW; Unit 7: 300 MW; Unit 8: 330 MW)', 'Type': '', 'Projected in service': 'Unit 7: 2007; Unit 8: 2014', 'Coal Type': 'Anthracite', 'Coal Source': 'Quảng Ninh province', 'Source of financing': ''}
# {'ref': '21', 'Owner': 'Vietnam National Coal and Mineral Industries Group', 'Parent company': 'Vinacomin', 'Location': 'Thanh Luận commune, Sơn Động district, Bắc Giang province', 'Coordinates': '21.179288, 106.780143 (exact)', 'Status': 'Operating', 'Gross Capacity': '2 x 110 MW', 'Type': '', 'In service': '2009', 'Coal Type': 'Anthracite', 'Coal Source': 'Domestic', 'Source of financing': ''}
# {'ref': '18', 'Sponsor': '', 'Parent company': '', 'Location': 'Quế Trung commune, Quế Sơn district, Quảng Nam province, Vietnam', 'Coordinates': '15.716308, 108.0310147 (exact)', 'Status': 'Operating', 'Gross Capacity': '30 MW', 'Type': '', 'In service': '2014', 'Coal Type': 'Anthracite', 'Coal Source': 'Mine-mouth', 'Source of financing': ''}
# 11 https://www.gem.wiki/Hai_Phong_Thermal_Power_Station
# 5 https://www.gem.wiki/Cam_Pha_power_station
# 9 https://www.gem.wiki/Duyen_Hai_Power_Generation_Complex
# 14 https://www.gem.wiki/Mong_Duong_power_station
# {'ref': '5', 'Sponsor': '', 'Parent company': '', 'Location': 'Cửa Ông commune, Cẩm Phả district, Quảng Ninh province, Vietnam', 'Coordinates': 'Cam Pha power station: 21.008172, 107.358091 (exact); Cam Pha Phase III: 21.046, 107.357 (exact)', 'Status': 'Phases 1-2: Operating (2011), Phase 3: Cancelled', 'Gross Capacity': 'Phases 1 and 2: 680 MW (2 x 340 MW)', 'Type': '', 'In service': 'Units 1 and 2: 2011', 'Coal Type': 'anthracite, culm', 'Coal Source': 'Cửa Ông Coal Company, Vietnam', 'Source of financing': 'China ExIm Bank supplied loans for 85% of the EPC contract value'}
# {'ref': '14', 'Sponsor': '', 'Parent company': '', 'Location': 'Mông Dương ward, Cẩm Phả city, Quảng Ninh province, Vietnam', 'Coordinates': '21.07324, 107.34847 (exact)', 'Status': 'Operating (Mông Dương-2); Operating (Mông Dương-1)', 'Gross Capacity': '', 'Type': '', 'In service': 'Mar. 2015 (Mông Dương-1 Unit 1); May 2015 (Mông Dương-1 Unit 2); Mar. 2015 (Mông Dương-2 Unit 1); Q3/4 2015 (Mông Dương-2 Unit 2)', 'Coal Type': 'Anthracite', 'Coal Source': '', 'Source of financing': 'Export-Import Bank of Korea 40%, '}
# {'ref': '9', 'Sponsor': '', 'Parent company': '', 'Location': 'Dan Thanh commune, Duyên Hải district, Trà Vinh province, Vietnam', 'Coordinates': '9.58517, 106.52809 (exact)', 'Status': '', 'Gross Capacity': '4,305 MW\n', 'Type': '', 'In service': '', 'Coal Type': 'Bituminous', 'Coal Source': 'Imported (Duyên Hải-2)', 'Source of financing': ''}

# %%
with open('../data/hanoi/plants_info.json') as f:
    coals = json.load(f)
    
coals = pd.DataFrame(coals)
coals.head(2)
# Out:
#   ref                                            Sponsor Parent company  \
# 0  29                         Sembcorp Utilities Vietnam
# 1  40  Duc Giang - Lao Cai Chemicals Joint Stock Company
#
#                                             Location  \
# 0    Bình Sơn district, Quảng Ngãi province, Vietnam
# 1  Duc Giang Lao Cai chemical plant, Tằng Loỏng t...
#
#                          Coordinates        Status      Gross Capacity Type  \
# 0  15.35790, 108.80911 (approximate)     Cancelled            1,200 MW  NaN
# 1    22.3043761, 104.1469831 (exact)  Construction  100 MW (2 x 50 MW)
#
#   Projected in service Coal Type  \
# 0                  NaN       NaN
# 1              2019-20
#
#                                          Coal Source  \
# 0                                                NaN
# 1  Quang Ninh Coal (expected type 6) or China, by...
#
#                                  Source of financing In service Owner  \
# 0                                                NaN        NaN   NaN
# 1  30% internal capital; 70% loan of VND1,400 bil...        NaN   NaN
#
#   In Service
# 0        NaN
# 1        NaN

# %%
coals['latitude']  = coals['Coordinates'].str.extract('(\d+.\d+)').astype(float)
coals['longitude'] = coals['Coordinates'].str.extract(', (\d+.\d+)').astype(float)

# %%
coals.to_csv('../data/hanoi/coat_plants.csv', index= False)

# %%
coals = pd.read_csv('../data/hanoi/coat_plants.csv')

coals.head()
# Out:
#    ref                                            Sponsor Parent company  \
# 0   29                         Sembcorp Utilities Vietnam            NaN
# 1   40  Duc Giang - Lao Cai Chemicals Joint Stock Company            NaN
# 2    4          An Khánh Thermo-Power Joint Stock Company            NaN
# 3   34                        Ninh Binh Thermal Power JSC            NaN
# 4   27                                                NaN            NaN
#
#                                             Location  \
# 0    Bình Sơn district, Quảng Ngãi province, Vietnam
# 1  Duc Giang Lao Cai chemical plant, Tằng Loỏng t...
# 2  An Khánh commune, Dai Tu district, Thái Nguyên...
# 3  Thanh Bình ward, Ninh Bình city, Ninh Bình pro...
# 4                        Bình Định province, Vietnam
#
#                          Coordinates  \
# 0  15.35790, 108.80911 (approximate)
# 1    22.3043761, 104.1469831 (exact)
# 2      21.596912, 105.766609 (exact)
# 3        20.25267, 105.98447 (exact)
# 4      14.079, 109.205 (approximate)
#
#                                               Status  \
# 0                                          Cancelled
# 1                                       Construction
# 2  Operating (An Khánh-1 Unit 1); Operating (An K...
# 3                                          Cancelled
# 4                                          Cancelled
#
#                            Gross Capacity Type Projected in service  \
# 0                                1,200 MW  NaN                  NaN
# 1                      100 MW (2 x 50 MW)  NaN              2019-20
# 2  100 MW (An Khánh-1 Units 1 & 2: 50 MW)  NaN                  NaN
# 3                                  330 MW  NaN                  NaN
# 4                                3,200 MW  NaN              2026-29
#
#     Coal Type                                        Coal Source  \
# 0         NaN                                                NaN
# 1         NaN  Quang Ninh Coal (expected type 6) or China, by...
# 2         NaN                             An Khanh mine, Vietnam
# 3  Anthracite                                                NaN
# 4         NaN                                                NaN
#
#                                  Source of financing  \
# 0                                                NaN
# 1  30% internal capital; 70% loan of VND1,400 bil...
# 2  Bank for Investment and Development of Vietnam...
# 3                                                NaN
# 4                                                NaN
#
#                                           In service Owner  In Service  \
# 0                                                NaN   NaN         NaN
# 1                                                NaN   NaN         NaN
# 2  4/2015 (An Khánh-1 Unit 1); 8/2015 (An Khánh-1...   NaN         NaN
# 3                                                NaN   NaN         NaN
# 4                                                NaN   NaN         NaN
#
#     latitude   longitude
# 0  15.357900  108.809110
# 1  22.304376  104.146983
# 2  21.596912  105.766609
# 3  20.252670  105.984470
# 4  14.079000  109.205000

# %% [markdown]
# ## Other Power Plants

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/List_of_power_stations_in_Vietnam#For_gas,_coal-fired_power_plants')

# %%
label_list = ['coal','gas','solar', 'wind', 'biomass', 'hydroelectricity']

# %%
power_plants = []
for df, label in zip(dfs, label_list): 
    df['type'] = label
    power_plants.append(df)
    
power_plants= pd.concat(power_plants)

# %%
power_plants['Status'] = power_plants['Status'].fillna(power_plants['Unnamed: 7'])
#power_plants['Capacity (MW)'] = power_plants['Capacity (MW)'].fillna(power_plants['Capacity (MWp)'])

# %%
power_plants.to_csv('C:/Users/Benny/Documents/Fern/aqi_thailand2/data/hanoi/power_plants.csv',index=False)

# %%
power_plants[~power_plants['Unnamed: 7'].isna()]
# Out:
#                             Station    Province Capacity (MW) Commission date  \
# 9      Trung Nam Ninh Thuan phase 2  Ninh Thuan           NaN             NaN
# 10              Dai Phong wind farm  Binh Thuan           NaN             NaN
# 11  Bac Lieu phase III (VN version)    Bac Lieu           NaN             NaN
# 12   Cong Ly (3 phase) (VN version)   Soc Trang           NaN             NaN
# 13                        Lac Hoa 1   Soc Trang           NaN             NaN
# ..                              ...         ...           ...             ...
# 67                 Dak Po wind farm     Gia Lai           NaN             NaN
# 68              Mang Yang wind farm     Gia Lai           NaN             NaN
# 69                         Thai Hoa  Binh Thuan           NaN             NaN
# 70                       Thai Phong  Binh Thuan           NaN             NaN
# 71          Chinh Thang Wind Energy  Ninh Thuan           NaN             NaN
#
#                       Sponsor/Owner              Status  \
# 9           Trungnam Wind Power JSC  Under Construction
# 10            AC Energy+Blue Circle  Under Construction
# 11  Super Wind Energy Cong Ly 1 JSC  Under Construction
# 12  Super Wind Energy Cong Ly 1 JSC  Under Construction
# 13                 Hoang Son Energy  Under Construction
# ..                              ...                 ...
# 67               Mirat Energy + HLP            Approved
# 68               Mirat Energy + HLP            Approved
# 69  Pacific Energy - Binh Thuan JSC            Approved
# 70  Pacific Energy - Binh Thuan JSC            Approved
# 71      Chinh Thang Wind Power Ltd.  Under Construction
#
#                                                  Note  Ref  type  \
# 9                  ENERCON turbines, Siemens Inverter  NaN  wind
# 10  AC Energy accounts for over 62% of the economi...  NaN  wind
# 11  Super Wind Energy Cong Ly 1 JSC = Cong Ly + Th...  NaN  wind
# 12                                      15x2MW units.  NaN  wind
# 13                                                NaN  NaN  wind
# ..                                                ...  ...   ...
# 67                                                NaN  NaN  wind
# 68                                                NaN  NaN  wind
# 69                                  Metmast installed  NaN  wind
# 70                                  Metmast installed  NaN  wind
# 71  Transit 110kV Thap Cham - Ninh Phuoc (ACSR 300...  NaN  wind
#
#                                              Location  Capacity (MWp)  \
# 9   Loi Hai and Bac Phong communes, Thuan Bac dist...            64.0
# 10  Thien Nghiep commune, Mui Ne ward, Phan Thiet ...            40.0
# 11             Vinh Trach Dong commune, Bac Lieu city           142.0
# 12     Lai Hoa commune, Vinh Chau district, Soc Trang            90.0
# 13     Lac Hoa commune, Vinh Chau district, Soc Trang            30.0
# ..                                                ...             ...
# 67                  Dak Po district, Gia Lai province           200.0
# 68               Mang Yang district, Gia Lai province           200.0
# 69  Hoa Thang commune, Bac Binh district, Binh Thu...            82.5
# 70  Chi Cong, Hoa Minh and Phong Phu communes, Tuy...            52.5
# 71     Thuan Nam and Ninh Phuoc districts, Ninh Thuan            50.0
#
#    Construction Start Date COD date      Source          Unnamed: 7  \
# 9                      NaN      NaN  [165][166]  Under Construction
# 10                     NaN      NaN       [167]  Under Construction
# 11              30/01/2018      NaN       [168]  Under Construction
# 12              30/01/2018      NaN       [169]  Under Construction
# 13                     NaN      NaN       [170]  Under Construction
# ..                     ...      ...         ...                 ...
# 67                     NaN      NaN       [192]            Approved
# 68                     NaN      NaN       [192]            Approved
# 69                     NaN      NaN       [193]            Approved
# 70                     NaN      NaN       [193]            Approved
# 71              25/04/2019      NaN       [194]  Under Construction
#
#    Plant name  Operation time Technology Fuel type  Commission time
# 9         NaN             NaN        NaN       NaN              NaN
# 10        NaN             NaN        NaN       NaN              NaN
# 11        NaN             NaN        NaN       NaN              NaN
# 12        NaN             NaN        NaN       NaN              NaN
# 13        NaN             NaN        NaN       NaN              NaN
# ..        ...             ...        ...       ...              ...
# 67        NaN             NaN        NaN       NaN              NaN
# 68        NaN             NaN        NaN       NaN              NaN
# 69        NaN             NaN        NaN       NaN              NaN
# 70        NaN             NaN        NaN       NaN              NaN
# 71        NaN             NaN        NaN       NaN              NaN
#
# [63 rows x 20 columns]

# %%
power_plants.dropna(axis=1,how='all')
# Out:
#                                   Station     Province Capacity (MW)  \
# 0    An Khanh 1 (Khanh Hoa power station)  Thai Nguyen          2x58
# 1                      Cam Pha Phase I-II   Quang Ninh         2x340
# 2                                Cao Ngan  Thai Nguyen        2x57.5
# 3               Dong Nai Formosa Unit 1-2     Dong Nai         2x150
# 4                 Dong Nai Formosa Unit 3     Dong Nai           150
# ..                                    ...          ...           ...
# 101                    Hoa Binh expansion          NaN         2x240
# 102                        Ialy expansion          NaN         2x180
# 103                      Tri An expansion          NaN           200
# 104                                 My Ly          NaN           250
# 105                                Nam Mo          NaN            90
#
#     Commission date             Sponsor/Owner     Status  \
# 0              2015  An Khanh Electricity JSC  Operating
# 1              2011                 VINACOMIN  Operating
# 2              2006                 VINACOMIN  Operating
# 3              2004       Hung Nghiep Formosa  Operating
# 4              2018       Hung Nghiep Formosa  Operating
# ..              ...                       ...        ...
# 101             NaN                       EVN        NaN
# 102             NaN                       EVN        NaN
# 103             NaN                       EVN        NaN
# 104             NaN                       IPP        NaN
# 105             NaN                       IPP        NaN
#
#                                Note                              Ref  \
# 0                               NaN                              [4]
# 1                               NaN                              [5]
# 2                               NaN                              [6]
# 3                               NaN                              [7]
# 4                               NaN                              [8]
# ..                              ...                              ...
# 101  Under construction or proposed  Report 58/BC-CBT annex row I.21
# 102  Under construction or proposed  Report 58/BC-CBT annex row I.22
# 103  Under construction or proposed  Report 58/BC-CBT annex row I.23
# 104  Under construction or proposed   Report 58/BC-CBT annex row V.5
# 105  Under construction or proposed   Report 58/BC-CBT annex row V.6
#
#                  type Location  Capacity (MWp) Construction Start Date  \
# 0                coal      NaN             NaN                     NaN
# 1                coal      NaN             NaN                     NaN
# 2                coal      NaN             NaN                     NaN
# 3                coal      NaN             NaN                     NaN
# 4                coal      NaN             NaN                     NaN
# ..                ...      ...             ...                     ...
# 101  hydroelectricity      NaN             NaN                     NaN
# 102  hydroelectricity      NaN             NaN                     NaN
# 103  hydroelectricity      NaN             NaN                     NaN
# 104  hydroelectricity      NaN             NaN                     NaN
# 105  hydroelectricity      NaN             NaN                     NaN
#
#     COD date Source Unnamed: 7 Plant name  Operation time Technology  \
# 0        NaN    NaN        NaN        NaN             NaN        NaN
# 1        NaN    NaN        NaN        NaN             NaN        NaN
# 2        NaN    NaN        NaN        NaN             NaN        NaN
# 3        NaN    NaN        NaN        NaN             NaN        NaN
# 4        NaN    NaN        NaN        NaN             NaN        NaN
# ..       ...    ...        ...        ...             ...        ...
# 101      NaN    NaN        NaN        NaN             NaN        NaN
# 102      NaN    NaN        NaN        NaN             NaN        NaN
# 103      NaN    NaN        NaN        NaN             NaN        NaN
# 104      NaN    NaN        NaN        NaN             NaN        NaN
# 105      NaN    NaN        NaN        NaN             NaN        NaN
#
#     Fuel type  Commission time
# 0         NaN              NaN
# 1         NaN              NaN
# 2         NaN              NaN
# 3         NaN              NaN
# 4         NaN              NaN
# ..        ...              ...
# 101       NaN           2023.0
# 102       NaN           2023.0
# 103       NaN           2025.0
# 104       NaN           2024.0
# 105       NaN           2026.0
#
# [427 rows x 20 columns]

# %%
power_plants[(power_plants['type']=='gas') & (power_plants['Status']=='Operating')]
# Out:
#                                           Station  Province Capacity (MW)  \
# 0                      Ca Mau 1&2 gas power plant    Ca Mau         2x750
# 1                    Nhon Trach 1 gas power plant  Dong Nai           450
# 2   Nhon Trach 2 Combined Cycle Gas Turbine Plant  Dong Nai           750
# 3                                      Phu My 2.1  Vung Tau           477
# 4                                          Ba Ria  Vung Tau           340
# 5                            Phu My 2.1 extension  Vung Tau           468
# 6                                        Phu My 4  Vung Tau           477
# 7                                           O Mon   Can Tho         2x330
# 8                                        Phu My 1  Vung Tau          1118
# 9                                        Phu My 3  Vung Tau           720
# 10                                     Phu My 2.2  Vung Tau           720
#
#    Commission date                                      Sponsor/Owner  \
# 0             2008                          PetroVietnam Power Ca Mau
# 1             2009                      PetroVietnam Power Nhon Trach
# 2             2011                    PetroVietnam Power Nhon Trach 2
# 3             1997               Phu My Thermal Power Company, GENCO3
# 4        1992-2002              Ba Ria Thermal Power Company, GENCO 3
# 5             1999              Phu My Thermal Power Company, GENCO 3
# 6             2004              Phu My Thermal Power Company, GENCO 3
# 7        2009-2015                                          EVNGENCO2
# 8             2001              Phu My Thermal Power Company, GENCO 3
# 9             2004  Phu My 3 Bot Power Company LTD, BP Holdings BV...
# 10            2005  Mekong Energy Company LTD, Electricité De Fran...
#
#        Status Note                                               Ref type  \
# 0   Operating  NaN   [45] and decision 125/QD-DTDL annex 3 row 22-23  gas
# 1   Operating  NaN                                              [46]  gas
# 2   Operating  NaN                                              [47]  gas
# 3   Operating  NaN      [48] and Decision 125/QD-DTDL annex 1 row 15  gas
# 4   Operating  NaN      [49] and Decision 125/QD-DTDL annex 3 row 21  gas
# 5   Operating  NaN      [50] and Decision 125/QD-DTDL annex 1 row 15  gas
# 6   Operating  NaN      [50] and Decision 125/QD-DTDL annex 1 row 16  gas
# 7   Operating  NaN                                          [51][52]  gas
# 8   Operating  NaN  [53][50] and Decision 125/QD-DTDL annex 1 row 14  gas
# 9   Operating  NaN  [54][55] and Decision 125/QD-DTDL annex 3 row 18  gas
# 10  Operating  NaN      [56] and Decision 125/QD-DTDL annex 3 row 17  gas
#
#    Location  Capacity (MWp) Construction Start Date COD date Source  \
# 0       NaN             NaN                     NaN      NaN    NaN
# 1       NaN             NaN                     NaN      NaN    NaN
# 2       NaN             NaN                     NaN      NaN    NaN
# 3       NaN             NaN                     NaN      NaN    NaN
# 4       NaN             NaN                     NaN      NaN    NaN
# 5       NaN             NaN                     NaN      NaN    NaN
# 6       NaN             NaN                     NaN      NaN    NaN
# 7       NaN             NaN                     NaN      NaN    NaN
# 8       NaN             NaN                     NaN      NaN    NaN
# 9       NaN             NaN                     NaN      NaN    NaN
# 10      NaN             NaN                     NaN      NaN    NaN
#
#    Unnamed: 7 Plant name  Operation time Technology Fuel type  Commission time
# 0         NaN        NaN             NaN        NaN       NaN              NaN
# 1         NaN        NaN             NaN        NaN       NaN              NaN
# 2         NaN        NaN             NaN        NaN       NaN              NaN
# 3         NaN        NaN             NaN        NaN       NaN              NaN
# 4         NaN        NaN             NaN        NaN       NaN              NaN
# 5         NaN        NaN             NaN        NaN       NaN              NaN
# 6         NaN        NaN             NaN        NaN       NaN              NaN
# 7         NaN        NaN             NaN        NaN       NaN              NaN
# 8         NaN        NaN             NaN        NaN       NaN              NaN
# 9         NaN        NaN             NaN        NaN       NaN              NaN
# 10        NaN        NaN             NaN        NaN       NaN              NaN

# %%
df2 = pd.read_html('https://en.wikipedia.org/wiki/List_of_gas_power_plants_in_Vietnam')[0]
df2.head()
# Out:
#                                       Power plants Other names   Sponsors  \
# 0       O Mon III Combined Cycle Gas Turbine Plant         NaN  EVN (ODA)
# 1        O Mon IV Combined Cycle Gas Turbine Plant         NaN        EVN
# 2     Dung Quat I Combined Cycle Gas Turbine Plant         NaN        EVN
# 3   Dung Quat III Combined Cycle Gas Turbine Plant         NaN        EVN
# 4  Nhon Trach 3&4 Combined Cycle Gas Turbine Plant         NaN        PVN
#
#   Capacity (MW)                Status    Province Commission date  \
# 0         1x750  pre-permit/permitted     Can Tho            2025
# 1         1x750  pre-permit/permitted     Can Tho            2023
# 2           750  pre-permit/permitted  Quang Ngai            2024
# 3           750  pre-permit/permitted  Quang Ngai            2025
# 4         2x750  pre-permit/permitted    Dong Nai       2023-2024
#
#                                  Source  Note
# 0  MOIT Report 58/BC-CBT annex row I.13   NaN
# 1  MOIT Report 58/BC-CBT annex row I.14   NaN
# 2  MOIT Report 58/BC-CBT annex row I.19   NaN
# 3  MOIT Report 58/BC-CBT annex row I.20   NaN
# 4  MOIT Report 58/BC-CBT annex row II.5   NaN

# %%
df2[df2['Status']=='operating']
# Out:
#                                      Power plants Other names  \
# 12                     Ca Mau 1&2 gas power plant         NaN
# 13                   Nhon Trach 1 gas power plant         NaN
# 14  Nhon Trach 2 Combined Cycle Gas Turbine Plant         NaN
# 16                                     Phu My 2.1         NaN
# 17                                         Ba Ria         NaN
# 18                           Phu My 2.1 extension         NaN
# 19                                       Phu My 4         NaN
# 22                                          O Mon         NaN
# 23                                       Phu My 1         NaN
# 24                                       Phu My 3         NaN
# 25                                     Phu My 2.2         NaN
#
#                                              Sponsors Capacity (MW)  \
# 12                          PetroVietnam Power Ca Mau         2x750
# 13                      PetroVietnam Power Nhon Trach           450
# 14                    PetroVietnam Power Nhon Trach 2           750
# 16               Phu My Thermal Power Company, GENCO3           477
# 17              Ba Ria Thermal Power Company, GENCO 3           340
# 18              Phu My Thermal Power Company, GENCO 3           468
# 19              Phu My Thermal Power Company, GENCO 3           477
# 22                                          EVNGENCO2         2x330
# 23              Phu My Thermal Power Company, GENCO 3          1118
# 24  Phu My 3 Bot Power Company LTD, BP Holdings BV...           720
# 25  Mekong Energy Company LTD, Electricité De Fran...           720
#
#        Status  Province Commission date  \
# 12  operating    Ca Mau            2008
# 13  operating  Dong Nai            2009
# 14  operating  Dong Nai            2011
# 16  operating  Vung Tau            1997
# 17  operating  Vung Tau       1992-2002
# 18  operating  Vung Tau            1999
# 19  operating  Vung Tau            2004
# 22  operating   Can Tho       2009-2015
# 23  operating  Vung Tau            2001
# 24  operating  Vung Tau            2004
# 25  operating  Vung Tau            2005
#
#                                               Source  Note
# 12    [6] and decision 125/QD-DTDL annex 3 row 22-23   NaN
# 13                                               [7]   NaN
# 14                                               [8]   NaN
# 16      [10] and Decision 125/QD-DTDL annex 1 row 15   NaN
# 17      [11] and Decision 125/QD-DTDL annex 3 row 21   NaN
# 18      [12] and Decision 125/QD-DTDL annex 1 row 15   NaN
# 19      [12] and Decision 125/QD-DTDL annex 1 row 16   NaN
# 22                                          [15][16]   NaN
# 23  [12][17] and Decision 125/QD-DTDL annex 1 row 14   NaN
# 24  [18][19] and Decision 125/QD-DTDL annex 3 row 18   NaN
# 25      [20] and Decision 125/QD-DTDL annex 3 row 17   NaN
