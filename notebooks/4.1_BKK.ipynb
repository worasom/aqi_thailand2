# %%
#  Load the "autoreload" extension so that code can change
# %load_ext autoreload
# %reload_ext autoreload
from pathlib import Path

#  always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append('../')
from src.imports import *
from src.data.download_data import *
from src.data.fire_data import *
from src.data.read_data import *
from src.gen_functions import *
from src.features.dataset import Dataset
from src.features.build_features import *
from src.models.train_model import *
from src.visualization.vis_data import *
import seaborn as sns
output_notebook()
plt.rcParams.update({'font.size': 14})
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Traffic 2020

# %%
t_folder = '../data/traffic/'
t_files = glob(t_folder + '*.csv')

# %%
trf = pd.read_csv(t_files[0])
trf = trf.iloc[:,1:]
trf.columns = ['date', 'max', 'mean']
 # extract months and date 
trf['month'] = trf['date'].str.extract('(\D+)').iloc[:,0]
trf['day'] = trf['date'].str.extract('(\d+)').iloc[:,0]
month_list = s.unique().tolist()
# Out:
#       date  max  mean
# 0  1มกราคม  3.7   2.1
# 1  2มกราคม  5.5   2.7

# %%
month_dict = {}
for i, m in enumerate(month_list):
    i += 1
    if len(str(i))==1:
        month_dict[m] = '-0'+str(i)
    else:
        month_dict[m] = str(i)
        
print(month_dict)
# Out:
# {'มกราคม': '-01', 'กุมภาพันธ์': '-02', 'มีนาคม': '-03', 'เมษายน': '-04', 'พฤษภาคม': '-05', 'มิถุนายน': '-06', 'กรกฎาคม': '-07', 'สิงหาคม': '-08'}

# %%
# change month to number 
trf['month'] = trf['month'].replace(month_dict)

# combine month, date into one strings
date_list = []
for i, row in trf.iterrows():
    if len(row['day']) == 1:
        day = '-0' + row['day']
    else:
        day = '-' + row['day']
    new_date = '2020'+row['month'] + day
    date_list.append(new_date)
    
trf['date'] = pd.to_datetime(date_list)
trf = trf[['date','max','mean']]

# %%
_, ax = plt.subplots(figsize=(10,4))
ax.plot(trf['date'], trf['mean'], label='mean traffic index')


#ax.xaxis.set_major_formatter(mdates.DateFormatter("%b\n%Y"))
ax.axvspan(datetime(2020, 3, 18), datetime(2020, 4, 30), color='gray', alpha=0.2, label='lockdown' )
ax.set_xlabel('date')
ax.set_ylabel('index')
ax.legend(loc='lower right')

# %% [markdown]
# # BKK Data

# %%
# start building dataset from scratch only perform this when new data files are added 
dataset = Dataset('Bangkok')
dataset.build_all_data( build_fire=True, build_holiday = True)
# Out:
# save file ../data/bangkok/02t.csv
# save file ../data/bangkok/03t.csv
# save file ../data/bangkok/05t.csv
# save file ../data/bangkok/11t.csv
# save file ../data/bangkok/12t.csv
# save file ../data/bangkok/50t.csv
# save file ../data/bangkok/52t.csv
# save file ../data/bangkok/53t.csv
# save file ../data/bangkok/59t.csv
# save file ../data/bangkok/61t.csv
# Averaging data from 11 stations
# Loading all hotspots data. This might take sometimes
# before drop (3168630, 18)
# after drop (3064842, 10)

# %%
# reinit the data and load saved process data 
dataset = Dataset('Bangkok')
dataset.load_()
# merge pollution data with other data except fire
dataset.feature_no_fire()
# Out:
# data no fire has shape (52806, 14)

# %%
# plot the raw data
plot_all_pollutions(dataset.poll_df, city_name=dataset.city_name)
# Out:
# Index(['PM2.5', 'PM10', 'O3', 'CO', 'NO2', 'SO2'], dtype='object')

# %%
plot_polls_aqi(dataset.poll_df.copy(), dataset.roll_dict, dataset.city_name, filename=dataset.report_folder + 'all_pol_aqi.png' )

# %%
plot_chem_print(poll_to_aqi(dataset.poll_df.copy(), dataset.roll_dict).mean(axis=0), dataset.city_name, filename=dataset.report_folder + 'fingerprint.png')

# %%
ax, year_avg = plot_yearly_ln(dataset, filename=dataset.report_folder + 'compare_ln_trends.png')

# %%
plot_corr(year_avg, figsize=(6,4))

# %%
plot_season_aqi(dataset.poll_df.copy(), dataset.roll_dict, 'PM2.5', filename=dataset.report_folder + 'seasonal_pattern_PM25.png')
# Out:
# aqi 100 in  11-05 to 03-28

# %%
ax = compare_seson_avg(dataset, agg='mean')
ax[3].set_ylim([0,15])

plt.savefig(dataset.report_folder + 'fire_PM25_season.png')

# %%
_, ax = plt.subplots(2, 1, figsize=(9, 7))
plot_hour_avg(dataset.poll_df.copy(), 'PM2.5', ax[0],  color='blue')
plot_hour_avg(dataset.wea.copy(), 'Wind Speed(kmph)', ax[1],  color='green')
plt.tight_layout()

# %% [markdown]
# # Map

# %%
dataset.city_info

x = merc_x(dataset.city_info['Longitude'])
y = merc_y(dataset.city_info['Latitude'])
#stepx = 2E5

stepx = 1E6
stepy = stepx

# %%
# select fire data 
fire = dataset.fire
i = 0
month_list = ['2019-03','2019-04']
month = month_list[i]
color = 'red'
fire1 = fire.loc[month:month_list[i+1]]

month_list = ['2018-12','2019-01']
month = month_list[i]
fire2 = fire.loc[month:month_list[i+1]]

# %%
# range bounds supplied in web mercator coordinates
p = figure(x_range=(x-0.5*stepx,x+0.5*stepx), y_range=(y-stepy*0.1, y+stepy*0.0001),
           x_axis_type="mercator", y_axis_type="mercator",
          title = dataset.city_name)
p.add_tile(get_provider(Vendors.STAMEN_TERRAIN_RETINA))

# add city center
p.scatter(x,y,color='red',line_color='black',size=10, legend_label=dataset.city_name)

# plot hotspots at the begining and end of winter season

p.scatter(fire1['long_km']*1000,fire1['lat_km']*1000,color='red',size=1, alpha=0.5,legend_label='fire in Mar 2019')

p.scatter(fire2['long_km']*1000,fire2['lat_km']*1000,color='blue',size=1, alpha=0.5, legend_label='fire in Dec 2018')

#add circles
labels = ['0-100km','100-200km','200-400km','400-600km']

rs = [100, 200, 400, 600]
rs.reverse()
colors = get_color(color_length=len(labels),cmap=cm.jet)
for i, (r, label, color) in enumerate(zip(rs, labels, colors)):
    if i ==3 or i ==2:
        alpha=0.4
    else:
        alpha=0.2
        
    xy = get_circle(x,y,r=r*1E3)
    p.patch(xy[0,:],xy[1,:],alpha=alpha,line_width=2,line_color='black',color=color, legend_label=label)
    
p.legend.location = "bottom_right"

show(p)
# Out:
#   <div class="bk-root" id="1de9542e-5e04-4e63-bb9e-c3fcb2b3ccea" data-root-id="2827"></div>

# %% [markdown]
# # Train Model

# %%
dataset, model, poll_meta = train_city_s1(city= 'Bangkok', pollutant='PM2.5')
# Out:
# data no fire has shape (52731, 21)
# use default fire feature
# =================optimize 1: find the best RF model=================
# {'n_estimators': 180, 'min_samples_split': 50, 'min_samples_leaf': 23, 'max_features': 'log2', 'max_depth': None, 'bootstrap': False} 0.27101123178516395
# optimize 1 score {'val_r2_score': 0.3101758778630781, 'val_mean_squared_error': 140.62754618537562, 'val_mean_absolute_error': 8.828853893773758}
# =================optimize 2: remove unncessary columns=================
# old cols length 25
# drop time_of_day_[9, 12)
# drop time_of_day_[15, 18)
# drop time_of_day_[6, 9)
# drop fire_100_200
# use columns ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day_[0, 3)', 'time_of_day_[3, 6)', 'time_of_day_[12, 15)', 'time_of_day_[18, 21)', 'time_of_day_[21, 24)', 'fire_0_100', 'fire_200_400', 'fire_400_800', 'fire_800_1000']
# score after dropping columns {'r2_score': 0.3361634708327589, 'mean_squared_error': 135.32971545821943, 'mean_absolute_error': 8.617316012539709}
# ================= optimization 3: find the best fire feature ===================
# skop_ fire use x_cols ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day_[0, 3)', 'time_of_day_[3, 6)', 'time_of_day_[6, 9)', 'time_of_day_[9, 12)', 'time_of_day_[12, 15)', 'time_of_day_[15, 18)', 'time_of_day_[18, 21)', 'time_of_day_[21, 24)', 'fire_0_100', 'fire_100_200', 'fire_200_400', 'fire_400_800', 'fire_800_1000']
# old score 140.62754618537562 fire dict {'w_speed': 7, 'shift': -5, 'roll': 44}
# optimizing fire parameter using skopt optimizer. This will take about 20 mins
# mean_squared_error for the best fire parameters 125.49208938911232
# new fire dict {'w_speed': 17, 'shift': -25, 'roll': 143}
# ================= optimization 4: improve model performance by adding lag columns =================
# model parameters {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'mse', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 23, 'min_samples_split': 50, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 180, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# new mean squared error 123.49794018077192 using {'n_max': 51, 'step': 15, 'roll': True}
# x_cols Index(['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM',
#        'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday',
#        ...
#        'day_of_week_lag_46', 'time_of_day_[0, 3)_lag_46',
#        'time_of_day_[3, 6)_lag_46', 'time_of_day_[12, 15)_lag_46',
#        'time_of_day_[18, 21)_lag_46', 'time_of_day_[21, 24)_lag_46',
#        'fire_0_100_lag_46', 'fire_200_400_lag_46', 'fire_400_800_lag_46',
#        'fire_800_1000_lag_46'],
#       dtype='object', length=105)
# xtrn has shape (23708, 105)
# op4 score {'val_r2_score': 0.36417060594325534, 'val_mean_squared_error': 123.49794018077192, 'val_mean_absolute_error': 7.851843882780283}
# op4 test score {'test_r2_score': 0.3645922833747314, 'test_mean_squared_error': 146.60176914547804, 'test_mean_absolute_error': 9.015827648233584}
# ================= optimization 5: remove unncessary lag columns =================
# old cols length 105
# drop time_of_day_[0, 3)_lag_1
# drop fire_0_100_lag_1
# drop fire_0_100
# drop fire_400_800_lag_16
# drop fire_400_800_lag_31
# drop fire_200_400_lag_1
# drop fire_200_400_lag_46
# drop fire_200_400_lag_31
# drop fire_200_400
# use columns ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day_[0, 3)', 'time_of_day_[3, 6)', 'time_of_day_[12, 15)', 'time_of_day_[18, 21)', 'time_of_day_[21, 24)', 'fire_400_800', 'fire_800_1000', 'Temperature(C)_lag_1', 'Humidity(%)_lag_1', 'Wind Speed(kmph)_lag_1', 'wind_CALM_lag_1', 'wind_E_lag_1', 'wind_N_lag_1', 'wind_S_lag_1', 'wind_W_lag_1', 'is_rain_lag_1', 'is_holiday_lag_1', 'is_weekend_lag_1', 'day_of_week_lag_1', 'time_of_day_[3, 6)_lag_1', 'time_of_day_[12, 15)_lag_1', 'time_of_day_[18, 21)_lag_1', 'time_of_day_[21, 24)_lag_1', 'fire_400_800_lag_1', 'fire_800_1000_lag_1', 'Temperature(C)_lag_16', 'Humidity(%)_lag_16', 'Wind Speed(kmph)_lag_16', 'wind_CALM_lag_16', 'wind_E_lag_16', 'wind_N_lag_16', 'wind_S_lag_16', 'wind_W_lag_16', 'is_rain_lag_16', 'is_holiday_lag_16', 'is_weekend_lag_16', 'day_of_week_lag_16', 'time_of_day_[0, 3)_lag_16', 'time_of_day_[3, 6)_lag_16', 'time_of_day_[12, 15)_lag_16', 'time_of_day_[18, 21)_lag_16', 'time_of_day_[21, 24)_lag_16', 'fire_0_100_lag_16', 'fire_200_400_lag_16', 'fire_800_1000_lag_16', 'Temperature(C)_lag_31', 'Humidity(%)_lag_31', 'Wind Speed(kmph)_lag_31', 'wind_CALM_lag_31', 'wind_E_lag_31', 'wind_N_lag_31', 'wind_S_lag_31', 'wind_W_lag_31', 'is_rain_lag_31', 'is_holiday_lag_31', 'is_weekend_lag_31', 'day_of_week_lag_31', 'time_of_day_[0, 3)_lag_31', 'time_of_day_[3, 6)_lag_31', 'time_of_day_[12, 15)_lag_31', 'time_of_day_[18, 21)_lag_31', 'time_of_day_[21, 24)_lag_31', 'fire_0_100_lag_31', 'fire_800_1000_lag_31', 'Temperature(C)_lag_46', 'Humidity(%)_lag_46', 'Wind Speed(kmph)_lag_46', 'wind_CALM_lag_46', 'wind_E_lag_46', 'wind_N_lag_46', 'wind_S_lag_46', 'wind_W_lag_46', 'is_rain_lag_46', 'is_holiday_lag_46', 'is_weekend_lag_46', 'day_of_week_lag_46', 'time_of_day_[0, 3)_lag_46', 'time_of_day_[3, 6)_lag_46', 'time_of_day_[12, 15)_lag_46', 'time_of_day_[18, 21)_lag_46', 'time_of_day_[21, 24)_lag_46', 'fire_0_100_lag_46', 'fire_400_800_lag_46', 'fire_800_1000_lag_46']
# score after dropping columns {'r2_score': 0.39594479249699965, 'mean_squared_error': 117.32640009944502, 'mean_absolute_error': 7.657074773120232}
# ================= optimization 6: optimize for the best rf again =================
# val score before refit {'val_r2_score': 0.39594479249699965, 'val_mean_squared_error': 117.32640009944502, 'val_mean_absolute_error': 7.657074773120232}
# test score before refit {'test_r2_score': 0.35883328403413706, 'test_mean_squared_error': 147.93049001201527, 'test_mean_absolute_error': 8.958787307676687}
# final score for test set {'test_r2_score': 0.3918192530597633, 'test_mean_squared_error': 140.3199412421352, 'test_mean_absolute_error': 8.76019412906186}

# %%
dataset, model, fire_cols, zone_list, feat_imp, roll_win = load_model(city='Bangkok', pollutant='PM2.5', split_list=[0.8, 0.2])
# Out:
# data no fire has shape (52762, 21)
# raw model performance {'test_r2_score': 0.4542498785184952, 'test_mean_squared_error': 105.04173082228195, 'test_mean_absolute_error': 7.638214197932823}
# daily avg training error {'avg_trn_r2_score': 0.8985223393551013, 'avg_trn_mean_squared_error': 19.241718681719895, 'avg_trn_mean_absolute_error': 3.1073030813220317}
# daily avg test error {'avg_test_r2_score': 0.5310800984925479, 'avg_test_mean_squared_error': 74.32586368022162, 'avg_test_mean_absolute_error': 6.4134822170156305}

# %%
ytrn_pred_df, ytest_pred_df = plot_model_perf(dataset=dataset, model=model, split_list=[0.8, 0.2], xlim=[], to_save=True)

# %%
dataset, model, poll_meta = train_city_s1(city= 'Bangkok', pollutant='PM2.5')
# Out:
# data no fire has shape (52783, 21)
# use default fire feature
# =================optimize 1: find the best RF model=================
# {'n_estimators': 140, 'min_samples_split': 50, 'min_samples_leaf': 25, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True} 0.26360985643197987
# optimize 1 score {'val_r2_score': 0.33113479290792536, 'val_mean_squared_error': 136.72001415900422, 'val_mean_absolute_error': 8.752519952985194}
# =================optimize 2: remove unncessary columns=================
# old cols length 26
# drop time_of_day_[21, 24)
# drop fire_100_200
# use columns ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day_[0, 3)', 'time_of_day_[3, 6)', 'time_of_day_[6, 9)', 'time_of_day_[9, 12)', 'time_of_day_[12, 15)', 'time_of_day_[15, 18)', 'time_of_day_[18, 21)', 'fire_0_100', 'fire_200_400', 'fire_400_600', 'fire_600_800', 'fire_800_1000']
# score after dropping columns {'r2_score': 0.3555949264409106, 'mean_squared_error': 131.72021783606507, 'mean_absolute_error': 8.574041423222406}
# ================= optimization 3: find the best fire feature ===================
# skop_ fire use x_cols ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day_[0, 3)', 'time_of_day_[3, 6)', 'time_of_day_[6, 9)', 'time_of_day_[9, 12)', 'time_of_day_[12, 15)', 'time_of_day_[15, 18)', 'time_of_day_[18, 21)', 'time_of_day_[21, 24)', 'fire_0_100', 'fire_100_200', 'fire_200_400', 'fire_400_600', 'fire_600_800', 'fire_800_1000']
# old score 136.72001415900422 fire dict {'w_speed': 7, 'shift': -5, 'roll': 44}
# optimizing fire parameter using skopt optimizer. This will take about 20 mins
# mean_squared_error for the best fire parameters 125.76374230503919
# new fire dict {'w_speed': 9, 'shift': -56, 'roll': 138}
# ================= optimization 4: improve model performance by adding lag columns =================
# model parameters {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'mse', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 25, 'min_samples_split': 50, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 140, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# new mean squared error 117.96531693932005 using {'n_max': 36, 'step': 13, 'roll': True}
# x_cols Index(['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM',
#        'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday',
#        'is_weekend', 'day_of_week', 'time_of_day_[0, 3)', 'time_of_day_[3, 6)',
#        'time_of_day_[6, 9)', 'time_of_day_[9, 12)', 'time_of_day_[12, 15)',
#        'time_of_day_[15, 18)', 'time_of_day_[18, 21)', 'fire_0_100',
#        'fire_200_400', 'fire_400_600', 'fire_600_800', 'fire_800_1000',
#        'Temperature(C)_lag_1', 'Humidity(%)_lag_1', 'Wind Speed(kmph)_lag_1',
#        'wind_CALM_lag_1', 'wind_E_lag_1', 'wind_N_lag_1', 'wind_S_lag_1',
#        'wind_W_lag_1', 'is_rain_lag_1', 'is_holiday_lag_1', 'is_weekend_lag_1',
#        'day_of_week_lag_1', 'time_of_day_[0, 3)_lag_1',
#        'time_of_day_[3, 6)_lag_1', 'time_of_day_[6, 9)_lag_1',
#        'time_of_day_[9, 12)_lag_1', 'time_of_day_[12, 15)_lag_1',
#        'time_of_day_[15, 18)_lag_1', 'time_of_day_[18, 21)_lag_1',
#        'fire_0_100_lag_1', 'fire_200_400_lag_1', 'fire_400_600_lag_1',
#        'fire_600_800_lag_1', 'fire_800_1000_lag_1', 'Temperature(C)_lag_14',
#        'Humidity(%)_lag_14', 'Wind Speed(kmph)_lag_14', 'wind_CALM_lag_14',
#        'wind_E_lag_14', 'wind_N_lag_14', 'wind_S_lag_14', 'wind_W_lag_14',
#        'is_rain_lag_14', 'is_holiday_lag_14', 'is_weekend_lag_14',
#        'day_of_week_lag_14', 'time_of_day_[0, 3)_lag_14',
#        'time_of_day_[3, 6)_lag_14', 'time_of_day_[6, 9)_lag_14',
#        'time_of_day_[9, 12)_lag_14', 'time_of_day_[12, 15)_lag_14',
#        'time_of_day_[15, 18)_lag_14', 'time_of_day_[18, 21)_lag_14',
#        'fire_0_100_lag_14', 'fire_200_400_lag_14', 'fire_400_600_lag_14',
#        'fire_600_800_lag_14', 'fire_800_1000_lag_14', 'Temperature(C)_lag_27',
#        'Humidity(%)_lag_27', 'Wind Speed(kmph)_lag_27', 'wind_CALM_lag_27',
#        'wind_E_lag_27', 'wind_N_lag_27', 'wind_S_lag_27', 'wind_W_lag_27',
#        'is_rain_lag_27', 'is_holiday_lag_27', 'is_weekend_lag_27',
#        'day_of_week_lag_27', 'time_of_day_[0, 3)_lag_27',
#        'time_of_day_[3, 6)_lag_27', 'time_of_day_[6, 9)_lag_27',
#        'time_of_day_[9, 12)_lag_27', 'time_of_day_[12, 15)_lag_27',
#        'time_of_day_[15, 18)_lag_27', 'time_of_day_[18, 21)_lag_27',
#        'fire_0_100_lag_27', 'fire_200_400_lag_27', 'fire_400_600_lag_27',
#        'fire_600_800_lag_27', 'fire_800_1000_lag_27'],
#       dtype='object')
# xtrn has shape (23740, 96)
# op4 score {'val_r2_score': 0.39016432381347443, 'val_mean_squared_error': 117.96531693932005, 'val_mean_absolute_error': 7.678778713346611}
# op4 test score {'test_r2_score': 0.37491515855443525, 'test_mean_squared_error': 144.34798591529562, 'test_mean_absolute_error': 8.940704302120208}
# ================= optimization 5: remove unncessary lag columns =================
# old cols length 96
# drop is_holiday_lag_1
# use columns ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day_[0, 3)', 'time_of_day_[3, 6)', 'time_of_day_[6, 9)', 'time_of_day_[9, 12)', 'time_of_day_[12, 15)', 'time_of_day_[15, 18)', 'time_of_day_[18, 21)', 'fire_0_100', 'fire_200_400', 'fire_400_600', 'fire_600_800', 'fire_800_1000', 'Temperature(C)_lag_1', 'Humidity(%)_lag_1', 'Wind Speed(kmph)_lag_1', 'wind_CALM_lag_1', 'wind_E_lag_1', 'wind_N_lag_1', 'wind_S_lag_1', 'wind_W_lag_1', 'is_rain_lag_1', 'is_weekend_lag_1', 'day_of_week_lag_1', 'time_of_day_[0, 3)_lag_1', 'time_of_day_[3, 6)_lag_1', 'time_of_day_[6, 9)_lag_1', 'time_of_day_[9, 12)_lag_1', 'time_of_day_[12, 15)_lag_1', 'time_of_day_[15, 18)_lag_1', 'time_of_day_[18, 21)_lag_1', 'fire_0_100_lag_1', 'fire_200_400_lag_1', 'fire_400_600_lag_1', 'fire_600_800_lag_1', 'fire_800_1000_lag_1', 'Temperature(C)_lag_14', 'Humidity(%)_lag_14', 'Wind Speed(kmph)_lag_14', 'wind_CALM_lag_14', 'wind_E_lag_14', 'wind_N_lag_14', 'wind_S_lag_14', 'wind_W_lag_14', 'is_rain_lag_14', 'is_holiday_lag_14', 'is_weekend_lag_14', 'day_of_week_lag_14', 'time_of_day_[0, 3)_lag_14', 'time_of_day_[3, 6)_lag_14', 'time_of_day_[6, 9)_lag_14', 'time_of_day_[9, 12)_lag_14', 'time_of_day_[12, 15)_lag_14', 'time_of_day_[15, 18)_lag_14', 'time_of_day_[18, 21)_lag_14', 'fire_0_100_lag_14', 'fire_200_400_lag_14', 'fire_400_600_lag_14', 'fire_600_800_lag_14', 'fire_800_1000_lag_14', 'Temperature(C)_lag_27', 'Humidity(%)_lag_27', 'Wind Speed(kmph)_lag_27', 'wind_CALM_lag_27', 'wind_E_lag_27', 'wind_N_lag_27', 'wind_S_lag_27', 'wind_W_lag_27', 'is_rain_lag_27', 'is_holiday_lag_27', 'is_weekend_lag_27', 'day_of_week_lag_27', 'time_of_day_[0, 3)_lag_27', 'time_of_day_[3, 6)_lag_27', 'time_of_day_[6, 9)_lag_27', 'time_of_day_[9, 12)_lag_27', 'time_of_day_[12, 15)_lag_27', 'time_of_day_[15, 18)_lag_27', 'time_of_day_[18, 21)_lag_27', 'fire_0_100_lag_27', 'fire_200_400_lag_27', 'fire_400_600_lag_27', 'fire_600_800_lag_27', 'fire_800_1000_lag_27']
# score after dropping columns {'r2_score': 0.3911331515907821, 'mean_squared_error': 117.7779089534108, 'mean_absolute_error': 7.675290286631154}
# ================= optimization 6: optimize for the best rf again =================
# val score before refit {'val_r2_score': 0.3911331515907821, 'val_mean_squared_error': 117.7779089534108, 'val_mean_absolute_error': 7.675290286631154}
# test score before refit {'test_r2_score': 0.3802267135174743, 'test_mean_squared_error': 143.12141280048453, 'test_mean_absolute_error': 8.882720801513846}
# final score for test set {'test_r2_score': 0.4149973898379875, 'test_mean_squared_error': 135.09197941321557, 'test_mean_absolute_error': 8.685404595849645}

# %%
dataset, model, fire_cols, zone_list, feat_imp, roll_win = load_model(city='Bangkok', pollutant='PM2.5', split_list=[0.8, 0.2])
# Out:
# data no fire has shape (52801, 21)
# raw model performance {'test_r2_score': 0.44643308046105057, 'test_mean_squared_error': 106.50649183085086, 'test_mean_absolute_error': 7.73752343300369}
# daily avg training error {'avg_trn_r2_score': 0.8521492072108316, 'avg_trn_mean_squared_error': 28.18101878093847, 'avg_trn_mean_absolute_error': 3.81684957280046}
# daily avg test error {'avg_test_r2_score': 0.5263525346044393, 'avg_test_mean_squared_error': 75.09394652925938, 'avg_test_mean_absolute_error': 6.475809606518423}

# %%
ytrn_pred_df, ytest_pred_df = plot_model_perf(dataset=dataset, model=model, split_list=[0.8, 0.2], xlim=[], to_save=True)
