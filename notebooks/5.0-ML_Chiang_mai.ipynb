# %%
#  Load the "autoreload" extension so that code can change
# %load_ext autoreload
# %reload_ext autoreload
from pathlib import Path

#  always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append('../')
from src.imports import *
from src.data.download_data import *
from src.data.fire_data import *
from src.data.read_data import *
from src.gen_functions import *
from src.features.dataset import Dataset
from src.features.build_features import *
from src.models.train_model import *
import seaborn as sns
output_notebook()
# set font size 
from src.visualization.vis_model import *
from src.models.train_model import *
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Experiment with lag

# %%
data = Dataset('Chiang Mai')
data.load_()
data.monitor = data.pollutant = 'PM2.5'
# build the first dataset 
data.feature_no_fire()
data.fire_dict = {'w_speed': 7, 'shift': -5, 'roll': 44}
# use default fire feature
data.merge_fire()
# Out:
# data no fire has shape (77747, 14)
# use default fire feature
# (['fire_0_100',
#   'fire_100_200',
#   'fire_200_400',
#   'fire_400_700',
#   'fire_700_1000'],
#  [0, 100, 200, 400, 700, 1000])

# %%
print('Step 1 Get a reasonable RF model')
data.split_data(split_ratio=[0.3, 0.25, 0.25, 0.2])
xtrn, ytrn, x_cols = data.get_data_matrix(use_index=data.split_list[0])
xval, yval, _ = data.get_data_matrix(use_index=data.split_list[1])
print(xtrn.shape)
# Out:
# Step 1 Get a reasonable RF model
# (23324, 17)

# %%
# %%time
model = do_rf_search(xtrn,ytrn, x_tree=False)
score_dict = cal_scores(yval, model.predict(xval), header_str ='val_')
print('optimize 1 score', score_dict)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)
# {'n_estimators': 120, 'min_samples_split': 50, 'min_samples_leaf': 12, 'max_features': 2, 'max_depth': None, 'bootstrap': True} 0.12148704705450666
# optimize 1 score {'val_r2_score': 0.5107975772057206, 'val_mean_squared_error': 615.8945686775909, 'val_mean_absolute_error': 14.907642748269327}
# Wall time: 6min 52s

# %%
importances = model.feature_importances_
feat_imp = pd.DataFrame(importances, index=x_cols, columns=['importance']) 
feat_imp = feat_imp.sort_values('importance',ascending=False).reset_index()
show_fea_imp(feat_imp, title='rf feature of importance(raw)')

# %%
# optimize 1 drop unuse cols 
to_drop = feat_imp['index']
to_drop = [a for a in to_drop if 'fire' not in a]

for s in ['Humidity(%)','Temperature(C)','Wind Speed(kmph)']:
    to_drop.remove(s)
to_drop.reverse()

model, new_x_cols = reduce_cols(dataset=data,x_cols=x_cols,to_drop=to_drop,model=model,trn_i=0, val_i=1)
data.x_cols = new_x_cols
# Out:
# old cols length 17
# drop is_rain
# drop wind_E
# drop wind_N
# drop is_weekend
# drop wind_W
# drop day_of_week
# use columns Index(['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM',
#        'wind_S', 'is_holiday', 'time_of_day', 'fire_0_100', 'fire_100_400',
#        'fire_400_700', 'fire_700_1000'],
#       dtype='object')
# r2_score after dropping columns 0.5354552887695351

# %%
data.x_cols_org = data.x_cols = ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM',
       'wind_S', 'is_holiday', 'time_of_day', 'fire_0_100', 'fire_100_400',
       'fire_400_700', 'fire_700_1000']

data.data_org = data.data[data.x_cols_org + [data.monitor]]

data.fire_dict = {'w_speed': 7, 'shift': -5, 'roll': 44}

data.split_data(split_ratio=[0.3, 0.25, 0.25, 0.2])
model = RandomForestRegressor(**{'n_estimators': 120, 'min_samples_split': 50, 'min_samples_leaf': 12, 'max_features': 2, 'max_depth': None, 'bootstrap': True} )

# %%
# %%time
data.fire_dict, gp_result = sk_op_fire(data, model, trn_index=data.split_list[0], val_index=data.split_list[1])
print(data.fire_dict)
# Out:
# skop_ fire use x_cols ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_S', 'is_holiday', 'time_of_day', 'fire_0_100', 'fire_100_400', 'fire_400_700', 'fire_700_1000']
# old score 14.767829432042104 fire dict {'w_speed': 4, 'shift': -24, 'roll': 108}
# optimizing fire parameter using skopt optimizer. This will take about 20 mins
# mean_absolute_error for the best fire parameters 14.318928093836577
# {'w_speed': 7, 'shift': -5, 'roll': 44}
# Wall time: 15min 10s

# %%
data.split_data(split_ratio=[0.45, 0.25, 0.3])
xtrn, ytrn, x_cols = data.get_data_matrix(use_index=data.split_list[0], x_cols=data.x_cols)
xval, yval, _ = data.get_data_matrix(use_index=data.split_list[1], x_cols=data.x_cols)
model.fit(xtrn,ytrn)
cal_scores(yval, model.predict(xval))
# Out:
# {'test_r2_score': 0.6892129758262073,
#  'test_mean_squared_error': 154.51890304753374,
#  'test_mean_absolute_error': 8.739730065150068}

# %%
plt.plot(data.split_list[0], ytrn)
plt.plot(data.split_list[0], model.predict(xtrn))

plt.plot(data.split_list[1], yval)
plt.plot(data.split_list[1], model.predict(xval))

# %%
# Add lag
#data.build_lag(lag_range=[1,5,10,20,50,100,200])
score = 154
best_lag = 0
score_df = []
for max_n in np.arange(12,36,1):
    for step in np.arange(1,13,2):
        data.build_lag(lag_range=np.arange(1,max_n,step),roll=True)
    
        data.x_cols = data.data.columns
    
        data.split_data(split_ratio=[0.45, 0.25, 0.3])
        xtrn, ytrn, x_cols = data.get_data_matrix(use_index=data.split_list[0], x_cols=data.x_cols)
        xval, yval, _ = data.get_data_matrix(use_index=data.split_list[1], x_cols=data.x_cols)
        print(xtrn.shape)
        model.fit(xtrn,ytrn)
        result_dict = cal_scores(yval, model.predict(xval))
        result_dict['step'] = step
        score_df.append(pd.DataFrame(result_dict, index=[max_n]))
     
score_df = pd.concat(score_df).sort_values(['test_mean_squared_error'])
score_df.sort_values('test_mean_squared_error')
# Out:
# (34981, 133)
# (34981, 56)
# (34981, 45)
# (34982, 34)
# (34981, 34)
# (34985, 23)
# (34980, 144)
# (34981, 56)
# (34981, 45)
# (34982, 34)
# (34981, 34)
# (34980, 34)
# (34980, 155)
# (34980, 67)
# (34981, 45)
# (34982, 34)
# (34981, 34)
# (34980, 34)
# (34979, 166)
# (34980, 67)
# (34981, 45)
# (34982, 34)
# (34981, 34)
# (34980, 34)
# (34979, 177)
# (34980, 67)
# (34981, 45)
# (34979, 45)
# (34981, 34)
# (34980, 34)
# (34978, 188)
# (34978, 78)
# (34978, 56)
# (34979, 45)
# (34981, 34)
# (34980, 34)
# (34978, 199)
# (34978, 78)
# (34978, 56)
# (34979, 45)
# (34981, 34)
# (34980, 34)
# (34978, 210)
# (34978, 78)
# (34978, 56)
# (34979, 45)
# (34981, 34)
# (34980, 34)
# (34977, 221)
# (34977, 89)
# (34978, 56)
# (34979, 45)
# (34977, 45)
# (34980, 34)
# (34977, 232)
# (34977, 89)
# (34978, 56)
# (34979, 45)
# (34977, 45)
# (34980, 34)
# (34976, 243)
# (34977, 89)
# (34976, 67)
# (34979, 45)
# (34977, 45)
# (34980, 34)
# (34976, 254)
# (34976, 100)
# (34976, 67)
# (34976, 56)
# (34977, 45)
# (34980, 34)
# (34975, 265)
# (34976, 100)
# (34976, 67)
# (34976, 56)
# (34977, 45)
# (34975, 45)
# (34975, 276)
# (34976, 100)
# (34976, 67)
# (34976, 56)
# (34977, 45)
# (34975, 45)
# (34974, 287)
# (34974, 111)
# (34976, 67)
# (34976, 56)
# (34977, 45)
# (34975, 45)
# (34974, 298)
# (34974, 111)
# (34974, 78)
# (34976, 56)
# (34977, 45)
# (34975, 45)
# (34974, 309)
# (34974, 111)
# (34974, 78)
# (34976, 56)
# (34977, 45)
# (34975, 45)
# (34973, 320)
# (34973, 122)
# (34974, 78)
# (34976, 56)
# (34973, 56)
# (34975, 45)
# (34973, 331)
# (34973, 122)
# (34974, 78)
# (34973, 67)
# (34973, 56)
# (34975, 45)
# (34972, 342)
# (34973, 122)
# (34974, 78)
# (34973, 67)
# (34973, 56)
# (34975, 45)
# (34972, 353)
# (34972, 133)
# (34972, 89)
# (34973, 67)
# (34973, 56)
# (34975, 45)
# (34971, 364)
# (34972, 133)
# (34972, 89)
# (34973, 67)
# (34973, 56)
# (34975, 45)
# (34971, 375)
# (34972, 133)
# (34972, 89)
# (34973, 67)
# (34973, 56)
# (34975, 45)
# (34970, 386)
# (34970, 144)
# (34972, 89)
# (34973, 67)
# (34973, 56)
# (34970, 56)
#     test_r2_score  test_mean_squared_error  test_mean_absolute_error  step
# 12       0.905082                47.192001                  4.316788    11
# 14       0.876727                61.287102                  5.128404     9
# 12       0.876498                61.401039                  5.198639     9
# 16       0.876425                61.437906                  5.082981    11
# 14       0.875265                62.015300                  5.110443     7
# ..            ...                      ...                       ...   ...
# 25       0.754517               122.047966                  7.813560     1
# 28       0.753880               122.356072                  7.822415     1
# 35       0.752689               122.961562                  7.894733     1
# 34       0.752369               123.120628                  7.918511     1
# 29       0.750263               124.158200                  7.867753     1
#
# [144 rows x 4 columns]

# %%
# %%time
lag_dict, gp_result = op_lag(data, model, split_ratio=[0.45, 0.25, 0.3])
# Out:
# new mean squared error 43.58435051767538 using {'max_n': 12, 'step': 25}
# Wall time: 6min 28s

# %%
data.build_lag(lag_range=np.arange(1,lag_dict['n_max'],lag_dict['step']),roll=True)
data.x_cols = data.data.columns
    
data.split_data(split_ratio=[0.45, 0.25, 0.3])
xtrn, ytrn, x_cols = data.get_data_matrix(use_index=data.split_list[0], x_cols=data.x_cols)
xval, yval, _ = data.get_data_matrix(use_index=data.split_list[1], x_cols=data.x_cols)
print(xtrn.shape)
model.fit(xtrn,ytrn)
result_dict = cal_scores(yval, model.predict(xval))

result_dict
# Out:
# (34985, 23)
# {'test_r2_score': 0.9133531453995838,
#  'test_mean_squared_error': 43.07958789775131,
#  'test_mean_absolute_error': 4.112504672174814}

# %%
importances = model.feature_importances_
feat_imp = pd.DataFrame(importances, index=x_cols, columns=['importance']) 
feat_imp = feat_imp.sort_values('importance',ascending=False).reset_index()

# optimize 1 drop unuse cols 
to_drop = feat_imp['index']
to_drop = [a for a in to_drop if 'fire' not in a]

for s in ['Humidity(%)','Temperature(C)','Wind Speed(kmph)']:
    to_drop.remove(s)
to_drop.reverse()
model, new_x_cols = reduce_cols(dataset=data,x_cols=data.x_cols,to_drop=to_drop,model=model,trn_i=0, val_i=1)
data.x_cols = new_x_cols
# Out:
# old cols length 23
# drop is_holiday
# drop wind_S
# drop wind_CALM
# drop wind_S_lag_1
# drop wind_CALM_lag_1
# drop time_of_day_lag_1
# drop time_of_day
# drop Wind Speed(kmph)_lag_1
# drop Temperature(C)_lag_1
# drop Humidity(%)_lag_1
# use columns Index(['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'fire_0_100',
#        'fire_100_400', 'fire_400_700', 'fire_700_1000', 'PM2.5',
#        'is_holiday_lag_1', 'fire_0_100_lag_1', 'fire_100_400_lag_1',
#        'fire_400_700_lag_1', 'fire_700_1000_lag_1'],
#       dtype='object')
# r2_score after dropping columns 0.9527129113839794

# %%
xtrn, ytrn, x_cols = data.get_data_matrix(use_index=data.split_list[0], x_cols=data.x_cols)
xval, yval, _ = data.get_data_matrix(use_index=data.split_list[1], x_cols=data.x_cols)

# %%
plt.figure(figsize=(10,4))
plt.plot(data.split_list[0], ytrn)
plt.plot(data.split_list[0], model.predict(xtrn))

plt.plot(data.split_list[1], yval)
plt.plot(data.split_list[1], model.predict(xval))

#plt.xlim([data.split_list[1][100:].min(), data.split_list[1][:2000].max()])

# %%
importances = model.feature_importances_
feat_imp = pd.DataFrame(importances, index=x_cols, columns=['importance']) 
feat_imp = feat_imp.sort_values('importance',ascending=False).reset_index()
show_fea_imp(feat_imp, title='rf feature of importance(raw)')

# %% [markdown]
# ## Senario

# %%
col_to_reduce = data.data.columns[data.data.columns.str.contains('fire_0_100')]
data.data[col_to_reduce] *=0.1

# %%
col_to_reduce = data.data.columns[data.data.columns.str.contains('fire_100_400')]
data.data[col_to_reduce] *=0.1

# %%
# Build a senario
#data.split_data(split_ratio=[0.35, 0.25, 0.20, 0.2])
xtrn_s , ytrn_s, x_cols = data.get_data_matrix(use_index=data.split_list[0], x_cols=data.x_cols)
xval_s, yval_s, _ = data.get_data_matrix(use_index=data.split_list[1], x_cols=data.x_cols)

# %%
ytrn_s_pred = model.predict(xtrn_s)
yval_s_pred = model.predict(xval_s)

# %%
plt.plot(ytrn_s)
plt.plot(model.predict(xtrn))
plt.plot(ytrn_s_pred)

# %%
trn_df_s = pd.DataFrame(ytrn, index=data.split_list[0], columns=['PM2.5'])
trn_df_s['pred'] = model.predict(xtrn_s)
trn_df_s['shift'] = trn_df_s['PM2.5'].shift(1) + 2*np.random.normal(size=len(trn_df_s))
trn_df_s = trn_df_s.round().dropna()


val_df_s = pd.DataFrame(yval, index=data.split_list[1], columns=['PM2.5'])
val_df_s['pred'] = model.predict(xval_s)
val_df_s['shift'] = val_df_s['PM2.5'].shift(1) + 2*np.random.normal(size=len(val_df_s))
val_df_s = val_df_s.round().dropna()

# %%
ytrn_ln_s = trn_df_s['PM2.5'].values
xtrn_ln_s = trn_df_s[['pred','shift']].values

yval_ln_s = val_df_s['PM2.5'].values
xval_ln_s = val_df_s[['pred','shift']].values

# %%
yln_iter_pred = []
for i, value in enumerate(trn_df_s['pred']):
    if i == 0:
        arr = np.array([value, int_value]).reshape(1,-1)
    else: 
        arr = np.array([value, prev]).reshape(1,-1)
        
    prev = regr.predict(arr)
    yln_iter_pred.append(prev)
    
    
yval_iter_pred = []
for i, value in enumerate(val_df_s['pred']):
    if i == 0:
        arr = np.array([value, int_value]).reshape(1,-1)
    else: 
        arr = np.array([value, prev]).reshape(1,-1)
        
    prev = regr.predict(arr)
    yval_iter_pred.append(prev)

# %%
plt.figure(figsize=(10,5))
plt.plot(trn_df.index[1:], ytrn_ln)
plt.plot(trn_df.index[1:], regr.predict(xtrn_ln))
plt.plot(trn_df_s.index, regr.predict(xtrn_ln_s) )
plt.plot(trn_df.index[1:], yln_iter_pred)

plt.plot(val_df.index, yval_ln)
plt.plot(val_df.index, regr.predict(xval_ln))
plt.plot(val_df_s.index, regr.predict(xval_ln_s) )
plt.plot(val_df.index, yval_iter_pred)

# %% [markdown]
# # Training with Lag

# %% [markdown]
# ## Stage 1

# %%
# %%time 
# with roll 
data, rf_model, poll_meta = train_city_s1(city='Chiang Mai', pollutant='PM2.5', build=False, rolling_win=True)
# Out:
# rolling_win  24
# data no fire has shape (78565, 14)
# use default fire feature
# =================optimize 1: find the best RF model=================
# {'n_estimators': 20, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'log2', 'max_depth': 3, 'bootstrap': True} -0.09154370696764255
# optimize 1 score {'val_r2_score': 0.5837140138469783, 'val_mean_squared_error': 352.2499650531784, 'val_mean_absolute_error': 10.93236530718047}
# =================optimize 2: remove unncessary columns=================
# old cols length 18
# drop wind_E
# use columns ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day', 'fire_0_100', 'fire_100_200', 'fire_200_400', 'fire_400_700', 'fire_700_1000']
# score after dropping columns {'r2_score': 0.6031286945511642, 'mean_squared_error': 335.8217862841379, 'mean_absolute_error': 10.56701382673738}
# ================= optimization 3: find the best fire feature ===================
# skop_ fire use x_cols ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day', 'fire_0_100', 'fire_100_200', 'fire_200_400', 'fire_400_700', 'fire_700_1000']
# old score 352.2499650531784 fire dict {'w_speed': 7, 'shift': -5, 'roll': 44}
# optimizing fire parameter using skopt optimizer. This will take about 20 mins
# mean_squared_error for the best fire parameters 328.1941530296244
# new fire dict {'w_speed': 8, 'shift': -72, 'roll': 140}
# ================= optimization 4: improve model performance by adding lag columns =================
# model parameters {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'mse', 'max_depth': 3, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 20, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# new mean squared error 108.3164098898853 using {'n_max': 112, 'step': 24, 'roll': True}
# x_cols Index(['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM',
#        'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend',
#        ...
#        'is_rain_lag_97', 'is_holiday_lag_97', 'is_weekend_lag_97',
#        'day_of_week_lag_97', 'time_of_day_lag_97', 'fire_0_100_lag_97',
#        'fire_100_200_lag_97', 'fire_200_400_lag_97', 'fire_400_700_lag_97',
#        'fire_700_1000_lag_97'],
#       dtype='object', length=102)
# xtrn has shape (35310, 102)
# op4 score {'val_r2_score': 0.7576798025932179, 'val_mean_squared_error': 108.3164098898853, 'val_mean_absolute_error': 7.639976522931811}
# op4 test score {'test_r2_score': 0.714830437291291, 'test_mean_squared_error': 191.31303358570838, 'test_mean_absolute_error': 9.330008226538707}
# ================= optimization 5: remove unncessary lag columns =================
# old cols length 102
# drop fire_0_100_lag_25
# use columns ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day', 'fire_0_100', 'fire_100_200', 'fire_200_400', 'fire_400_700', 'fire_700_1000', 'Temperature(C)_lag_1', 'Humidity(%)_lag_1', 'Wind Speed(kmph)_lag_1', 'wind_CALM_lag_1', 'wind_N_lag_1', 'wind_S_lag_1', 'wind_W_lag_1', 'is_rain_lag_1', 'is_holiday_lag_1', 'is_weekend_lag_1', 'day_of_week_lag_1', 'time_of_day_lag_1', 'fire_0_100_lag_1', 'fire_100_200_lag_1', 'fire_200_400_lag_1', 'fire_400_700_lag_1', 'fire_700_1000_lag_1', 'Temperature(C)_lag_25', 'Humidity(%)_lag_25', 'Wind Speed(kmph)_lag_25', 'wind_CALM_lag_25', 'wind_N_lag_25', 'wind_S_lag_25', 'wind_W_lag_25', 'is_rain_lag_25', 'is_holiday_lag_25', 'is_weekend_lag_25', 'day_of_week_lag_25', 'time_of_day_lag_25', 'fire_100_200_lag_25', 'fire_200_400_lag_25', 'fire_400_700_lag_25', 'fire_700_1000_lag_25', 'Temperature(C)_lag_49', 'Humidity(%)_lag_49', 'Wind Speed(kmph)_lag_49', 'wind_CALM_lag_49', 'wind_N_lag_49', 'wind_S_lag_49', 'wind_W_lag_49', 'is_rain_lag_49', 'is_holiday_lag_49', 'is_weekend_lag_49', 'day_of_week_lag_49', 'time_of_day_lag_49', 'fire_0_100_lag_49', 'fire_100_200_lag_49', 'fire_200_400_lag_49', 'fire_400_700_lag_49', 'fire_700_1000_lag_49', 'Temperature(C)_lag_73', 'Humidity(%)_lag_73', 'Wind Speed(kmph)_lag_73', 'wind_CALM_lag_73', 'wind_N_lag_73', 'wind_S_lag_73', 'wind_W_lag_73', 'is_rain_lag_73', 'is_holiday_lag_73', 'is_weekend_lag_73', 'day_of_week_lag_73', 'time_of_day_lag_73', 'fire_0_100_lag_73', 'fire_100_200_lag_73', 'fire_200_400_lag_73', 'fire_400_700_lag_73', 'fire_700_1000_lag_73', 'Temperature(C)_lag_97', 'Humidity(%)_lag_97', 'Wind Speed(kmph)_lag_97', 'wind_CALM_lag_97', 'wind_N_lag_97', 'wind_S_lag_97', 'wind_W_lag_97', 'is_rain_lag_97', 'is_holiday_lag_97', 'is_weekend_lag_97', 'day_of_week_lag_97', 'time_of_day_lag_97', 'fire_0_100_lag_97', 'fire_100_200_lag_97', 'fire_200_400_lag_97', 'fire_400_700_lag_97', 'fire_700_1000_lag_97']
# score after dropping columns {'r2_score': 0.7621564524409934, 'mean_squared_error': 106.31536067882362, 'mean_absolute_error': 7.561088771903482}
# ================= optimization 8: optimize for the best rf again =================
# val score before refit {'val_r2_score': 0.7621564524409934, 'val_mean_squared_error': 106.31536067882362, 'val_mean_absolute_error': 7.561088771903482}
# test score before refit {'test_r2_score': 0.7173296777582199, 'test_mean_squared_error': 189.6363564857869, 'test_mean_absolute_error': 9.151076471905185}
# final score for test set {'test_r2_score': 0.730576591438785, 'test_mean_squared_error': 180.7493377668023, 'test_mean_absolute_error': 8.663314586731673}
# Wall time: 33min 22s

# %%
# %%time
#  (no roll)
data, rf_model, poll_meta = train_city_s1(city='Chiang Mai', pollutant='PM2.5', build=False, rolling_win=False)
# Out:
# rolling_win  1
# data no fire has shape (77747, 14)
# use default fire feature
# =================optimize 1: find the best RF model=================
# {'n_estimators': 180, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True} 0.07241942841927984
# optimize 1 score {'val_r2_score': 0.5980980424201171, 'val_mean_squared_error': 372.48529775992387, 'val_mean_absolute_error': 10.928152599405301}
# =================optimize 2: remove unncessary columns=================
# old cols length 18
# use columns ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day', 'fire_0_100', 'fire_100_200', 'fire_200_400', 'fire_400_700', 'fire_700_1000']
# score after dropping columns {'r2_score': 0.5980980424201171, 'mean_squared_error': 372.48529775992387, 'mean_absolute_error': 10.928152599405301}
# ================= optimization 3: find the best fire feature ===================
# skop_ fire use x_cols ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day', 'fire_0_100', 'fire_100_200', 'fire_200_400', 'fire_400_700', 'fire_700_1000']
# old score 372.48529775992387 fire dict {'w_speed': 7, 'shift': -5, 'roll': 44}
# optimizing fire parameter using skopt optimizer. This will take about 20 mins
# mean_squared_error for the best fire parameters 368.1853719869944
# new fire dict {'w_speed': 18, 'shift': 22, 'roll': 30}
# ================= optimization 4: improve model performance by adding lag columns =================
# model parameters {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'mse', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 17, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 180, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# new mean squared error 137.23950574851574 using {'n_max': 45, 'step': 7, 'roll': True}
# x_cols Index(['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM',
#        'wind_E', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday',
#        ...
#        'is_rain_lag_43', 'is_holiday_lag_43', 'is_weekend_lag_43',
#        'day_of_week_lag_43', 'time_of_day_lag_43', 'fire_0_100_lag_43',
#        'fire_100_200_lag_43', 'fire_200_400_lag_43', 'fire_400_700_lag_43',
#        'fire_700_1000_lag_43'],
#       dtype='object', length=144)
# xtrn has shape (34940, 144)
# op4 score {'val_r2_score': 0.7241804856023593, 'val_mean_squared_error': 137.23950574851574, 'val_mean_absolute_error': 8.281338373566125}
# op4 test score {'test_r2_score': 0.7063872217704759, 'test_mean_squared_error': 229.5519249852993, 'test_mean_absolute_error': 9.698544122303796}
# ================= optimization 5: remove unncessary lag columns =================
# old cols length 144
# drop wind_E
# drop fire_100_200_lag_22
# use columns ['Temperature(C)', 'Humidity(%)', 'Wind Speed(kmph)', 'wind_CALM', 'wind_N', 'wind_S', 'wind_W', 'is_rain', 'is_holiday', 'is_weekend', 'day_of_week', 'time_of_day', 'fire_0_100', 'fire_100_200', 'fire_200_400', 'fire_400_700', 'fire_700_1000', 'Temperature(C)_lag_1', 'Humidity(%)_lag_1', 'Wind Speed(kmph)_lag_1', 'wind_CALM_lag_1', 'wind_E_lag_1', 'wind_N_lag_1', 'wind_S_lag_1', 'wind_W_lag_1', 'is_rain_lag_1', 'is_holiday_lag_1', 'is_weekend_lag_1', 'day_of_week_lag_1', 'time_of_day_lag_1', 'fire_0_100_lag_1', 'fire_100_200_lag_1', 'fire_200_400_lag_1', 'fire_400_700_lag_1', 'fire_700_1000_lag_1', 'Temperature(C)_lag_8', 'Humidity(%)_lag_8', 'Wind Speed(kmph)_lag_8', 'wind_CALM_lag_8', 'wind_E_lag_8', 'wind_N_lag_8', 'wind_S_lag_8', 'wind_W_lag_8', 'is_rain_lag_8', 'is_holiday_lag_8', 'is_weekend_lag_8', 'day_of_week_lag_8', 'time_of_day_lag_8', 'fire_0_100_lag_8', 'fire_100_200_lag_8', 'fire_200_400_lag_8', 'fire_400_700_lag_8', 'fire_700_1000_lag_8', 'Temperature(C)_lag_15', 'Humidity(%)_lag_15', 'Wind Speed(kmph)_lag_15', 'wind_CALM_lag_15', 'wind_E_lag_15', 'wind_N_lag_15', 'wind_S_lag_15', 'wind_W_lag_15', 'is_rain_lag_15', 'is_holiday_lag_15', 'is_weekend_lag_15', 'day_of_week_lag_15', 'time_of_day_lag_15', 'fire_0_100_lag_15', 'fire_100_200_lag_15', 'fire_200_400_lag_15', 'fire_400_700_lag_15', 'fire_700_1000_lag_15', 'Temperature(C)_lag_22', 'Humidity(%)_lag_22', 'Wind Speed(kmph)_lag_22', 'wind_CALM_lag_22', 'wind_E_lag_22', 'wind_N_lag_22', 'wind_S_lag_22', 'wind_W_lag_22', 'is_rain_lag_22', 'is_holiday_lag_22', 'is_weekend_lag_22', 'day_of_week_lag_22', 'time_of_day_lag_22', 'fire_0_100_lag_22', 'fire_200_400_lag_22', 'fire_400_700_lag_22', 'fire_700_1000_lag_22', 'Temperature(C)_lag_29', 'Humidity(%)_lag_29', 'Wind Speed(kmph)_lag_29', 'wind_CALM_lag_29', 'wind_E_lag_29', 'wind_N_lag_29', 'wind_S_lag_29', 'wind_W_lag_29', 'is_rain_lag_29', 'is_holiday_lag_29', 'is_weekend_lag_29', 'day_of_week_lag_29', 'time_of_day_lag_29', 'fire_0_100_lag_29', 'fire_100_200_lag_29', 'fire_200_400_lag_29', 'fire_400_700_lag_29', 'fire_700_1000_lag_29', 'Temperature(C)_lag_36', 'Humidity(%)_lag_36', 'Wind Speed(kmph)_lag_36', 'wind_CALM_lag_36', 'wind_E_lag_36', 'wind_N_lag_36', 'wind_S_lag_36', 'wind_W_lag_36', 'is_rain_lag_36', 'is_holiday_lag_36', 'is_weekend_lag_36', 'day_of_week_lag_36', 'time_of_day_lag_36', 'fire_0_100_lag_36', 'fire_100_200_lag_36', 'fire_200_400_lag_36', 'fire_400_700_lag_36', 'fire_700_1000_lag_36', 'Temperature(C)_lag_43', 'Humidity(%)_lag_43', 'Wind Speed(kmph)_lag_43', 'wind_CALM_lag_43', 'wind_E_lag_43', 'wind_N_lag_43', 'wind_S_lag_43', 'wind_W_lag_43', 'is_rain_lag_43', 'is_holiday_lag_43', 'is_weekend_lag_43', 'day_of_week_lag_43', 'time_of_day_lag_43', 'fire_0_100_lag_43', 'fire_100_200_lag_43', 'fire_200_400_lag_43', 'fire_400_700_lag_43', 'fire_700_1000_lag_43']
# score after dropping columns {'r2_score': 0.7247321278461037, 'mean_squared_error': 136.96502513735655, 'mean_absolute_error': 8.294174959131922}
# ================= optimization 8: optimize for the best rf again =================
# val score before refit {'val_r2_score': 0.7247321278461037, 'val_mean_squared_error': 136.96502513735655, 'val_mean_absolute_error': 8.294174959131922}
# test score before refit {'test_r2_score': 0.7051319719371607, 'test_mean_squared_error': 230.53330262598806, 'test_mean_absolute_error': 9.742391345819932}
# final score for test set {'test_r2_score': 0.7121776178352484, 'test_mean_squared_error': 225.03224087467203, 'test_mean_absolute_error': 9.127618177819155}
# Wall time: 13h 35min 32s

# %%
_, df = plot_model_perf(dataset=data, model=rf_model, split_list=[0.7, 0.3], xlim=[], to_save=False)

# %%
data, model, fire_cols, zone_list, feat_imp, rolling_win = load_model1(city='Chiang Mai', pollutant='PM2.5',split_list=[0.7, 0.3])
# Out:
# rolling_win 1
# data no fire has shape (77747, 14)
# raw model performance {'test_r2_score': 0.7122449924118716, 'test_mean_squared_error': 224.97967147940352, 'test_mean_absolute_error': 9.131018661099539}
# daily avg training error {'avg_trn_r2_score': 0.9492851954528936, 'avg_trn_mean_squared_error': 33.138830210385116, 'avg_trn_mean_absolute_error': 3.566305657569526}
# daily avg test error {'avg_test_r2_score': 0.7854894564576684, 'avg_test_mean_squared_error': 143.92828455217742, 'avg_test_mean_absolute_error': 7.610005328100918}
