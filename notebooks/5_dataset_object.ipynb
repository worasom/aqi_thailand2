# %% [markdown]
# # Imports

# %%
#  Load the "autoreload" extension so that code can change
# %load_ext autoreload
# %reload_ext autoreload
from pathlib import Path

#  always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append('../')
from src.imports import *
from src.data.download_data import *
from src.data.fire_data import *
from src.data.read_data import *
from src.gen_functions import *
from src.features.dataset import Dataset
import seaborn as sns
output_notebook()
# set font size 
plt.rcParams.update({'font.size': 16})
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
b_folder='../data/pm25/'
a4th_folder='../data/air4thai_hourly/'
cm_folder ='../data/cm_proc/'
cdc_folder = '../data/cdc_data/'
aqm_folder = '../data/aqm_hourly2/'
w_folder = '../data/weather_cities/'

# %% [markdown]
# # Dataset Object

# %%
data = Dataset('Chiang Mai')
data.gas_list
# Out:
# ['PM2.5', 'PM10', 'O3', 'CO', 'NO2', 'SO2']

# %%
data.get_th_stations()
# Out:
# (['35t', '36t', 'm9', 'o10'],
#  [{'stationID': '35t',
#    'nameTH': 'ศูนย์ราชการจังหวัดเชียงใหม่ ',
#    'nameEN': 'City Hall, Chiangmai',
#    'areaTH': 'ต.ช้างเผือก อ.เมือง, เชียงใหม่',
#    'areaEN': 'Chang Phueak, Meuang, Chiang Mai',
#    'stationType': 'GROUND',
#    'lat': '18.840633',
#    'long': '98.969661',
#    'LastUpdate': {'date': '2020-06-14',
#     'time': '06:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': '22', 'unit': 'µg/m³'},
#     'O3': {'value': '13', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '3', 'unit': 'ppb'},
#     'SO2': {'value': '0', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': '36t',
#    'nameTH': 'โรงเรียนยุพราชวิทยาลัย ',
#    'nameEN': 'Yupparaj Wittayalai School',
#    'areaTH': 'ต.ศรีภูมิ อ.เมือง, เชียงใหม่',
#    'areaEN': 'Si Phum, Meuang, Chiang Mai',
#    'stationType': 'GROUND',
#    'lat': '18.7909205',
#    'long': '98.9881062',
# ...

# %%
#data.merge_new_old_pollution(['35t', '36t'])
data_list = data.build_pollution()
# Out:
# save file ../data/chiang_mai/35t.csv
# save file ../data/chiang_mai/36t.csv

# %%
len(data_list)
# Out:
# 3

# %%
all_data = pd.DataFrame()
for df in data_list:
    df = df.sort_values(['datetime','PM2.5'])
    df = df.drop_duplicates('datetime')
    all_data = pd.concat([all_data, df], axis=0,ignore_index=True)

# %%
data_list[1].set_index('datetime').dropna(how='all').head()
# Out:
#                      PM2.5  PM10   O3   CO  NO2  SO2
# datetime
# 1995-06-15 00:00:00    NaN  26.0  5.0  0.2  1.0  4.0
# 1995-06-15 01:00:00    NaN  28.0  5.0  0.1  0.0  4.0
# 1995-06-15 02:00:00    NaN  25.0  4.0  0.0  0.0  4.0
# 1995-06-15 03:00:00    NaN  22.0  4.0  0.0  0.0  4.0
# 1995-06-15 04:00:00    NaN  18.0  4.0  0.0  0.0  4.0

# %%
data_list[2].set_index('datetime').dropna(how='all').head()
# Out:
#                      PM2.5   PM10  O3  CO  NO2  SO2
# datetime
# 1995-06-05 08:00:00    NaN  127.0 NaN NaN  NaN  4.0
# 1995-06-05 09:00:00    NaN  197.0 NaN NaN  NaN  4.0
# 1995-06-05 10:00:00    NaN  500.0 NaN NaN  NaN  4.0
# 1995-06-05 11:00:00    NaN  405.0 NaN NaN  NaN  5.0
# 1995-06-05 12:00:00    NaN   77.0 NaN NaN  NaN  3.0

# %%
all_data.groupby('datetime').mean().tail()
# Out:
#                      PM2.5  PM10    O3    CO  NO2  SO2
# datetime
# 2020-06-13 12:00:00   10.0  13.5  28.0  0.37  2.0  2.0
# 2020-06-13 13:00:00    7.0  18.0  32.0  0.31  3.0  1.0
# 2020-06-13 14:00:00    7.5  20.0  32.0  0.30  2.0  1.0
# 2020-06-13 15:00:00   13.0  19.0  28.0  0.30  3.0  1.0
# 2020-06-13 16:00:00   10.0  19.0  24.0  0.32  2.0  1.0

# %%
all_data.groupby('datetime').mean().loc['2020-02-01':]
# Out:
#                      PM2.5  PM10    O3    CO  NO2  SO2
# datetime
# 2020-02-18 01:00:00   72.9   NaN   NaN   NaN  NaN  NaN
# 2020-02-18 02:00:00   71.9   NaN   NaN   NaN  NaN  NaN
# 2020-02-18 03:00:00   74.8   NaN   NaN   NaN  NaN  NaN
# 2020-02-18 04:00:00   80.3   NaN   NaN   NaN  NaN  NaN
# 2020-02-18 05:00:00   75.1   NaN   NaN   NaN  NaN  NaN
# ...                    ...   ...   ...   ...  ...  ...
# 2020-06-13 12:00:00   10.0  13.5  28.0  0.37  2.0  2.0
# 2020-06-13 13:00:00    7.0  18.0  32.0  0.31  3.0  1.0
# 2020-06-13 14:00:00    7.5  20.0  32.0  0.30  2.0  1.0
# 2020-06-13 15:00:00   13.0  19.0  28.0  0.30  3.0  1.0
# 2020-06-13 16:00:00   10.0  19.0  24.0  0.32  2.0  1.0
#
# [2800 rows x 6 columns]

# %%
data_bkk = Dataset('Bangkok')
station_ids, _ = data_bkk.get_th_stations()
station_ids
# Out:
# ['02t',
#  '03t',
#  '05t',
#  '10t',
#  '11t',
#  '12t',
#  '50t',
#  '52t',
#  '53t',
#  '54t',
#  '59t',
#  '61t',
#  'bkp100t',
#  'bkp101t',
#  'bkp102t',
#  'bkp103t',
#  'bkp104t',
#  'bkp105t',
#  'bkp56t',
#  'bkp57t',
#  'bkp58t',
#  'bkp59t',
#  'bkp60t',
#  'bkp61t',
#  'bkp62t',
#  'bkp63t',
#  'bkp64t',
#  'bkp65t',
#  'bkp66t',
#  'bkp67t',
#  'bkp68t',
#  'bkp69t',
#  'bkp70t',
#  'bkp71t',
#  'bkp72t',
#  'bkp73t',
#  'bkp74t',
#  'bkp75t',
#  'bkp76t',
#  'bkp77t',
#  'bkp78t',
#  'bkp79t',
#  'bkp80t',
#  'bkp81t',
#  'bkp82t',
#  'bkp83t',
#  'bkp84t',
#  'bkp85t',
#  'bkp86t',
#  'bkp87t',
#  'bkp88t',
#  'bkp89t',
#  'bkp90t',
#  'bkp91t',
#  'bkp92t',
#  'bkp93t',
#  'bkp94t',
#  'bkp95t',
#  'bkp96t',
#  'bkp97t',
#  'bkp98t',
#  'bkp99t']

# %%
# process bangkok data
station_ids = ['02t',
 '03t',
 '05t',
 '10t',
 '11t',
 '12t',
 '50t',
 '52t',
 '53t',
 '54t',
 '59t',
 '61t']

station_ids.reverse()

for ids in station_ids:
    path = Path(aqm_folder)
    files = [*path.rglob(f'({ids})*.xlsx')]
    try:
        df = read_his_xl(files[0])
    except:
        print('bad file', files[0])
    else:
        df.to_csv('C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/process/'+ids+'.csv')

# %%
all_data[all_data[['PM2.5','PM10']].isna().any(axis=1)]
# Out:
#         PM2.5            datetime  PM10  O3    CO  NO2  SO2
# 0        53.7 2016-03-03 15:00:00   NaN NaN   NaN  NaN  NaN
# 1        53.7 2016-03-03 16:00:00   NaN NaN   NaN  NaN  NaN
# 2        53.7 2016-03-03 17:00:00   NaN NaN   NaN  NaN  NaN
# 3        53.7 2016-03-03 18:00:00   NaN NaN   NaN  NaN  NaN
# 4        33.4 2016-03-03 19:00:00   NaN NaN   NaN  NaN  NaN
# ...       ...                 ...   ...  ..   ...  ...  ...
# 449322    NaN 2020-06-09 18:00:00   NaN NaN  0.32  NaN  1.0
# 449323    NaN 2020-06-09 19:00:00  12.0 NaN  0.40  NaN  1.0
# 449368    NaN 2020-06-11 16:00:00  38.0 NaN  0.30  NaN  1.0
# 449415    NaN 2020-06-13 15:00:00   NaN NaN  0.30  NaN  1.0
# 449416    NaN 2020-06-13 16:00:00   NaN NaN  0.32  NaN  1.0
#
# [325737 rows x 7 columns]

# %%
all_data.dropna(['PM2.5','PM10'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-9751f3dc2a32> in <module>
# ----> 1 all_data.dropna(['PM2.5','PM10'])
#
# c:\users\benny\pyenv\geo\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4732         if isinstance(axis, (tuple, list)):
#    4733             # GH20987
# -> 4734             raise TypeError("supplying multiple axes to axis is no longer supported.")
#    4735
#    4736         axis = self._get_axis_number(axis)
#
# TypeError: supplying multiple axes to axis is no longer supported.
