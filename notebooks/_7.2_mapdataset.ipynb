# %%
#  Load the "autoreload" extension so that code can change
# %load_ext autoreload
# %reload_ext autoreload

#  always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append('../')
from src.features.map_dataset import MapDataset
from src.visualization.mapper import *

from shapely.geometry import Polygon, MultiPoint, Point, MultiPolygon
from scipy.stats import poisson, gamma, nbinom
plt.rcParams.update({'font.size': 16})
matplotlib.rc('font', family='Arial')

# %%
# Build all pollution data
mapper = Mapper()
# this fuction concatenate all station data into a single file and save 
mapper.build_station_info()
# Out:
# number of stations = (2733, 30)
# Countries ['Thailand' nan 'India' 'China' 'Indonesia' 'Malaysia' 'Bangladesh'
#  'Vietnam' 'Myanmar' 'Brunei Darussalam' 'Cambodia' 'Bhutan' 'Laos']

# %%
# Compiling all pollution data 
mapper.build_pollution_all()
# Out:
# no data file for station 87t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station 87t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station 88t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station 88t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station 89t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station 89t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station o22 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station o22 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station 86t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station 86t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station m9 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station m9 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station 40t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station 40t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station m1 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station m1 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station 17t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station 17t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station 84t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station 85t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station 85t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station 82t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station o29 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station o29 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station o25 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station o25 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station 83t in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station o30 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station o30 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# no data file for station o31 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly2/
# no data file for station o31 in folder C:/Users/Benny/Documents/Fern/aqi_thailand2/data/aqm_hourly3/
# 80it [00:07, 10.54it/s]
# pcd data shape (7132951, 8)
# 2it [00:00, 19.58it/s]
# data_columns Index(['datetime', 'PM2.5', 'PM10', 'O3', 'CO', 'NO2', 'SO2', 'stationid'], dtype='object')
# 404it [00:18, 21.69it/s]
# cmu data shape (3059950, 8)
# 75it [00:05, 14.77it/s]
# bkp data shape (1823586, 8)
# 20it [00:04,  4.93it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Bangkok.txt berk122
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Bang_Kruai.txt berk123
# 27it [00:05,  9.20it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Ban_Lam_Luk_Ka.txt berk133
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Ban_Mai.txt berk134
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Ban_Pong.txt berk135
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Ban_Talat_Yai.txt berk136
# 69it [00:07, 17.89it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Chaiyaphum.txt berk292
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Chanthaburi.txt berk316
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Chiang_Mai.txt berk337
# 71it [00:07, 15.91it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Chiang_Rai.txt berk338
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Chon_Buri.txt berk357
# 73it [00:07, 15.71it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Chumphon.txt berk360
# 115it [00:10, 16.52it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Hat_Yai.txt berk659
# 120it [00:10, 17.21it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Hua_Hin.txt berk720
# 134it [00:11, 12.54it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Kalasin.txt berk867
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Kamphaeng_Phet.txt berk874
# 145it [00:12, 15.91it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Kanchanaburi.txt berk884
# 159it [00:13, 17.81it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Khlong_Luang.txt berk940
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Khon_Kaen.txt berk941
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Klaeng.txt berk950
# 170it [00:13, 15.92it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Ko_Samui.txt berk979
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Krathum_Baen.txt berk980
# 187it [00:15, 16.11it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Lampang.txt berk1025
# 197it [00:15, 17.88it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Lop_Buri.txt berk1093
# 203it [00:15, 20.73it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Maha_Sarakham.txt berk1133
# 227it [00:16, 22.61it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Mueang_Nonthaburi.txt berk1225
# 233it [00:17, 17.23it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Nakhon_Pathom.txt berk1255
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Nakhon_Ratchasima.txt berk1256
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Nakhon_Sawan.txt berk1257
# 239it [00:17, 19.35it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Nakhon_Si_Thammarat.txt berk1258
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Nong_Khai.txt berk1323
# 248it [00:18, 18.00it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Pak_Kret.txt berk1344
# 283it [00:20, 15.38it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Phatthaya.txt berk1417
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Phetchabun.txt berk1418
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Phitsanulok.txt berk1419
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Phra_Nakhon_Si_Ayutthaya.txt berk1420
# 285it [00:20, 13.21it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Phra_Phutthabat.txt berk1421
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Phra_Pradaeng.txt berk1422
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Phuket.txt berk1423
# 312it [00:22, 16.88it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Ratchaburi.txt berk1541
# 314it [00:22, 13.85it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Rayong.txt berk1548
# 319it [00:22, 15.20it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Sakon_Nakhon.txt berk1571
# 324it [00:23, 16.28it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Samut_Prakan.txt berk1583
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Samut_Sakhon.txt berk1584
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Saraburi.txt berk1595
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Sattahip.txt berk1602
# 353it [00:24, 19.74it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Si_Racha.txt berk1733
# 359it [00:25, 17.98it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Songkhla.txt berk1741
# 373it [00:25, 21.59it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Suphan_Buri.txt berk1774
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Surat_Thani.txt berk1779
# 416it [00:28, 16.09it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Tha_Maka.txt berk1855
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Trang.txt berk1893
# 424it [00:29, 17.10it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Ubon_Ratchathani.txt berk1909
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Udon_Thani.txt berk1914
# 428it [00:29, 17.43it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Uttaradit.txt berk1930
# 439it [00:30, 18.17it/s]
# C:\Users\Benny\Documents\Fern\aqi_thailand2\data/pm25/Yala.txt berk2058
# 444it [00:30, 14.66it/s]
# Berkeley data shape (10715971, 8)
# 6it [00:39,  6.56s/it]
# US Embassy data shape (244633, 8)

# %% [markdown]
# # MapDataset

# %% [markdown]
# This object allows easily visualization of the data by country.

# %%
mdataset = MapDataset('Thailand')
mdataset.load_()

# %%
# build or load pollution by province and add as .poll attribute
mdataset.load_poll_prov(pollutant='PM2.5')

# %%
# calculate the yearly average only during the winter season
#poll attributes 
poll = mdataset.poll
poll = add_season(poll, start_month='-10-01', end_month='-04-30')
# keep only winter season 
poll = poll[poll['season'] != 'other']
# calculate mean by province 
mean_poll = pd.DataFrame(poll.mean(axis=0))
mean_poll.columns = ['PM2.5']

# %%
mean_poll.sort_values('PM2.5', ascending=False).head()
# Out:
#                         PM2.5
# year              2013.085775
# Buri Ram            56.989312
# Sukhothai           50.842950
# Saraburi            42.873442
# Nong Bua Lam Phu    41.021575

# %%
# create a map of pollution by merging with the shape file 
plot_map = mdataset.prov_map.merge(mean_poll, left_on='province', right_index=True, how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-3231925229e7> in <module>
#       1 # create a map of pollution by merging with the shape file
# ----> 2 plot_map = mdataset.prov_map.merge(mean_poll, left_on='province', right_index=True, how='left')
#
# NameError: name 'mean_poll' is not defined

# %%
_, ax = plt.subplots(1, 1, figsize=(5,10))
plot_map.plot(column='PM2.5',
           ax=ax,legend=True,
           legend_kwds={'label': "PM2.5",
                       'orientation': "horizontal"},  cmap='RdYlGn_r',
             missing_kwds={
         "color": "lightgrey",
         "edgecolor": "red",
            "hatch": "///",
           "label": "Missing values" },)

 
plot_map.boundary.plot(ax=ax, color='black')

ax.set_title("Average PM2.5 in Winter")
plt.savefig(mdataset.report_folder + 'avg_pm25_map.png', dpi=300)

# %% [markdown]
# # Near Income Province

# %%
# select province based on average income level
# load income data by province 
income = pd.read_csv(mdataset.health_folder + 'process/income_98_19.csv')
income = income.drop('thaiprov', axis=1).set_index('province')
income.columns = income.columns.astype(int)
income.head()
# Out:
#                     1998     2000     2002     2004     2006     2007  \
# province
# Whole Kingdom    12492.0  12150.0  13736.0  14963.0  17787.0  18660.0
# Greater Bangkok  24929.0  25242.0  28239.0  28135.0  33088.0  35007.0
# Bangkok          26054.0  26909.0  29589.0  29843.0  36658.0  39020.0
# Samut Prakan     18100.0  15745.0  19680.0  19946.0  20382.0  21302.0
# Nonthaburi       24211.0  24566.0  29119.0  26658.0  31152.0  32743.0
#
#                     2009     2011     2013          2015      2017      2019
# province
# Whole Kingdom    20904.0  23235.9  25194.0  26914.846584  26946.43  26018.42
# Greater Bangkok  37732.0  41630.6  43058.0  41002.390519       NaN       NaN
# Bangkok          42380.0  48951.0  49190.8  45571.700000  45707.31  39459.36
# Samut Prakan     23359.0  23797.9  29575.3  25457.200000  28711.77  24729.42
# Nonthaburi       34626.0  35119.7  30663.6  36884.000000  40860.88  37502.22

# %%
# select province based on average income level
avg_income = income.mean(axis=1).astype(int).sort_values()
cm_income = avg_income.loc['Chiang Mai']
near_income = avg_income[(avg_income < cm_income +1000) & (avg_income > cm_income - 2000) ]
near_income = near_income.drop(['Northeastern Region', 'Northern Region'])

# %%
near_income.index.to_list()
# Out:
# ['Tak',
#  'Narathiwat',
#  'Nan',
#  'Surin',
#  'Sakon Nakhon',
#  'Nong Bua Lam Phu',
#  'Roi Et',
#  'Amnat Charoen',
#  'Chaiyaphum',
#  'Chiang Mai',
#  'Pattani',
#  'Uthai Thani',
#  'Loei',
#  'Phrae',
#  'Phetchabun',
#  'Mukdahan',
#  'Nong Khai',
#  'Yala',
#  'Uttaradit',
#  'Suphan Buri']

# %%
near_income_list = ['Tak',
 'Narathiwat',
 'Nan',
 'Surin',
 'Sakon Nakhon',
 'Nong Bua Lam Phu',
 'Roi Et',
 'Amnat Charoen',
 'Chaiyaphum',
 'Chiang Mai',
 'Pattani',
 'Uthai Thani',
 'Loei',
 'Phrae',
 'Phetchabun',
 'Mukdahan',
 'Nong Khai',
 'Yala',
 'Uttaradit',
 'Suphan Buri']

# %%
provinces = mdataset.prov_map[['region', 'province']]

region_list = ['Northern Region', 'Northeastern Region', 'Central Region','Greater Bangkok','Southern Region']

# %%
fig, ax = plt.subplots(1,1, figsize=(14, 7))

province_list = []
for region in region_list:
    # select province
    prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
    df = near_income[near_income.index.isin(prov_in_region)]
    province_list += df.index.to_list()
    if len(df) > 0:
        ax.bar(df.index, df, label=region, edgecolor='black')
 
df = near_income.loc[['Chiang Mai']]
ax.bar(df.index, df, color='magenta', label='Chiang Mai', edgecolor='black')

ax.legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

#ax.set_xlabel('province')
ax.set_title('income per month per household(Baht)')
plt.tight_layout()
plt.savefig(mdataset.report_folder + 'income_bar.png', dpi=300)

# %% [markdown]
# plotting pollution bar

# %%
# use province_list to keep the bar plot in the same order
pm25_short = pd.DataFrame(index=province_list, columns =['PM2.5'])
pm25_short = pm25_short.merge(mean_poll, right_index=True, left_index=True, how='left', suffixes=('_x', ''))
pm25_short = pm25_short[['PM2.5']]

# %%
fig, ax = plt.subplots(1,1, figsize=(14, 7))
#ax.bar(pm10_short_list['province'], pm10_short_list['avgPM10'])


for region in region_list:
    # select province
    prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
    # select only province near Chiang Mai
    # use province_list to keep the bar plot in the same order

    prov_in_region = [s for s in province_list if s in prov_in_region]
    df = pm25_short.loc[prov_in_region]
     
    if len(df) > 0:
        ax.bar(df.index, df['PM2.5'], label=region, edgecolor='black')
# highlight Chiang Mai
df = pm25_short.loc[['Chiang Mai']]
ax.bar(df.index, df['PM2.5'], color='magenta', label='Chiang Mai', edgecolor='black')

ax.set_xlabel('province')
ax.set_ylabel('$\mu g/m^3$')
ax.legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);
ax.set_title('average PM2.5')
plt.tight_layout()
plt.savefig(mdataset.report_folder + 'avg_pm25_bar.png', dpi=300)

# %% [markdown]
# # Correction Factor

# %% [markdown]
# reference : https://github.com/cs109/2015lab9

# %%
population = pd.read_csv(mdataset.health_folder  + 'process/pop_prov.csv')  
population = population.drop(['province_th', 'gender_th'], axis=1)

# %%
dead_cause = pd.read_csv(mdataset.health_folder + 'process/lung_dead_prov.csv').set_index('province')
dead_male = dead_cause[dead_cause['gender']=='Male']
dead_female = dead_cause[dead_cause['gender']=='Female']

dead_male = dead_male.drop('gender', axis=1)
dead_female = dead_female.drop('gender', axis=1)

mean_male_dead = pd.DataFrame(dead_male.mean(axis=1))
mean_male_dead.columns = ['lung_dead']

mean_female_dead = pd.DataFrame(dead_female.mean(axis=1))
mean_female_dead.columns = ['lung_dead']

# %%
# separate male and femal population
pop_male = population[population['gender']=='Male'].set_index('province')
pop_female = population[population['gender']=='Female'].set_index('province')
pop_male = pop_male.drop('gender', axis=1)
pop_female = pop_female.drop('gender', axis=1)

# %%
dead_female.head()
# Out:
#                     2007       2008       2009       2010       2011  \
# province
# Amnat Charoen   9.781067  10.860534  11.375455  15.115444  18.850852
# Ang Thong      20.357615  16.936292  25.708506  18.243983  35.828725
# Bangkok        33.001540  33.527157  31.751714  35.412813  35.120518
# Bueng Kan            NaN        NaN        NaN        NaN        NaN
# Buri Ram       10.657849  11.809271  11.122694  14.944544  14.752801
#
#                     2012       2013       2014  gender
# province
# Amnat Charoen  15.581848  25.157771  35.217280  Female
# Ang Thong      29.791325  37.265902  39.340437  Female
# Bangkok        33.262383  41.010114  47.026634  Female
# Bueng Kan      29.193206  15.568443  14.011354  Female
# Buri Ram       14.049285  18.180501  23.676580  Female

# %%
# create a map of pollution by merging with the shape file 
plot_map = mdataset.prov_map.merge(mean_female_dead, left_on='province', right_index=True, how='left')

# %%
_, ax = plt.subplots(1, 1, figsize=(5,10))
plot_map.plot(column='lung_dead',
           ax=ax,legend=True,
           legend_kwds={'label': "lung_dead",
                       'orientation': "horizontal"},  cmap='RdYlGn_r',
             missing_kwds={
         "color": "lightgrey",
         "edgecolor": "red",
            "hatch": "///",
           "label": "Missing values" },)

 
plot_map.boundary.plot(ax=ax, color='black')

ax.set_title("Female Dead Lung Disease")
#plt.savefig(mdataset.report_folder + 'avg_pm25_map.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Female Dead Lung Disease')

# %%
dead_male = pd.DataFrame(dead_male.mean(axis=1))
dead_male.columns = ['lung_dead']
# create a map of pollution by merging with the shape file 
plot_map = mdataset.prov_map.merge(dead_male, left_on='province', right_index=True, how='left')

_, ax = plt.subplots(1, 1, figsize=(5,10))
plot_map.plot(column='lung_dead',
           ax=ax,legend=True,
           legend_kwds={'label': "lung_dead",
                       'orientation': "horizontal"},  cmap='RdYlGn_r',
             missing_kwds={
         "color": "lightgrey",
         "edgecolor": "red",
            "hatch": "///",
           "label": "Missing values" },)

 
plot_map.boundary.plot(ax=ax, color='black')

ax.set_title("Male Dead Lung Disease")
# Out:
# Text(0.5, 1.0, 'Male Dead Lung Disease')

# %%
# use province_list to keep the bar plot in the same order
dead_male_short = pd.DataFrame(index=province_list, columns =['lung'])
dead_male_short = dead_male_short.merge(mean_male_dead, right_index=True, left_index=True, how='left', suffixes=('_x', ''))
dead_male_short = dead_male_short[['lung_dead']]

# use province_list to keep the bar plot in the same order
dead_female_short = pd.DataFrame(index=province_list, columns =['lung'])
dead_female_short = dead_female_short.merge(mean_female_dead, right_index=True, left_index=True, how='left', suffixes=('_x', ''))
dead_female_short = dead_female_short[['lung_dead']]

# %%
fig, ax = plt.subplots(2,1, figsize=(14, 9), sharex=True)
#ax.bar(pm10_short_list['province'], pm10_short_list['avgPM10'])


for region in region_list:
    # select province
    prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
    # select only province near Chiang Mai
    # use province_list to keep the bar plot in the same order

    prov_in_region = [s for s in province_list if s in prov_in_region]
    df = dead_male_short.loc[prov_in_region]
     
    if len(df) > 0:
        ax[0].bar(df.index, df['lung_dead'], label=region, edgecolor='black')
        
         
    df = dead_female_short.loc[prov_in_region]
     
    if len(df) > 0:
        ax[1].bar(df.index, df['lung_dead'], label=region, edgecolor='black')
        
        
# highlight Chiang Mai
df = dead_male_short.loc[['Chiang Mai']]
ax[0].bar(df.index, df['lung_dead'], color='magenta', label='Chiang Mai', edgecolor='black')

df = dead_female_short.loc[['Chiang Mai']]
ax[1].bar(df.index, df['lung_dead'], color='magenta', label='Chiang Mai', edgecolor='black')

 
ax[0].legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()
ax[0].set_title('Male Lung Dead')
ax[1].set_title('Female Lung Dead')

ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=90);



plt.tight_layout()
#plt.savefig(mdataset.report_folder + 'avg_pm25_bar.png', dpi=300)

# %%
# use province_list to keep the bar plot in the same order
pop_male_short = pd.DataFrame(index=province_list, columns =['lung'])
pop_male_short = pop_male_short.merge(pop_male, right_index=True, left_index=True, how='left', suffixes=('_x', ''))
pop_male_short = pop_male_short[['2019']]
pop_male_short.columns = ['pop']

# %%
# use province_list to keep the bar plot in the same order
pop_female_short = pd.DataFrame(index=province_list, columns =['lung'])
pop_female_short = pop_female_short.merge(pop_female, right_index=True, left_index=True, how='left', suffixes=('_x', ''))
pop_female_short = pop_female_short[['2019']]
pop_female_short.columns = ['pop']

# %%
fig, ax = plt.subplots(2,1, figsize=(14, 9), sharex=True)

#ax.bar(pm10_short_list['province'], pm10_short_list['avgPM10'])


for region in region_list:
    # select province
    prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
    # select only province near Chiang Mai
    # use province_list to keep the bar plot in the same order

    prov_in_region = [s for s in province_list if s in prov_in_region]
    df = pop_male_short.loc[prov_in_region]
     
    if len(df) > 0:
        ax[0].bar(df.index, df['pop'], label=region, edgecolor='black')
        
    df = pop_female_short.loc[prov_in_region]
     
    if len(df) > 0:
        ax[1].bar(df.index, df['pop'], label=region, edgecolor='black')
        
        
# highlight Chiang Mai
df = pop_male_short.loc[['Chiang Mai']]
ax[0].bar(df.index, df['pop'], color='magenta', label='Chiang Mai', edgecolor='black')

df = pop_female_short.loc[['Chiang Mai']]
ax[1].bar(df.index, df['pop'], color='magenta', label='Chiang Mai', edgecolor='black')



ax[0].legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()
ax[0].set_title('Male Population')
ax[1].set_title('Female Population')

ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=90);
plt.tight_layout()
#plt.savefig(mdataset.report_folder + 'avg_pm25_bar.png', dpi=300)

# %%
dead_cause = pd.read_csv(mdataset.health_folder + 'process/lung_dead_prov.csv').set_index('province')
dead_male = dead_cause[dead_cause['gender']=='Male']
dead_female = dead_cause[dead_cause['gender']=='Female']

dead_male = dead_male.drop('gender', axis=1)
dead_female = dead_female.drop('gender', axis=1)

# %%
# separate male and femal population
pop_male = population[population['gender']=='Male'].set_index('province')
pop_female = population[population['gender']=='Female'].set_index('province')
pop_male = pop_male.drop('gender', axis=1)
pop_female = pop_female.drop('gender', axis=1)

# %%
dead_male = dead_male.melt(ignore_index=False,var_name='year', value_name='dead')
dead_male = dead_male.dropna()
dead_male = dead_male.reset_index()

# %%
dead_female = dead_female.melt(ignore_index=False,var_name='year', value_name='dead')
dead_female = dead_female.dropna()
dead_female = dead_female.reset_index()

# %%
pop_male = pop_male.melt(ignore_index=False,var_name='year', value_name='pop')
pop_male = pop_male.dropna()
pop_male = pop_male.reset_index()

# %%
pop_female = pop_female.melt(ignore_index=False,var_name='year', value_name='pop')
pop_female = pop_female.dropna()
pop_female = pop_female.reset_index()

# %%
dead_male_rate = dead_male.merge(pop_male, on=['province', 'year'], how='left')
# calcualte the rate 
dead_male_rate['rate'] = dead_male_rate['dead']/100000
# add dead count
dead_male_rate['count'] = dead_male_rate['rate']*dead_male_rate['pop']

# %%
dead_female_rate = dead_female.merge(pop_female, on=['province', 'year'], how='left')
# calcualte the rate 
dead_female_rate['rate'] = dead_female_rate['dead']/100000
# add dead count
dead_female_rate['count'] = dead_female_rate['rate']*dead_female_rate['pop']

# %%
plt.scatter(dead_male_rate['pop'], dead_male_rate['dead'], alpha=0.5)
plt.scatter(dead_female_rate['pop'], dead_male_rate['dead'], alpha=0.5)

plt.xlabel('population')
plt.ylabel('lung_mortality')

plt.xscale('log')

# %% [markdown]
# I don't see a strong population depedence so correction factor is probably not needed.

# %%
dead_male_rate[dead_male_rate['rate'] > 0.0008]
# Out:
#             province  year       dead       pop      rate       count
# 516         Saraburi  2013  80.486525  311374.0  0.000805  250.614112
# 519        Sing Buri  2013  96.490883  101384.0  0.000965   97.826316
# 559     Nakhon Nayok  2014  86.498388  127503.0  0.000865  110.288040
# 592  Samut Songkhram  2014  94.313335   93316.0  0.000943   88.009431
# 593         Saraburi  2014  92.530337  313285.0  0.000925  289.883665
# 596        Sing Buri  2014  90.834592  101181.0  0.000908   91.907349

# %%
dead_male_rate[dead_male_rate['province'].str.contains('Samut Sakhon')]
# Out:
#          province  year       dead       pop      rate       count  \
# 56   Samut Sakhon  2007  45.037089  228254.0  0.000450  102.798958
# 132  Samut Sakhon  2008  44.776963  231803.0  0.000448  103.794343
# 208  Samut Sakhon  2009  45.871756  234714.0  0.000459  107.667434
# 284  Samut Sakhon  2010  54.166138  237906.0  0.000542  128.864492
# 360  Samut Sakhon  2011  48.007681  241183.0  0.000480  115.786366
# 437  Samut Sakhon  2012  49.279897  245830.0  0.000493  121.144772
# 514  Samut Sakhon  2013  55.947997  251059.0  0.000559  140.462481
# 591  Samut Sakhon  2014  51.580895  256880.0  0.000516  132.501004
#
#      adjusted_rate
# 56        0.000449
# 132       0.000446
# 208       0.000457
# 284       0.000539
# 360       0.000478
# 437       0.000491
# 514       0.000557
# 591       0.000513

# %% [markdown]
# # Adjust

# %%
# prior of the rate 
prior = lambda theta, a,b: gamma.pdf(theta, a, 0., 1./b)
# likelyhood
like1 = lambda yj, thetaj, nj: poisson.pmf(yj, 1.*thetaj*nj)
posterior = lambda thetaj,a,b,yj, nj: gamma.pdf(thetaj, a+yj, 0., 1./(b+1.*nj))

# %%
meanpost = lambda yj,nj,a,b: (a+yj)/(b + 1*nj)
postpred = lambda y,a,b,nj: nbinom.pmf(y, a, b/(1.*nj))
meanpostpred=lambda nj, a,b: 1.*nj*(a/b)
varpostpred=lambda nj,a,b: meanpostpred(nj,a,b)*(1. +  meanpostpred(nj,a,b)/a)

# %%
meany=dead_male_rate['count'].mean()
vary=dead_male_rate['count'].var()
meanpop=dead_male_rate['pop'].mean()
meanpopsquared=np.mean(dead_male_rate['pop']**2)

# %%
abyb=meany/(1.*meanpop)
est_a = (1.*meanpopsquared*abyb*abyb)/(vary - meany) 
est_b = est_a/abyb

print(est_a, est_b)
# Out:
# 1.0477423802222077 3220.8242337856414

# %%
abyb
# Out:
# 0.0003253025636207192

# %%
plt.scatter(dead_male_rate['pop'], dead_male_rate['rate'], alpha=0.5, color='blue')


# adjust the rate of the old plot
vals=zip(dead_male_rate['count'], dead_male_rate['pop'])
meanposts=[meanpost(yjay, njay, est_a, est_b) for (yjay, njay) in vals]
plt.scatter(dead_male_rate['pop'], np.array(meanposts), color="green", alpha=0.5)
 
plt.xscale('log')

# %% [markdown]
# # Smoking Rate

# %%
smoke = pd.read_csv(mdataset.health_folder  + 'process/smoke.csv')

# remove strange year 
smoke = smoke[~smoke['year'].isin([2001, 2014])]
smoke = smoke.set_index(['region', 'gender', 'year'])

# calculate the rate 
smoke['total'] = smoke.sum(axis=1)
smoke['freq_rate'] = smoke['frequent']/smoke['total']

smoke.head()
# Out:
#                                      frequent         never    occasional  \
# region              gender year
# Central Region      Female 2004  4.140495e+06  2.405032e+07  8.416739e+05
#                     Male   2004  1.860313e+06  2.980548e+06  3.820262e+05
# Greater Bangkok     Female 2004  8.991480e+05  8.884521e+06  1.594606e+05
#                     Male   2004  8.176897e+05  1.950692e+06  1.476288e+05
# Northeastern Region Female 2004  7.080440e+06  3.089837e+07  1.039622e+06
#
#                                       unknown  former frequent  \
# region              gender year
# Central Region      Female 2004  2.408923e+06     7.628249e+05
#                     Male   2004  0.000000e+00     3.528641e+05
# Greater Bangkok     Female 2004  0.000000e+00     2.081420e+05
#                     Male   2004  0.000000e+00     1.695960e+05
# Northeastern Region Female 2004  4.236681e+06     1.466386e+06
#
#                                  former occasional         total  freq_rate
# region              gender year
# Central Region      Female 2004        366651.9865  3.257089e+07   0.127123
#                     Male   2004        158922.0095  5.734674e+06   0.324397
# Greater Bangkok     Female 2004         72811.8139  1.022408e+07   0.087944
#                     Male   2004         59242.9813  3.144850e+06   0.260009
# Northeastern Region Female 2004        654328.3634  4.537583e+07   0.156040

# %%
smoke = smoke.reset_index()

# %%
_, ax = plt.subplots(2,1, figsize=(17,10))
temp = smoke[smoke['gender'] == 'Male']
sns.lineplot(data=temp, x='year', y='freq_rate', hue='region', marker='o', ax=ax[0], ci=None)


temp = smoke[smoke['gender'] == 'Female']
sns.lineplot(data=temp, x='year', y='freq_rate', hue='region', marker='o', ax=ax[1], ci=None)

title_list = ['Smoking Rate[Male]', 'Smoking Rate[Female]']
for a, t in zip(ax, title_list) :
    a.legend(bbox_to_anchor=(1.05,1.05))
    a.set_title(t)
    a.set_ylabel('fraction')
    
plt.tight_layout()
plt.savefig(mdataset.report_folder+'smoke_year.png', dpi=300)

# %%
smoke[smoke['year']==2015]
# Out:
#                  region  gender  year      frequent         never  \
# 40       Central Region    Male  2015  2.336758e+06  3.704222e+06
# 41       Central Region  FeMale  2015  9.602598e+04  8.040108e+06
# 42      Greater Bangkok    Male  2015  8.919991e+05  1.955539e+06
# 43      Greater Bangkok  FeMale  2015  4.041865e+04  3.739877e+06
# 44  Northeastern Region    Male  2015  2.878510e+06  2.366721e+06
# 45  Northeastern Region  FeMale  2015  5.233274e+04  7.534318e+06
# 46      Northern Region    Male  2015  1.423963e+06  1.934414e+06
# 47      Northern Region  FeMale  2015  1.270283e+05  4.583260e+06
# 48      Southern Region    Male  2015  1.516676e+06  1.222867e+06
# 49      Southern Region  FeMale  2015  3.745877e+04  3.585283e+06
#
#      occasional     unknown  former frequent  former occasional         total  \
# 40  476429.6740  96902.7885      616339.6889        622453.2304  7.853105e+06
# 41   41166.1280  42902.1536       41586.5199         54444.5180  8.316233e+06
# 42  177747.2772  38861.2314      260938.4006        268850.5359  3.593936e+06
# 43   57360.7673   7543.0941       15906.6824         20308.1158  3.881414e+06
# 44  343737.4778  40537.6522      938413.3564        574529.5111  7.142449e+06
# 45   15640.2525   6043.6992       60268.3094         37401.5933  7.706005e+06
# 46  181323.3478  26724.6178      659159.2689        349601.0157  4.575185e+06
# 47   26896.1184   5983.5629      105522.6676         54230.3613  4.902921e+06
# 48  217999.0255  29549.7067      322135.7550        197198.5330  3.506426e+06
# 49    7566.0831  10291.3994       24327.8462         15617.1982  3.680544e+06
#
#     freq_rate
# 40   0.297558
# 41   0.011547
# 42   0.248196
# 43   0.010413
# 44   0.403014
# 45   0.006791
# 46   0.311236
# 47   0.025909
# 48   0.432542
# 49   0.010178

# %% [markdown]
# # Cause of Dead

# %%
pop = population.melt(id_vars=['province', 'gender'], var_name='year', value_name='pop')
pop['year'] = pop['year'].astype(int)

# %%
dead = pd.read_csv(mdataset.health_folder + 'process/cause_of_dead.csv').dropna()
# add population 
dead = dead.merge(pop, on=['province', 'gender', 'year'], how='left')

# %%
lung_list = ['วัณโรคทางเดินหายใจ',
 'โรคของทางเดินหายใจส่วนล่างเรื้อรัง',
 'โรคของระบบทางเดินหายใจอื่น ๆ',
 'โรคของทางเดินหายใจส่วนล่างเฉียบพลันอื่น ๆ',
 'โรคมะเร็งหลอดลมและปอด' ]

label = ['TB', 'chronic lower res', 'other res', 'sudden res', 'cancer']

lung_dead = dead[dead['cause_of_dead'].isin(lung_list)] 

# calculate the rate 
lung_dead['rate'] = lung_dead['number']/lung_dead['pop']

lung_dead.head()
# Out:
#     year  gender                       cause_of_dead  number  admin1Name_th  \
# 1   2009    Male                  วัณโรคทางเดินหายใจ     261  กรุงเทพมหานคร
# 18  2009    Male               โรคมะเร็งหลอดลมและปอด     766  กรุงเทพมหานคร
# 44  2009    Male  โรคของทางเดินหายใจส่วนล่างเรื้อรัง     222  กรุงเทพมหานคร
# 45  2009    Male        โรคของระบบทางเดินหายใจอื่น ๆ     342  กรุงเทพมหานคร
# 75  2009  Female                  วัณโรคทางเดินหายใจ      71  กรุงเทพมหานคร
#
#    province        pop      rate
# 1   Bangkok  2713535.0  0.000096
# 18  Bangkok  2713535.0  0.000282
# 44  Bangkok  2713535.0  0.000082
# 45  Bangkok  2713535.0  0.000126
# 75  Bangkok  2989060.0  0.000024

# %%
lung_dead_avg = lung_dead.groupby(['province', 'gender', 'cause_of_dead']).mean()[['rate']].reset_index()

# %%
# add whole kingdom stat 
lung_dead_whole = lung_dead.groupby(['year', 'gender', 'cause_of_dead'], as_index=False).sum()
lung_dead_whole['rate'] = lung_dead_whole['number']/lung_dead_whole['pop']

# %%
lung_dead_whole_avg = lung_dead_whole.groupby(['gender', 'cause_of_dead'], as_index=False).mean()

# %%
for dis in lung_list[:-1]:
    temp = dead[dead['cause_of_dead']== dis]
    temp = temp[temp['gender']=='Female']
    temp = temp.merge(pop, on=['province', 'gender', 'year'], how='left')

    # calculate the rate 
    temp['rate'] = temp['number']/temp['pop']
    sns.regplot(data=temp, x='year', y='rate')

plt.legend(label, bbox_to_anchor=(1.05, 1.05))

# %%
near_income_list = ['Tak',
 'Narathiwat',
 'Nan',
 'Surin',
 'Sakon Nakhon',
 'Nong Bua Lam Phu',
 'Roi Et',
 'Amnat Charoen',
 'Chaiyaphum',
 'Chiang Mai',
 'Pattani',
 'Uthai Thani',
 'Loei',
 'Phrae',
 'Phetchabun',
 'Mukdahan',
 'Nong Khai',
 'Yala',
 'Uttaradit',
 'Suphan Buri']

# %%
provinces = mdataset.prov_map[['region', 'province']]

region_list = ['Northern Region', 'Northeastern Region', 'Central Region','Greater Bangkok','Southern Region']

# %%
fig, ax = plt.subplots(len(label),1, figsize=(14, 4*len(label)), sharex=True)
 
gender = 'Male'
for a, l, d in zip(ax, label, lung_list):
    temp = lung_dead_avg[(lung_dead_avg['gender']==gender) & (lung_dead_avg['cause_of_dead']==d)].set_index('province')
    for region in region_list:
        # select province
        prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
        # select only province near Chiang Mai
        # use province_list to keep the bar plot in the same order

        prov_in_region = [s for s in province_list if s in prov_in_region]
        df = pd.DataFrame(index=prov_in_region)
        df = df.merge(temp, right_index=True, left_index=True, how='left')
        df['rate'] = df['rate'].fillna(0)
        df = df.loc[prov_in_region]
     
        if len(df) > 0:
            a.bar(df.index, df['rate'], label=region, edgecolor='black')
        
        a.set_title(l)
        a.set_ylabel('number/population')
        
    temp = lung_dead_whole_avg[(lung_dead_whole_avg['gender']==gender) & (lung_dead_whole_avg['cause_of_dead']==d)]
    a.bar(['National'], temp['rate'], label='National', edgecolor='black')
    
ax[0].legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()

ax[-1].set_xticklabels(ax[-1].get_xticklabels(), rotation=90);

# %%
fig, ax = plt.subplots(len(label),1, figsize=(14, 4*len(label)), sharex=True)
 
gender = 'Female'
for a, l, d in zip(ax, label, lung_list):
    temp = lung_dead_avg[(lung_dead_avg['gender']==gender) & (lung_dead_avg['cause_of_dead']==d)].set_index('province')
    for region in region_list:
        # select province
        prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
        # select only province near Chiang Mai
        # use province_list to keep the bar plot in the same order

        prov_in_region = [s for s in province_list if s in prov_in_region]
        df = pd.DataFrame(index=prov_in_region)
        df = df.merge(temp, right_index=True, left_index=True, how='left')
        df['rate'] = df['rate'].fillna(0)
        df = df.loc[prov_in_region]
     
        if len(df) > 0:
            a.bar(df.index, df['rate'], label=region, edgecolor='black')
            
        
        a.set_title(l)
        a.set_ylabel('number/population')
        
    temp = lung_dead_whole_avg[(lung_dead_whole_avg['gender']==gender) & (lung_dead_whole_avg['cause_of_dead']==d)]
    a.bar(['National'], temp['rate'], label='National', edgecolor='black')
    
ax[0].legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()

ax[-1].set_xticklabels(ax[-1].get_xticklabels(), rotation=90);

# %% [markdown]
# # Search for cause of dead

# %%
near_income_list = ['Tak',
 'Narathiwat',
 'Nan',
 'Surin',
 'Sakon Nakhon',
 'Nong Bua Lam Phu',
 'Roi Et',
 'Amnat Charoen',
 'Chaiyaphum',
 'Chiang Mai',
 'Pattani',
 'Uthai Thani',
 'Loei',
 'Phrae',
 'Phetchabun',
 'Mukdahan',
 'Nong Khai',
 'Yala',
 'Uttaradit',
 'Suphan Buri']

# %%
population = pd.read_csv(mdataset.health_folder  + 'process/pop_prov.csv')  
population = population.drop(['province_th', 'gender_th'], axis=1)

pop = population.melt(id_vars=['province', 'gender'], var_name='year', value_name='pop')
pop['year'] = pop['year'].astype(int)
dead = pd.read_csv(mdataset.health_folder + 'process/cause_of_dead.csv').dropna()
# add population 
dead = dead.merge(pop, on=['province', 'gender', 'year'], how='left')

# add birth rate

birth_rate = pd.read_csv(mdataset.health_folder  + 'process/birth_prov.csv')
birth_rate = birth_rate.rename(columns={'number':'birth_number'})

dead = dead.merge(birth_rate, on=['province',  'year'], how='left')

# load provinces & region information 
provinces = mdataset.prov_map[['region', 'province']]

region_list = ['Northern Region', 'Northeastern Region', 'Central Region', 'Greater Bangkok', 'Southern Region']

# add region
dead = dead.merge(provinces, on='province', how='left')

# %%
dead.head()
# Out:
#    year gender                                      cause_of_dead  number  \
# 0  2009   Male  อาการท้องร่วง กระเพาะและลำไส้อักเสบจากการติดเชื้อ      22
# 1  2009   Male                                 วัณโรคทางเดินหายใจ     261
# 2  2009   Male                                       วัณโรคอื่น ๆ      20
# 3  2009   Male                                           บาดทะยัก       2
# 4  2009   Male                                       โลหิตเป็นพิษ    1495
#
#    admin1Name_th province        pop           region
# 0  กรุงเทพมหานคร  Bangkok  2713535.0  Greater Bangkok
# 1  กรุงเทพมหานคร  Bangkok  2713535.0  Greater Bangkok
# 2  กรุงเทพมหานคร  Bangkok  2713535.0  Greater Bangkok
# 3  กรุงเทพมหานคร  Bangkok  2713535.0  Greater Bangkok
# 4  กรุงเทพมหานคร  Bangkok  2713535.0  Greater Bangkok

# %%
cause = dead['cause_of_dead'].drop_duplicates().reset_index(drop=True)
birth_defect = cause[cause.str.contains('ครรภ์') | cause.str.contains('กำเนิด')| cause.str.contains('แรกเกิด')| cause.str.contains('แท้ง')| cause.str.contains('ทารก')].to_list()
birth_defect
# Out:
# ['ทารกในครรภ์แรกเกิดที่ได้รับผลจากปัจจัยทางมารดาและโรคแทรกในระยะตั้งครรภ์ เจ็บครรภ์และคลอด',
#  'ความผิดปกติเกี่ยวกับการตั้งครรภ์และการเจริญเติบโตของทารกในครรภ์',
#  'การขาดอ็อกซิเจนขณะอยู่ในโพรงมดลูกและภาวะแอสฟิกเซียเมื่อแรกเกิด',
#  'ปอดบวมแต่กำเนิด',
#  'ภาวะการหายใจอื่น ๆ ในทารกแรกเกิด',
#  'การติดเชื้อและมีพิษของแบคทีเรียในกระแสเลือดในทารกแรกเกิด',
#  'ภาวะปริกำเนิดอื่น ๆ',
#  'ศีรษะรูปบาตรและกระดูกสันหลังแยกแต่กำเนิด',
#  'ความผิดปกติแต่กำเนิดของระบบประสาทอื่น ๆ',
#  'ความผิดปกติของหัวใจแต่กำเนิด',
#  'ความผิดปกติอื่น ๆ แต่กำเนิด',
#  'การแท้ง',
#  'โรคแทรกของการเจ็บครรภ์และการคลอด',
#  'ภาวะหายใจลำบากของทารกแรกเกิด',
#  'เลือดออกและความผิดปกติเกี่ยวกับเลือดของทารกในครรภ์และแรกเกิด',
#  'ความผิดปกติแต่กำเนิดของระบบไหลเวียนโลหิตอื่น ๆ',
#  'การตั้งครรภ์ การคลอดและระยะหลังคลอดอื่น ๆ',
#  'ความผิดปกติอื่นที่ส่วนใหญ่เป็นผลจากการตั้งครรภ์',
#  'สะดืออักเสบในทารกแรกเกิดชนิดมีหรือไม่มีเลือดออก']

# %% [markdown]
# ## Compare Regions

# %%
region_to_compare = ['Northern Region', 'Northeastern Region', 'Central Region', 'Southern Region']

# pick only three regions
dead_3reg = dead[dead['region'].isin(region_to_compare)]

# calculate the rate by cause_of_dead by year, gender, region
dead_3reg = dead_3reg.groupby(['year', 'gender', 'cause_of_dead', 'region' ]).sum()

# calcule rate
dead_3reg['rate'] = dead_3reg['number']/dead_3reg['pop']

dead_3reg = dead_3reg.reset_index()
dead_3reg.head()
# Out:
#    year  gender                                      cause_of_dead  \
# 0  2009  Female                กลุ่มอาการและความผิดปกติของโครโมโซม
# 1  2009  Female                กลุ่มอาการและความผิดปกติของโครโมโซม
# 2  2009  Female                กลุ่มอาการและความผิดปกติของโครโมโซม
# 3  2009  Female                กลุ่มอาการและความผิดปกติของโครโมโซม
# 4  2009  Female  การขาดอ็อกซิเจนขณะอยู่ในโพรงมดลูกและภาวะแอสฟิก...
#
#                 region  number        pop      rate
# 0       Central Region      16  3169695.0  0.000005
# 1  Northeastern Region       7  3242314.0  0.000002
# 2      Northern Region       7  1691894.0  0.000004
# 3      Southern Region       7  1732192.0  0.000004
# 4       Central Region      24  4925269.0  0.000005

# %%
def cal_1z_test(row1, row2):
    """Compare two rate and return the z-score
    
    z = (p1 - p2)/sqrt(p(1-p)(1/n1 + 1/n2))
    
    """
    # calculate 1 sample z-test 
    p1 = row1['rate']
    n1 = row1['pop']
    p2 = row2['rate']
    n2 = row2['pop']

    p = (p1*n1 + p2*n2)/(n1+n2)

    z = (p1-p2)/np.sqrt(p*(1 - p) * (1/n1 + 1/n2))

    return z

# %%
significant_df1 = []
for year, gender, cause in zip(dead_3reg['year'], dead_3reg['gender'], dead_3reg['cause_of_dead']):
    temp = dead_3reg[(dead_3reg['year']==year) & (dead_3reg['gender']==gender) & (dead_3reg['cause_of_dead']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        #if (z1 >= 1.96) & (z2>= 1.96) & (z3>= 1.96):
        significant_df1.append([year, gender, cause, z1, z2, z3, row_n['rate']/row_s['rate'], row_ne['rate']/row_s['rate'], row_c['rate']/row_s['rate']] )
        
significant_df1 = pd.DataFrame(significant_df1, columns=['year', 'gender', 'cause', 'z_NE', 'z_N', 'z_C', 'ratio_north_south', 'ratio_northeast_south',  'ratio_central_south'])

# z2 should be more than z1
#significant_df['north_higher_than_ne_c'] =  (significant_df['z_N'] > significant_df['z_NE']) & (significant_df['z_N'] > significant_df['z_C']) 

#significant_df = significant_df[significant_df['north_higher_than_ne_c'] == True]

significant_df1 = significant_df1.drop_duplicates()

# %%
remove_list =  [ 'การติดเชื้อเอชไอวี/เอดส์', 'การพลัดตก หกล้ม', 'ภาวะทุพโภชนาการ',  'ฆ่าตัวตาย', 'โลหิตจาง', 'อุบัติเหตุจากการขนส่งทางบก',
       'อาการท้องร่วง กระเพาะและลำไส้อักเสบจากการติดเชื้อ', 'แผลกระเพาะอาหารและดูโอเดนั่ม', 'อาการแสดงที่พบจากการตรวจทางห้องปฏิบัติการ',
       'โรคของตับ',  
       'โรคติดเชื้อและปรสิตอื่น ๆ', 'โรคมะเร็งกระเพาะอาหาร',
       'โรคมะเร็งตับ',  'โรคระบบย่อยอาหารอื่น ๆ',
       'ความผิดปกติทางจิตเนื่องจากการใช้วัตถุออกฤทธิ์ต่อจิตประสาท',
       'สาเหตุจากภายนอกอื่น ๆ', 'อุบัติเหตุการตกน้ำจมน้ำ', 'โรคต่อมไร้ท่อ โภชนาการและเมตะบอสลิซึมอื่น ๆ']

significant_df1 = significant_df1[~significant_df1['cause'].isin(remove_list)]

# %%
significant_df.shape
# Out:
# (7, 9)

# %%
significant_df['cause'].unique()
# Out:
# array(['อาการแสดงที่พบจากการตรวจทางห้องปฏิบัติการ',
#        'โรคมะเร็งหลอดลมและปอด', 'เยื้อหุ้มสมองอักเสบ',
#        'โรคของผิวหนังและเนื้อเยื่อใต้ผิวหนัง',
#        'โรคของระบบสืบพันธุ์และทางเดินปัสสาวะอื่น ๆ', 'โลหิตเป็นพิษ'],
#       dtype=object)

# %% [markdown]
# ## Compare provinces with similar income

# %%
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
dead_3reg = dead[dead['region'].isin(region_to_compare) & dead['province'].isin(near_income_list)]

# calculate the rate by cause_of_dead by year, gender, region
dead_3reg = dead_3reg.groupby(['year', 'gender', 'cause_of_dead', 'region' ], as_index=False).sum()

# calcule rate
dead_3reg['rate'] = dead_3reg['number']/dead_3reg['pop']

dead_3reg = dead_3reg.reset_index()

# %%
significant_df2 = []
for year, gender, cause in zip(dead_3reg['year'], dead_3reg['gender'], dead_3reg['cause_of_dead']):
    temp = dead_3reg[(dead_3reg['year']== year ) & (dead_3reg['gender']==gender) & (dead_3reg['cause_of_dead']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        #if (z1 >= 1.96) & (z2>= 1.96) & (z3>= 1.96):
        significant_df2.append([year, gender, cause, z1, z2, z3 ] )
        
significant_df2 = pd.DataFrame(significant_df2, columns=['year', 'gender', 'cause', 'z_NE_income', 'z_N_income', 'z_C_income' ])

significant_df2 = significant_df2.drop_duplicates()

# %%
remove_list = [ 'การติดเชื้อเอชไอวี/เอดส์', 'การพลัดตก หกล้ม', 'ภาวะทุพโภชนาการ',  'ฆ่าตัวตาย', 'โลหิตจาง', 'อุบัติเหตุจากการขนส่งทางบก',
       'อาการท้องร่วง กระเพาะและลำไส้อักเสบจากการติดเชื้อ', 'แผลกระเพาะอาหารและดูโอเดนั่ม', 'อาการแสดงที่พบจากการตรวจทางห้องปฏิบัติการ',
       'โรคของตับ',  
       'โรคติดเชื้อและปรสิตอื่น ๆ', 'โรคมะเร็งกระเพาะอาหาร',
       'โรคมะเร็งตับ',  'โรคระบบย่อยอาหารอื่น ๆ',
       'ความผิดปกติทางจิตเนื่องจากการใช้วัตถุออกฤทธิ์ต่อจิตประสาท',
       'สาเหตุจากภายนอกอื่น ๆ', 'อุบัติเหตุการตกน้ำจมน้ำ', 'โรคต่อมไร้ท่อ โภชนาการและเมตะบอสลิซึมอื่น ๆ']

significant_df2 = significant_df2[~significant_df2['cause'].isin(remove_list)]

# %%
significant_df_merge = significant_df1.merge(significant_df2, on=['year', 'gender', 'cause'], how='inner')
significant_df_merge.shape
# Out:
# (992, 12)

# %%
significant_df_merge.to_csv(mdataset.health_folder  + 'process/' + 'cause_of_dead_narrow.csv', index=False, encoding='utf-8')

# %%
dead_signi_merge = pd.read_csv(mdataset.health_folder  + 'process/' + 'cause_of_dead_narrow.csv')

# %%
dead_signi_merge_avg = dead_signi_merge.groupby(['gender', 'cause'], as_index=False).mean()

# %%
dead_signi_merge_avg.head()
# Out:
#    gender                                              cause    year  \
# 0  Female                กลุ่มอาการและความผิดปกติของโครโมโซม  2015.2
# 1  Female  การขาดอ็อกซิเจนขณะอยู่ในโพรงมดลูกและภาวะแอสฟิก...  2012.5
# 2  Female          การตั้งครรภ์ การคลอดและระยะหลังคลอดอื่น ๆ  2016.0
# 3  Female             การตายเนื่องจาก การคลอด ที่มิใช่โดยตรง  2016.0
# 4  Female                การตายเนื่องจาก การคลอดโดยตรงอื่น ๆ  2016.0
#
#        z_NE       z_N       z_C  ratio_north_south  ratio_northeast_south  \
# 0 -2.016239 -0.835397 -0.248543           0.751245               0.530943
# 1 -2.078961 -0.916444 -0.140558           0.755438               0.565044
# 2 -0.270545  0.143356 -0.153067           1.089936               0.847483
# 3 -1.351617 -0.177069  0.177213           0.925568               0.570565
# 4 -1.166859 -0.909527 -0.479643           0.550226               0.559965
#
#    ratio_central_south  z_NE_income  z_N_income  z_C_income
# 0             0.970158    -1.034107   -0.901138   -0.583192
# 1             0.964162    -1.517184   -0.967189   -0.635340
# 2             0.889728    -0.096475   -0.097435   -0.229759
# 3             1.110480    -1.773820   -1.706920   -1.234379
# 4             0.727301    -0.698473   -1.363982   -1.021868

# %%
dead_signi_merge_avg[(dead_signi_merge_avg['z_N']> 1.96 ) & (dead_signi_merge_avg['z_NE']> 1.96 )]['cause'].unique()
# Out:
# array(['ปอดบวม', 'มะเร็งอื่น ๆ', 'วัณโรคทางเดินหายใจ',
#        'เยื้อหุ้มสมองอักเสบ', 'โรคของระบบกล้ามเนื้อกระดูก',
#        'โรคของระบบสืบพันธุ์และทางเดินปัสสาวะอื่น ๆ',
#        'โรคมะเร็งหลอดลมและปอด', 'โลหิตเป็นพิษ',
#        'โรคของผิวหนังและเนื้อเยื่อใต้ผิวหนัง'], dtype=object)

# %%
dead_signi_merge_avg[(dead_signi_merge_avg['z_N']> 1.96 ) & (dead_signi_merge_avg['z_NE']> 1.96 )].sort_values(['cause', 'gender'])
# Out:
#      gender                                       cause    year       z_NE  \
# 15   Female                                      ปอดบวม  2014.0   8.687474
# 79     Male                                      ปอดบวม  2014.0  10.890973
# 22   Female                                มะเร็งอื่น ๆ  2014.0  12.606739
# 85     Male                                มะเร็งอื่น ๆ  2014.0  14.729482
# 24   Female                          วัณโรคทางเดินหายใจ  2014.0   6.461618
# 87     Male                          วัณโรคทางเดินหายใจ  2014.0   5.776189
# 28   Female                         เยื้อหุ้มสมองอักเสบ  2014.4   2.094671
# 91     Male                         เยื้อหุ้มสมองอักเสบ  2014.0   3.182292
# 94     Male        โรคของผิวหนังและเนื้อเยื่อใต้ผิวหนัง  2014.0   2.091938
# 32   Female                  โรคของระบบกล้ามเนื้อกระดูก  2014.0   5.930703
# 95     Male                  โรคของระบบกล้ามเนื้อกระดูก  2014.3   7.012051
# 34   Female  โรคของระบบสืบพันธุ์และทางเดินปัสสาวะอื่น ๆ  2014.0  20.036007
# 97     Male  โรคของระบบสืบพันธุ์และทางเดินปัสสาวะอื่น ๆ  2014.0  16.272649
# 46   Female                       โรคมะเร็งหลอดลมและปอด  2014.0   3.009161
# 106    Male                       โรคมะเร็งหลอดลมและปอด  2014.0   2.777202
# 63   Female                                โลหิตเป็นพิษ  2014.0   7.250982
# 120    Male                                โลหิตเป็นพิษ  2014.0  10.493554
#
#            z_N        z_C  ratio_north_south  ratio_northeast_south  \
# 15   13.295297  19.096438           1.745149               1.395490
# 79   16.798368  19.393277           1.790499               1.412297
# 22    9.074229   5.533128           1.515615               1.686081
# 85    9.849550   5.608092           1.477625               1.685745
# 24    4.309627   4.520803           1.614653               1.885024
# 87    5.112815   5.942176           1.383895               1.395860
# 28    2.966699   1.712863           2.345005               1.819780
# 91    4.734570   3.101427           2.813571               2.028876
# 94    6.110489   5.668450           2.157557               1.306752
# 32    5.617710   3.151932           2.011366               2.058547
# 95    6.407140   2.727630           2.370472               2.454273
# 34   18.507877   7.983765           2.115713               2.146079
# 97   17.262554   2.948214           1.990805               1.844833
# 46   14.780398   6.330654           2.380441               1.210634
# 106  14.314168   7.268655           1.819057               1.130603
# 63   17.616473  18.229743           1.887064               1.321639
# 120  19.458627  14.496138           1.949802               1.458718
#
#      ratio_central_south  z_NE_income  z_N_income  z_C_income
# 15              2.155915     5.418226    8.353958    9.372265
# 79              1.948360     7.356104   11.038642   10.579121
# 22              1.296353     9.307375    7.469516    4.364729
# 85              1.256664    12.368059    9.583182    5.516365
# 24              1.626180     1.728663   -0.245972    0.834598
# 87              1.445042     0.172721   -1.016400    0.520179
# 28              1.667725     0.669720    1.035050    0.368563
# 91              2.111741     1.358596    1.913171    0.641446
# 94              2.065563     1.731167    3.347171    2.891153
# 32              1.492773     3.122885    3.133634    1.975141
# 95              1.466261     2.846821    2.956387    0.690547
# 34              1.407815    10.108841    8.739885    4.481276
# 97              1.134709     7.283420    7.586732    2.182305
# 46              1.497265     4.814464    9.843359    4.929518
# 106             1.377778     6.858641   11.521362    6.642738
# 63              1.904134     6.241149   10.023140    8.804009
# 120             1.651812     7.201273   10.900499    5.603697

# %% [markdown]
# ## Visualization

# %%
significant_df_merge['cause'].unique()
# Out:
# array(['โรคมะเร็งหลอดลมและปอด',
#        'โรคของระบบสืบพันธุ์และทางเดินปัสสาวะอื่น ๆ', 'โลหิตเป็นพิษ'],
#       dtype=object)

# %%
dis = 'โรคมะเร็งหลอดลมและปอด'

# %%
# calculate the rate by cause_of_dead by year, gender, region
dead_reg = dead.groupby(['year', 'gender', 'cause_of_dead', 'region' ]).sum()

# calcule rate
dead_reg['rate'] = dead_reg['number']/dead_reg['pop']

# reset index
dead_reg = dead_reg.reset_index()

one_disease = dead_reg[dead_reg['cause_of_dead'] == dis]

# %%
_, ax = plt.subplots(2,1, figsize=(14,8))

df = one_disease[one_disease['gender']=='Female']
sns.lineplot(data=df, x='year', y='rate', hue='region', ax=ax[0], marker='o')

df = one_disease[one_disease['gender']=='Male']
sns.lineplot(data=df, x='year', y='rate', hue='region', ax=ax[1], marker='o')

for a, t in zip(ax, ['Female', 'Male']):
    a.set_title(t)
    a.legend(bbox_to_anchor=(1.05, 1.05))
    
plt.tight_layout()

# %%
# select year 
temp = dead[dead['year'].isin(np.arange(2015, 2020))]
mean_rate = temp.groupby(['year', 'gender', 'cause_of_dead', 'province' ]).sum()

# calcule rate
mean_rate['rate'] = mean_rate['number']/mean_rate['pop']*100000

# reset index
mean_rate = mean_rate.reset_index()
mean_rate = mean_rate[mean_rate['cause_of_dead'] == dis]

# average of the rate
std_rate = mean_rate.groupby([ 'gender', 'cause_of_dead', 'province'], as_index=False).std()

mean_rate = mean_rate.groupby([ 'gender', 'cause_of_dead', 'province'], as_index=False).mean()


mean_rate = mean_rate.merge(std_rate, on=[ 'gender', 'cause_of_dead', 'province'], suffixes=('', '_std'))

# create a map of pollution by merging with the shape file 
plot_map = mdataset.prov_map.merge(mean_rate, on='province', how='left')

# %%
_, ax = plt.subplots(1, 2, figsize=(10,10))

df = plot_map[plot_map['gender']=='Female']

df.plot(column='rate',
           ax=ax[0],legend=True,
           legend_kwds={'label': "number per 100,000 population",
                       'orientation': "horizontal"},  cmap='RdYlGn_r',
             missing_kwds={
         "color": "lightgrey",
         "edgecolor": "red",
            "hatch": "///",
           "label": "Missing values" },)

 
df.boundary.plot(ax=ax[0], color='black')

df = plot_map[plot_map['gender']=='Male']

df.plot(column='rate',
           ax=ax[1],legend=True,
           legend_kwds={'label': "number per 100,000 population",
                       'orientation': "horizontal"},  cmap='RdYlGn_r',
             missing_kwds={
         "color": "lightgrey",
         "edgecolor": "red",
            "hatch": "///",
           "label": "Missing values" },)

 
df.boundary.plot(ax=ax[1], color='black')

ax[0].set_title("Lung Cancer Rate (Female)")
ax[1].set_title("Lung Cancer Rate (Male)");

# %%
fig, ax = plt.subplots(2,1, figsize=(14, 9), sharex=True)
#ax.bar(pm10_short_list['province'], pm10_short_list['avgPM10'])


for region in region_list:
    # select province
    prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
    # select only province near Chiang Mai
    # use province_list to keep the bar plot in the same order

    prov_in_region = [s for s in near_income_list if s in prov_in_region]
    df = mean_rate[mean_rate['province'].isin(prov_in_region) & (mean_rate['gender'] == 'Female')]
     
    if len(df) > 0:
        ax[0].bar(df['province'], df['rate'], yerr=df['rate_std'], label=region, edgecolor='black', capsize=10)
        
         
    df = mean_rate[mean_rate['province'].isin(prov_in_region) & (mean_rate['gender'] == 'Male')]
     
    if len(df) > 0:
        ax[1].bar(df['province'], df['rate'], yerr=df['rate_std'], label=region, edgecolor='black', capsize=10)
        
        
# highlight Chiang Mai
#df = dead_male_short.loc[['Chiang Mai']]
#ax[0].bar(df.index, df['lung_dead'], color='magenta', label='Chiang Mai', edgecolor='black')

#df = dead_female_short.loc[['Chiang Mai']]
#ax[1].bar(df.index, df['lung_dead'], color='magenta', label='Chiang Mai', edgecolor='black')

 
ax[0].legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()
ax[0].set_title('Female Lung Dead')
ax[1].set_title('Male Lung Dead')

ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=90);


plt.tight_layout()

# %% [markdown]
# ## Vis Birth Defect

# %%
cause = dead['cause_of_dead'].drop_duplicates().reset_index(drop=True)
birth_defect = cause[cause.str.contains('ครรภ์') | cause.str.contains('กำเนิด')| cause.str.contains('แรกเกิด')| cause.str.contains('แท้ง')| cause.str.contains('ทารก')].to_list()
birth_defect
# Out:
# ['ทารกในครรภ์แรกเกิดที่ได้รับผลจากปัจจัยทางมารดาและโรคแทรกในระยะตั้งครรภ์ เจ็บครรภ์และคลอด',
#  'ความผิดปกติเกี่ยวกับการตั้งครรภ์และการเจริญเติบโตของทารกในครรภ์',
#  'การขาดอ็อกซิเจนขณะอยู่ในโพรงมดลูกและภาวะแอสฟิกเซียเมื่อแรกเกิด',
#  'ปอดบวมแต่กำเนิด',
#  'ภาวะการหายใจอื่น ๆ ในทารกแรกเกิด',
#  'การติดเชื้อและมีพิษของแบคทีเรียในกระแสเลือดในทารกแรกเกิด',
#  'ภาวะปริกำเนิดอื่น ๆ',
#  'ศีรษะรูปบาตรและกระดูกสันหลังแยกแต่กำเนิด',
#  'ความผิดปกติแต่กำเนิดของระบบประสาทอื่น ๆ',
#  'ความผิดปกติของหัวใจแต่กำเนิด',
#  'ความผิดปกติอื่น ๆ แต่กำเนิด',
#  'การแท้ง',
#  'โรคแทรกของการเจ็บครรภ์และการคลอด',
#  'ภาวะหายใจลำบากของทารกแรกเกิด',
#  'เลือดออกและความผิดปกติเกี่ยวกับเลือดของทารกในครรภ์และแรกเกิด',
#  'ความผิดปกติแต่กำเนิดของระบบไหลเวียนโลหิตอื่น ๆ',
#  'การตั้งครรภ์ การคลอดและระยะหลังคลอดอื่น ๆ',
#  'ความผิดปกติอื่นที่ส่วนใหญ่เป็นผลจากการตั้งครรภ์',
#  'สะดืออักเสบในทารกแรกเกิดชนิดมีหรือไม่มีเลือดออก']

# %%
# global average
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
dead_3reg = dead[dead['region'].isin(region_to_compare)]

# calculate the rate by cause_of_dead by year, gender, region
dead_3reg = dead_3reg.groupby(['year', 'gender', 'cause_of_dead', 'region' ]).sum()

# calcule rate
dead_3reg['rate'] = dead_3reg['number']/dead_3reg['birth_number']

# calculate average over the years
dead_3reg = dead_3reg.reset_index()
#dead_3reg_global = dead_3reg.groupby([ 'gender', 'disease', 'region' ], as_index=False).mean() 

dead_3reg_global = dead_3reg[dead_3reg['cause_of_dead'].isin(birth_defect)]

# %%
# selected provinces in near income range
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
dead_3reg = dead[dead['region'].isin(region_to_compare) & dead['province'].isin(near_income_list)]

# calculate the rate by cause_of_dead by year, gender, region
dead_3reg = dead_3reg.groupby(['year', 'gender', 'cause_of_dead', 'region' ]).sum()

# calcule rate
dead_3reg['rate'] = dead_3reg['number']/dead_3reg['birth_number']

# calculate average over the years
dead_3reg = dead_3reg.reset_index()
#dead_3reg_spec = dead_3reg.groupby([ 'gender', 'disease', 'region' ], as_index=False).mean() 

# select only birth defect 
dead_3reg_spec = dead_3reg[dead_3reg['cause_of_dead'].isin(birth_defect)]

# %%
significant_df1 = []
for year, gender, cause in zip(dead_3reg_global['year'], dead_3reg_global['gender'], dead_3reg_global['cause_of_dead']):
    temp = dead_3reg_global[(dead_3reg_global['year']==year) & (dead_3reg_global['gender']==gender) & (dead_3reg_global['cause_of_dead']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        significant_df1.append([year, gender, cause, z1, z2, z3, row_n['rate']/row_s['rate'], row_ne['rate']/row_s['rate'], row_c['rate']/row_s['rate']] )
        
significant_df1 = pd.DataFrame(significant_df1, columns=['year', 'gender', 'cause_of_dead', 'z_NE', 'z_N', 'z_C', 'ratio_north_south', 'ratio_northeast_south',  'ratio_central_south'])

# %%
significant_df2 = []
for year, gender, cause in zip(dead_3reg_spec['year'], dead_3reg_spec['gender'], dead_3reg_spec['cause_of_dead']):
    temp = dead_3reg_spec[(dead_3reg_spec['year']==year) & (dead_3reg_spec['gender']==gender) & (dead_3reg_spec['cause_of_dead']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        significant_df2.append([year, gender, cause, z1, z2, z3]  )
        
significant_df2 = pd.DataFrame(significant_df2, columns=['year', 'gender', 'cause_of_dead', 'z_NE_spec', 'z_N_spec', 'z_C_spec' ])

# %%
significant_df = significant_df1.merge(significant_df2, on=['year','gender','cause_of_dead'])

# %%
significant_avg = significant_df.groupby(['gender','cause_of_dead'], as_index=False).mean()

# %%
significant_avg[significant_avg['ratio_north_south'] > 1]['cause_of_dead'].unique().tolist()
# Out:
# ['การตั้งครรภ์ การคลอดและระยะหลังคลอดอื่น ๆ',
#  'ความผิดปกติแต่กำเนิดของระบบไหลเวียนโลหิตอื่น ๆ',
#  'โรคแทรกของการเจ็บครรภ์และการคลอด']

# %%
significant_avg[(significant_avg['z_N_spec']> 1.64) & (significant_avg['z_NE_spec']> 1.64)   ]['cause_of_dead'].unique().tolist()
# Out:
# ['การตั้งครรภ์ การคลอดและระยะหลังคลอดอื่น ๆ',
#  'ความผิดปกติแต่กำเนิดของระบบประสาทอื่น ๆ',
#  'ศีรษะรูปบาตรและกระดูกสันหลังแยกแต่กำเนิด']

# %%
significant_avg[significant_avg['cause_of_dead'].isin(['ความผิดปกติแต่กำเนิดของระบบประสาทอื่น ๆ',
 'ศีรษะรูปบาตรและกระดูกสันหลังแยกแต่กำเนิด'])]
# Out:
#     gender                             cause_of_dead         year      z_NE  \
# 7   Female   ความผิดปกติแต่กำเนิดของระบบประสาทอื่น ๆ  2013.857143 -1.946982
# 13  Female  ศีรษะรูปบาตรและกระดูกสันหลังแยกแต่กำเนิด  2014.000000 -0.720992
# 20    Male   ความผิดปกติแต่กำเนิดของระบบประสาทอื่น ๆ  2013.555556  0.769782
# 25    Male  ศีรษะรูปบาตรและกระดูกสันหลังแยกแต่กำเนิด  2017.000000 -6.213173
#
#          z_N       z_C  ratio_north_south  ratio_northeast_south  \
# 7   5.279156  0.130138           1.342936               0.937405
# 13  3.470349  2.169756           1.478154               0.971167
# 20  5.321047  1.946021           1.289817               1.045629
# 25  4.081844  2.729579           1.367136               0.609156
#
#     ratio_central_south  z_NE_spec  z_N_spec  z_C_spec
# 7              1.009594  -0.310411  1.237333  0.686367
# 13             1.280168  -0.514122  6.105333  0.292217
# 20             1.129464   3.574140  2.016777  1.249559
# 25             1.286125   3.655653  3.242603  2.533115

# %% [markdown]
# # In Patient

# %%
near_income_list = ['Tak',
 'Narathiwat',
 'Nan',
 'Surin',
 'Sakon Nakhon',
 'Nong Bua Lam Phu',
 'Roi Et',
 'Amnat Charoen',
 'Chaiyaphum',
 'Chiang Mai',
 'Pattani',
 'Uthai Thani',
 'Loei',
 'Phrae',
 'Phetchabun',
 'Mukdahan',
 'Nong Khai',
 'Yala',
 'Uttaradit',
 'Suphan Buri']

# %%
population = pd.read_csv(mdataset.health_folder  + 'process/pop_prov.csv')  
population = population.drop(['province_th', 'gender_th'], axis=1)

pop = population.melt(id_vars=['province', 'gender'], var_name='year', value_name='pop')
pop['year'] = pop['year'].astype(int)
in_pat = pd.read_csv(mdataset.health_folder + 'process/in_patient_2007_2019.csv').dropna()

in_pat = in_pat[~in_pat['year'].isin([2013, 2016])]
# add population 
in_pat = in_pat.merge(pop, on=['province', 'gender', 'year'], how='left')

# add birth rate

birth_rate = pd.read_csv(mdataset.health_folder  + 'process/birth_prov.csv')
birth_rate = birth_rate.rename(columns={'number':'birth_number'})

in_pat = in_pat.merge(birth_rate, on=['province',  'year'], how='left')

# load provinces & region information 
provinces = mdataset.prov_map[['region', 'province']]

region_list = ['Northern Region', 'Northeastern Region', 'Central Region','Greater Bangkok','Southern Region']

# add region
in_pat = in_pat.merge(provinces, on='province', how='left')

# remove use number and remove total in gender 
in_pat = in_pat[(in_pat['number_type'] == 'number') & (in_pat['gender'].isin(['Male', 'Female'])) ]
in_pat = in_pat[~in_pat['region'].isna()]

# %%
in_pat['disease'].unique().shape
# Out:
# (298,)

# %%
cause = in_pat['disease'].drop_duplicates().reset_index(drop=True)
birth_defect = cause[cause.str.contains('ครรภ์') | cause.str.contains('กำเนิด')| cause.str.contains('แรกเกิด')| cause.str.contains('ทารก')].to_list()
birth_defect = [ 
 'Other pregnancies with abortive outcome (O00-O02, O05-O08)\nการตั้งครรภ์อื่น ๆ ที่สิ้นสุดโดยการแท้ง',
 'Oedema, proteinuria and hypertensive disorders in pregnancy, childbirth and the puerperium (O10-O16)\nการบวม การมีโปรตีนในปัสสาวะ และความดันโลหิตสูงขณะตั้งครรภ์ ระยะคลอด และระยะหลังคลอด',
 'Other maternal care related to fetus and amniotic cavity and possible delivery problems (O30-O43, O47-O48)\nการดูแลมารดาอื่น ๆ ที่มีปัญหาเกี่ยวกับทารกในครรภ์ และถุงน้ำคร่ำ และปัญหาที่อาจจะเกิดได้ในระยะคลอด',
 'Other complications of pregnancy and delivery (O20-O29, O60-O63, O67-O71, O73-O75, O81-O84)\nภาวะแทรกซ้อนอื่น ๆของการตั้งครรภ์ และการคลอด',
 'Fetus and newborn affected by maternal factors and by complications of pregnancy, labour and delivery (P00-P04)\nทารกในครรภ์และแรกเกิดที่ได้รับผลจากปัจจัยทางมารดา และโรคแทรกในระยะตั้งครรภ์ เจ็บครรภ์ และคลอด',
 'Slow fetal growth, fetal malnutrition and disorders related to short gestation and low birth weight (P05-P07)\nทารกในครรภ์โตช้า ทารกในครรภ์ขาดสารอาหาร และความผิดปกติเกี่ยวกับการตั้งครรภ์ระยะสั้น และน้ำหนักทารกแรกเกิดน้อย',
 'Intrauterine hypoxia and birth asphyxia (P20-P21)\nขาดออกซิเจนขณะอยู่ในโพรงมดลูก และภาวะแอสฟิกเซียเมื่อแรกเกิด',
 'Other infections specIfic to the perinatal period (P38-P39)\nการติดเชื้อเฉพาะอื่น ๆ ในระยะปริกำเนิด',
 'Haemolytic disease of fetus and newborn (P55)\nโรคเม็ดเลือดแตกของทารกในครรภ์และแรกเกิด',
 'Other conditions originating in the perinatal period (P08, P29, P50-P54, P56-P96)\nภาวะอื่น ๆ ในระยะปริกำเนิด',
 'Other congenital malformations of the nervous system (Q00-Q04, Q06-Q07)\nความผิดปกติอื่น ๆ แต่กำเนิดของระบบประสาท',
 'Congenital malformation of the circulatory system (Q20-Q28)\nความผิดปกติแต่กำเนิดของระบบไหลเวียนโลหิต',
 'Other congenital malformations of the digestive system (Q38-Q40, Q42-Q45)\nความผิดปกติแต่กำเนิดอื่น ๆ ของระบบย่อยอาหาร',
 'Congenital deformities of hip (Q65)\nความพิการแต่กำเนิดของสะโพก',
 'Congenital deformities of feet (Q66)\nความพิการแต่กำเนิดของเท้า',
 'Other congenital malformations and deformations of the musculoskeletal system (Q67-Q79)\nความผิดปกติและความพิการแต่กำเนิดอื่น ๆ ของระบบกล้ามเนื้อและโครงร่าง',
 'Other congenital malformations (Q10-Q18, Q30-Q34, Q80-Q89)\nความผิดปกติแต่กำเนิดอื่น ๆ']

# %% [markdown]
# ## Compare Region

# %%
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
in_pat_3reg = in_pat[in_pat['region'].isin(region_to_compare)]

# calculate the rate by cause_of_dead by year, gender, region
in_pat_3reg = in_pat_3reg.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
in_pat_3reg['rate'] = in_pat_3reg['number']/in_pat_3reg['pop']

# calculate average over the years
in_pat_3reg_global = in_pat_3reg.reset_index()

# %%
significant_df1 = []
for year, gender, cause in zip(in_pat_3reg_global['year'], in_pat_3reg_global['gender'], in_pat_3reg_global['disease']):
    temp = in_pat_3reg_global[(in_pat_3reg_global['year']==year) &(in_pat_3reg_global['gender']==gender) & (in_pat_3reg_global['disease']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        significant_df1.append([year, gender, cause, z1, z2, z3, row_n['rate']/row_s['rate'], row_ne['rate']/row_s['rate'], row_c['rate']/row_s['rate']] )
        
significant_df1 = pd.DataFrame(significant_df1, columns=['year', 'gender', 'disease', 'z_NE', 'z_N', 'z_C', 'ratio_north_south', 'ratio_northeast_south',  'ratio_central_south'])

# z2 should be more than z1
#significant_df1['north_higher_than_ne_c'] =  (significant_df1['z_N'] > significant_df1['z_NE']) & (significant_df1['z_N'] > significant_df1['z_C']) 
#significant_df1 = significant_df1[significant_df1['north_higher_than_ne_c'] == True]
significant_df1 = significant_df1.drop_duplicates()

# %%
remove_list = ['Acute hepatitis B (B16)\nตับอักเสบเฉียบพลันชนิดบี',
       'Alcohalic liver disease (K70)\nโรคตับเกี่ยวกับแอลกอฮอล์',
       'Blindness and low vision (H54)\nตาบอดและสายตาเลือนลาง',
       'Carcinoma in situ of cervix uteri (D06)\nมะเร็งจำกัดเฉพาะที่ของปากมดลูก',
       'Certain early complications of trauma and complications of surgical and medical care, note elsewhere classIfied (T79-T88)\nภาวะแทรกซ้อนระยะแรกของการบาดเจ็บบางชนิด และภาวะแทรกซ้อนของการรักษาทางศัลยกรรมและอายุรกรรมที่มิได้มีรหัสระบุไว้ที่อื่น',
       'Cervical and other intervertebral disc disorders (M50-M51)\nกระดูกสันหลังและหมอนรองกระดูกสันหลังอื่น ๆ ผิดปกติ',
       'Cholelithiasis and cholecysitis (K80-K81)\nโรคนิ่วในระบบน้ำดีและถุงน้ำดีอักเสบ',
       'Contraceptive management (Z30)\nการรับบริการคุมกำเนิด',
       'Dementia (F00-F03)\nสมองเสื่อม',
       'Diabetes mellitus (E10-E14)\nเบาหวาน',
       'Diseases of appendix (K35-K38)\nโรคของไส้ติ่ง',
       'Disorders of bone density and structure (M80-M85)\nความผิดปกติของความหนาแน่นของเนื้อกระดูกและโครงสร้าง',
       'Female genital prolapse (N81)\nการหย่อนตัวออกมาของอวัยวะสืบพันธุ์สตรี',
       'Gastric and duodenal ulcer (K25-K27)\nแผลเปื่อยของกระเพาะอาหารดูโอเดนัม',
       'Herpesviral infections (B00)\nเริม',
       'Injury of eye and orbit (S05)\nการบาดเจ็บของตาและเบ้าตา',
       'Malignant neoplasm of breast (C50)\nเนื้องอกร้ายที่เต้านม',
       'Malignant neoplasm of cervix uteri (C53)\nเนื้องอกร้ายที่ปากมดลูก',
       'Malignant neoplasm of colon (C18)\nเนื้องอกร้ายของลำไส้ใหญ่',
       'Malignant neoplasm of liver and intrahepatic bile ducts (C22)\nเนื้องอกร้ายที่ตับและท่อน้ำดีในตับ',
       'Malignant neoplasm of other and unspecified parts of uterus (C54-C55)\n เนื้องอกร้ายอื่น ๆ ที่มิได้ระบุส่วนของมดลูก',
       'Malignant neoplasm of other, ill-defined, secondary, unspecIfied and multiple sites (C73-C80, C97)\nเนื้องอกอื่น ๆ และที่ไม่ทราบสาเหตุ เนื้องอกทุติยภูมิที่มิได้ระบุรายละเอียดและเกิดขึ้นหลายแห่ง',
       'Malignant neoplasm of rectosigmoid junction, rectum, anus and anal canal (C19-C21)\nเนื้องอกร้ายที่รอยต่อลำไส้ใหญ่เร็คตัมและซิกมอยด์ เร็คตัม ทวารหนักและช่องทวารหนัก',
       'Malignant neoplasm of stomach (C16)\nเนื้องอกร้ายที่กระเพาะอาหาร',
       'Malignant neoplasms of lip, oral cavity and pharynx (C00-C14)\nเนื้องอกร้ายของริมฝีปาก ช่องปาก และคอหอย',
       'Maltreatment syndromes (T74)\nกลุ่มอาการจากการทารุณ',
       'Mental and behavioral disorders due to use of alcohol (F10)\nความผิดปกติของพฤติกรรมและจิตประสาทที่เกิดจากการเสพแอลกอฮอล์',
       'Osteomyelitis (M86)\nกระดูกอักเสบ',
       'Other diseases of liver (K71-K77)\nโรคอื่น ๆ ของตับ',
       'Other diseases of the digestive system (K82-K83, K87-K93)\nโรคอื่น ๆ ของระบบย่อยอาหาร',
       'Other diseases of the nervous system (G10-G13, G21-G26, G31-G32, G36-G37, G46-G47, G60-G73, G90-G99)\nโรคของระบบประสาทอื่น ๆ',
       'Other diseases of the oral cavity, salivary glands and jaws (K09-K14)\nโรคอื่น ๆ ของช่องปาก ต่อมน้ำลายและขากรรไกร',
       'Other diseorders of joints (M00-M03, M22-M25)\nความผิดปกติอื่น ๆ ของข้อ',
       'Other disorders of teeth and supporting structures (K00-K01, K03-K08)\nความผิดปกติอื่น ๆ ของฟันและโครงสร้าง',
       'Other dorsopathies (M40-M49, M53-M54)\nพยาธิสภาพของหลังส่วนอื่น ๆ',
       'Other fluke infections (B66)\nโรคพยาธิใบไม้อื่น ๆ',
       'Other helminthiases (B68-B71, B75, B77-B83)\nโรคพยาธิตัวตืดอื่น ๆ',
       'Other intestinal infectious diseases (A02, A04-A05, A07-A08)\nโรคลำไส้อักเสบอื่น ๆ',
       'Other malignant neoplasms of digestive organs (C17, C23-C24, C26)\nเนื้องอกร้ายที่อวัยวะย่อยอาหารอื่น ๆ',
       'Other malignant neoplasms of female genital organs (C51-C52, C56-C58)\nเนื้องอกร้ายของอวัยวะสืบพันธุ์หญิง',
       'Other malignant neoplasms of skin (C44)\nเนื้องอกร้ายที่ผิวหนังอื่น ๆ',
       'Other mental and behavioral disorders (F04-F09, F50-F69, F80-F99)\nความผิดปกติทางจิตและพฤติกรรมอื่น ๆ',
       'Other tetanus (A34-A35)\nบาดทะยักอื่น ๆ',
       'Other viral hepatitis (B15, B17-B19)\nตับอักเสบจากไวรัสอื่น ๆ',
       'Paralytic ileus and intestinal obstruction without hernia (K56)\nลำไส้ไม่ทำงานและลำไส้เกิดอุดตันแบบไม่มีไส้เลื่อน',
       "Parkinson's disease (G20)\nโรคพาร์คินสัน",
       'Persons encountering health services for specIfic procedures and health care (Z40-Z54, Z40-Z54)\nบุคคลขอรับบริการสุขภาพ เพื่อหัตถการหรือการบริการสุขภาพที่ระบุเฉพาะ',
       'Renal failure (N17-N19)\nไตวาย',
       'Renal tubulo-interstitial diseases (N10-N16)\nโรคของท่อและเนื้อเยื่อระหว่างท่อในไต',
       'Rheumatoid arthritis and other inflammatory polyarthropathies (M05-M14)\nข้ออักเสบรูห์มาตอยและข้ออักเสบหลายข้อ',
       'Schizophrenia, schizotypal and delusional disorders (F20-F29)\nจิตเภท พฤติกรรมแบบจิตเภทและความหลงผิด',
       'Senility (R54)\nชราภาพ', 
       'Urolithiasis (N20-N23)\nนิ่วในระบบทางเดินปัสสาวะ',
       'Acute pancreatitis and other diseases of the pancreas (K85-K86)\nตับอ่อนอักเสบเฉียบพลันและโรคอื่น ๆ ของตับอ่อน',
       'Crushing injuries and traumatic amputations of specIfied and multiple body regions (S07-S08, S17-S18, S28, S38, S47-S48, S57-S58, S67-S68, S77-S78, S87-S88, S97-S98, T04-T05)\nการบาดเจ็บจากการบดอัดและการบาดเจ็บที่เกิดจากตัดขาบริเวณร่างกายหลายแห่งที่ระบุเฉพาะ',
       'Dislocations, sprains and strains of specIfied and multiple body regions (S03, S13, S23, S33, S43,S53, S63, S73, S83, S93, T03)\nกระดูกเคลื่อน เคล็ด ขัด บริเวณร่างกายหลายแห่งที่ระบุเฉพาะ',
       'Fractures of other limb bones (S42, S52, S62, S82, S92, T10, T12)\nกระดูกแตกหักของแขนขาอื่น ๆ',
       'Other diseases of the urinary system (N25-N29, N31-N39)\nโรคอื่น ๆ ของระบบทางเดินปัสสาวะ',
       'Other disorders of prostate (N41-N42)\nความผิดปกติอื่น ๆ ของต่อมลูกหมาก',
       'Other infections with a predominantly sexual mode of transmission (A57-A64)\nโรคติดเชื้ออื่น ๆ ที่ติดต่อทางเพศสัมพันธ์เป็นส่วนมาก',
       'Other vitamin deficiencies (E51-E56)\nการขาดวิตามินอื่น ๆ',
       'Persons encountering health services for other reasons (Z31-Z33, Z37, Z55-Z99)\nบุคคลขอรับบริการสุขภาพด้วยเหตุผลอื่น',
       'Redundant prepuce, phimosis and paraphimosis (N47)\nหนังหุ้มปลายองคชาติยาวเกินไป ปลายตีบรูเปิดไม่ได้หรือเปิดลำบาก',
        'Other anaemias (D51-D64)\nโลหิตจางอื่น ๆ',
        'Other Endocrine, nutritional and metabolic disorders (E15-E35, E58-E63, E65, E67-E85, E87-E90)\nความผิดปกติของต่อมไร้ท่อ โภชนาการและเมตะบอลิกอื่น ๆ'
              ]

significant_df1 = significant_df1[~significant_df1['disease'].isin(remove_list)]

# %% [markdown]
#  ## Compare Provinces with similar income

# %%
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
in_pat_3reg = in_pat[in_pat['region'].isin(region_to_compare) & in_pat['province'].isin(near_income_list)]

# calculate the rate by cause_of_dead by year, gender, region
in_pat_3reg = in_pat_3reg.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
in_pat_3reg['rate'] = in_pat_3reg['number']/in_pat_3reg['pop']

# calculate average over the years
in_pat_3reg_spec = in_pat_3reg.reset_index()

# %%
significant_df2 = []
for year, gender, cause in zip(in_pat_3reg_spec['year'],in_pat_3reg_spec['gender'], in_pat_3reg_spec['disease']):
    temp = in_pat_3reg_spec[(in_pat_3reg_spec['year']==year) & (in_pat_3reg_spec['gender']==gender) & (in_pat_3reg_spec['disease']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        significant_df2.append([year, gender, cause, z1, z2, z3 ] )
        
significant_df2 = pd.DataFrame(significant_df2, columns=['year', 'gender', 'disease', 'z_NE_income', 'z_N_income', 'z_C_income' ])

significant_df2 = significant_df2.drop_duplicates()

# %%
remove_list = ['Acute hepatitis B (B16)\nตับอักเสบเฉียบพลันชนิดบี',
       'Alcohalic liver disease (K70)\nโรคตับเกี่ยวกับแอลกอฮอล์',
       'Blindness and low vision (H54)\nตาบอดและสายตาเลือนลาง',
       'Carcinoma in situ of cervix uteri (D06)\nมะเร็งจำกัดเฉพาะที่ของปากมดลูก',
       'Certain early complications of trauma and complications of surgical and medical care, note elsewhere classIfied (T79-T88)\nภาวะแทรกซ้อนระยะแรกของการบาดเจ็บบางชนิด และภาวะแทรกซ้อนของการรักษาทางศัลยกรรมและอายุรกรรมที่มิได้มีรหัสระบุไว้ที่อื่น',
       'Cervical and other intervertebral disc disorders (M50-M51)\nกระดูกสันหลังและหมอนรองกระดูกสันหลังอื่น ๆ ผิดปกติ',
       'Cholelithiasis and cholecysitis (K80-K81)\nโรคนิ่วในระบบน้ำดีและถุงน้ำดีอักเสบ',
       'Contraceptive management (Z30)\nการรับบริการคุมกำเนิด',
       'Dementia (F00-F03)\nสมองเสื่อม',
       'Diabetes mellitus (E10-E14)\nเบาหวาน',
       'Diseases of appendix (K35-K38)\nโรคของไส้ติ่ง',
       'Disorders of bone density and structure (M80-M85)\nความผิดปกติของความหนาแน่นของเนื้อกระดูกและโครงสร้าง',
       'Female genital prolapse (N81)\nการหย่อนตัวออกมาของอวัยวะสืบพันธุ์สตรี',
       'Gastric and duodenal ulcer (K25-K27)\nแผลเปื่อยของกระเพาะอาหารดูโอเดนัม',
       'Herpesviral infections (B00)\nเริม',
       'Injury of eye and orbit (S05)\nการบาดเจ็บของตาและเบ้าตา',
       'Malignant neoplasm of breast (C50)\nเนื้องอกร้ายที่เต้านม',
       'Malignant neoplasm of cervix uteri (C53)\nเนื้องอกร้ายที่ปากมดลูก',
       'Malignant neoplasm of colon (C18)\nเนื้องอกร้ายของลำไส้ใหญ่',
       'Malignant neoplasm of liver and intrahepatic bile ducts (C22)\nเนื้องอกร้ายที่ตับและท่อน้ำดีในตับ',
       'Malignant neoplasm of other and unspecified parts of uterus (C54-C55)\n เนื้องอกร้ายอื่น ๆ ที่มิได้ระบุส่วนของมดลูก',
       'Malignant neoplasm of other, ill-defined, secondary, unspecIfied and multiple sites (C73-C80, C97)\nเนื้องอกอื่น ๆ และที่ไม่ทราบสาเหตุ เนื้องอกทุติยภูมิที่มิได้ระบุรายละเอียดและเกิดขึ้นหลายแห่ง',
       'Malignant neoplasm of rectosigmoid junction, rectum, anus and anal canal (C19-C21)\nเนื้องอกร้ายที่รอยต่อลำไส้ใหญ่เร็คตัมและซิกมอยด์ เร็คตัม ทวารหนักและช่องทวารหนัก',
       'Malignant neoplasm of stomach (C16)\nเนื้องอกร้ายที่กระเพาะอาหาร',
       'Malignant neoplasms of lip, oral cavity and pharynx (C00-C14)\nเนื้องอกร้ายของริมฝีปาก ช่องปาก และคอหอย',
       'Maltreatment syndromes (T74)\nกลุ่มอาการจากการทารุณ',
       'Mental and behavioral disorders due to use of alcohol (F10)\nความผิดปกติของพฤติกรรมและจิตประสาทที่เกิดจากการเสพแอลกอฮอล์',
       'Osteomyelitis (M86)\nกระดูกอักเสบ',
       'Other diseases of liver (K71-K77)\nโรคอื่น ๆ ของตับ',
       'Other diseases of the digestive system (K82-K83, K87-K93)\nโรคอื่น ๆ ของระบบย่อยอาหาร',
       'Other diseases of the nervous system (G10-G13, G21-G26, G31-G32, G36-G37, G46-G47, G60-G73, G90-G99)\nโรคของระบบประสาทอื่น ๆ',
       'Other diseases of the oral cavity, salivary glands and jaws (K09-K14)\nโรคอื่น ๆ ของช่องปาก ต่อมน้ำลายและขากรรไกร',
       'Other diseorders of joints (M00-M03, M22-M25)\nความผิดปกติอื่น ๆ ของข้อ',
       'Other disorders of teeth and supporting structures (K00-K01, K03-K08)\nความผิดปกติอื่น ๆ ของฟันและโครงสร้าง',
       'Other dorsopathies (M40-M49, M53-M54)\nพยาธิสภาพของหลังส่วนอื่น ๆ',
       'Other fluke infections (B66)\nโรคพยาธิใบไม้อื่น ๆ',
       'Other helminthiases (B68-B71, B75, B77-B83)\nโรคพยาธิตัวตืดอื่น ๆ',
       'Other intestinal infectious diseases (A02, A04-A05, A07-A08)\nโรคลำไส้อักเสบอื่น ๆ',
       'Other malignant neoplasms of digestive organs (C17, C23-C24, C26)\nเนื้องอกร้ายที่อวัยวะย่อยอาหารอื่น ๆ',
       'Other malignant neoplasms of female genital organs (C51-C52, C56-C58)\nเนื้องอกร้ายของอวัยวะสืบพันธุ์หญิง',
       'Other malignant neoplasms of skin (C44)\nเนื้องอกร้ายที่ผิวหนังอื่น ๆ',
       'Other mental and behavioral disorders (F04-F09, F50-F69, F80-F99)\nความผิดปกติทางจิตและพฤติกรรมอื่น ๆ',
       'Other tetanus (A34-A35)\nบาดทะยักอื่น ๆ',
       'Other viral hepatitis (B15, B17-B19)\nตับอักเสบจากไวรัสอื่น ๆ',
       'Paralytic ileus and intestinal obstruction without hernia (K56)\nลำไส้ไม่ทำงานและลำไส้เกิดอุดตันแบบไม่มีไส้เลื่อน',
       "Parkinson's disease (G20)\nโรคพาร์คินสัน",
       'Persons encountering health services for specIfic procedures and health care (Z40-Z54, Z40-Z54)\nบุคคลขอรับบริการสุขภาพ เพื่อหัตถการหรือการบริการสุขภาพที่ระบุเฉพาะ',
       'Renal failure (N17-N19)\nไตวาย',
       'Renal tubulo-interstitial diseases (N10-N16)\nโรคของท่อและเนื้อเยื่อระหว่างท่อในไต',
       'Rheumatoid arthritis and other inflammatory polyarthropathies (M05-M14)\nข้ออักเสบรูห์มาตอยและข้ออักเสบหลายข้อ',
       'Schizophrenia, schizotypal and delusional disorders (F20-F29)\nจิตเภท พฤติกรรมแบบจิตเภทและความหลงผิด',
       'Senility (R54)\nชราภาพ', 
       'Urolithiasis (N20-N23)\nนิ่วในระบบทางเดินปัสสาวะ',
       'Acute pancreatitis and other diseases of the pancreas (K85-K86)\nตับอ่อนอักเสบเฉียบพลันและโรคอื่น ๆ ของตับอ่อน',
       'Crushing injuries and traumatic amputations of specIfied and multiple body regions (S07-S08, S17-S18, S28, S38, S47-S48, S57-S58, S67-S68, S77-S78, S87-S88, S97-S98, T04-T05)\nการบาดเจ็บจากการบดอัดและการบาดเจ็บที่เกิดจากตัดขาบริเวณร่างกายหลายแห่งที่ระบุเฉพาะ',
       'Dislocations, sprains and strains of specIfied and multiple body regions (S03, S13, S23, S33, S43,S53, S63, S73, S83, S93, T03)\nกระดูกเคลื่อน เคล็ด ขัด บริเวณร่างกายหลายแห่งที่ระบุเฉพาะ',
       'Fractures of other limb bones (S42, S52, S62, S82, S92, T10, T12)\nกระดูกแตกหักของแขนขาอื่น ๆ',
       'Other diseases of the urinary system (N25-N29, N31-N39)\nโรคอื่น ๆ ของระบบทางเดินปัสสาวะ',
       'Other disorders of prostate (N41-N42)\nความผิดปกติอื่น ๆ ของต่อมลูกหมาก',
       'Other infections with a predominantly sexual mode of transmission (A57-A64)\nโรคติดเชื้ออื่น ๆ ที่ติดต่อทางเพศสัมพันธ์เป็นส่วนมาก',
       'Other vitamin deficiencies (E51-E56)\nการขาดวิตามินอื่น ๆ',
       'Persons encountering health services for other reasons (Z31-Z33, Z37, Z55-Z99)\nบุคคลขอรับบริการสุขภาพด้วยเหตุผลอื่น',
       'Redundant prepuce, phimosis and paraphimosis (N47)\nหนังหุ้มปลายองคชาติยาวเกินไป ปลายตีบรูเปิดไม่ได้หรือเปิดลำบาก',
        'Other anaemias (D51-D64)\nโลหิตจางอื่น ๆ',
        'Other Endocrine, nutritional and metabolic disorders (E15-E35, E58-E63, E65, E67-E85, E87-E90)\nความผิดปกติของต่อมไร้ท่อ โภชนาการและเมตะบอลิกอื่น ๆ'
              ]

significant_df2 = significant_df2[~significant_df2['disease'].isin(remove_list)]

# %%
significant_df2.shape
# Out:
# (366, 6)

# %%
significant_df_merge = significant_df1.merge(significant_df2, on=['year', 'gender', 'disease'], how='inner')
significant_df_merge.shape
# Out:
# (4998, 12)

# %%
significant_df_merge.to_csv(mdataset.health_folder  + 'process/' + 'in_patient_narrow.csv', index=False, encoding='utf-8')

# %%
in_pat_sig_merge = pd.read_csv(mdataset.health_folder  + 'process/' + 'in_patient_narrow.csv')

# %%
in_pat_sig_avg = in_pat_sig_merge.groupby(['gender', 'disease'], as_index=False).mean()

# %%
in_pat_sig_dis = in_pat_sig_avg[(in_pat_sig_avg['z_N']> 1.96 ) & (in_pat_sig_avg['z_NE']> 1.96 )]['disease'].unique()

# %%
higher_female = []
for dis in in_pat_sig_dis:
    temp = in_pat_sig_avg[in_pat_sig_avg['disease'] == dis]
    if len(temp)== 2:
        temp = temp.set_index('gender')
        if (temp.loc['Female', 'z_N'] > temp.loc['Male', 'z_N']):
            
            higher_female.append(dis)

# %%
higher_female
# Out:
# ['Chronic rheumatic heart disease (I05-I09)\nโรคหัวใจรูมาติกเรื้อรัง',
#  'Conduction disorders and cardiac arrhythmias (I44-I49)\nความผิดปกติของการนำกระแสไฟฟ้าหัวใจและหัวใจเต้นผิดจังหวะ',
#  'Glaucoma (H40-H42)\nต้อหิน',
#  'Haemorrhagic conditions and other diseases of blood and blood-forming organs (D65-D77)\nภาวะเลือดออกอื่น ๆ โรคเลือดและอวัยวะที่สร้างเลือด',
#  'Keratitis and other disorders of sclera and cornea (H15-H19)\nกระจกตาอักเสบและความผิดปกติของตาขาวและกระจกตาอื่น ๆ',
#  'Malignant neoplasm of trachea, bronchus and lung (C33-C34)\nเนื้องอกร้ายที่หลอดคอ หลอดลม และปอด',
#  'Phlebitis, thrombophlebitis,venous embolism and thrombosis (I80-I82)\nหลอดเลือดดำอักเสบ หลอดเลือดดำอักเสบมีลิ่มเลือดก้อนเลือดและลิ่มเลือดในหลอดเลือดดำ',
#  'Systemic connective tissue disorders (M30-M36)\nความผิดปกติของระบบเนื้อเยื่อประสาน']

# %% [markdown]
# ## Visualization

# %%
significant_df_merge = pd.read_csv(mdataset.health_folder  + 'process/' + 'in_patient_narrow.csv')

# %%
significant_df_merge['disease'].value_counts()[significant_df_merge['disease'].value_counts() == 2].index
# Out:
# Index(['Systemic connective tissue disorders (M30-M36)\nความผิดปกติของระบบเนื้อเยื่อประสาน',
#        'Malignant neoplasm of trachea, bronchus and lung (C33-C34)\nเนื้องอกร้ายที่หลอดคอ หลอดลม และปอด',
#        'Other diseases of the circulatory system (I85-I99) \nโรคอื่น ๆ ของระบบไหลเวียนโลหิต',
#        'Septicemia (A40-A41)\nโลหิตเป็นพิษ',
#        'Conduction disorders and cardiac arrhythmias (I44-I49)\nความผิดปกติของการนำกระแสไฟฟ้าหัวใจและหัวใจเต้นผิดจังหวะ'],
#       dtype='object')

# %%
dis_list = ['Systemic connective tissue disorders (M30-M36)\nความผิดปกติของระบบเนื้อเยื่อประสาน',
       'Malignant neoplasm of trachea, bronchus and lung (C33-C34)\nเนื้องอกร้ายที่หลอดคอ หลอดลม และปอด',
       'Other diseases of the circulatory system (I85-I99) \nโรคอื่น ๆ ของระบบไหลเวียนโลหิต',
       'Septicemia (A40-A41)\nโลหิตเป็นพิษ',
       'Conduction disorders and cardiac arrhythmias (I44-I49)\nความผิดปกติของการนำกระแสไฟฟ้าหัวใจและหัวใจเต้นผิดจังหวะ']

# %%
dis = dis_list[4]

dis = 'Other congenital malformations of the nervous system (Q00-Q04, Q06-Q07)\nความผิดปกติอื่น ๆ แต่กำเนิดของระบบประสาท'

# %%
# calculate the rate by cause_of_in_pat by year, gender, region
in_pat_reg = in_pat.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
in_pat_reg['rate'] = in_pat_reg['number']/in_pat_reg['pop']

# reset index
in_pat_reg = in_pat_reg.reset_index()

one_disease = in_pat_reg[in_pat_reg['disease'] == dis]

# %%
_, ax = plt.subplots(2,1, figsize=(14,8))

df = one_disease[one_disease['gender']=='Female']
sns.lineplot(data=df, x='year', y='rate', hue='region', ax=ax[0], marker='o')

df = one_disease[one_disease['gender']=='Male']
sns.lineplot(data=df, x='year', y='rate', hue='region', ax=ax[1], marker='o')

for a, t in zip(ax, [dis + '\nFemale', 'Male']):
    a.set_title(t)
    a.legend(bbox_to_anchor=(1.05, 1.05))
    
plt.tight_layout()

# %% [markdown]
# ## Visualization Birth Defect

# %%
cause = in_pat['disease'].drop_duplicates().reset_index(drop=True)
birth_defect = cause[cause.str.contains('ครรภ์') | cause.str.contains('กำเนิด')| cause.str.contains('แรกเกิด')| cause.str.contains('ทารก')].to_list()
birth_defect = [ 
 'Other pregnancies with abortive outcome (O00-O02, O05-O08)\nการตั้งครรภ์อื่น ๆ ที่สิ้นสุดโดยการแท้ง',
 'Oedema, proteinuria and hypertensive disorders in pregnancy, childbirth and the puerperium (O10-O16)\nการบวม การมีโปรตีนในปัสสาวะ และความดันโลหิตสูงขณะตั้งครรภ์ ระยะคลอด และระยะหลังคลอด',
 'Other maternal care related to fetus and amniotic cavity and possible delivery problems (O30-O43, O47-O48)\nการดูแลมารดาอื่น ๆ ที่มีปัญหาเกี่ยวกับทารกในครรภ์ และถุงน้ำคร่ำ และปัญหาที่อาจจะเกิดได้ในระยะคลอด',
 'Other complications of pregnancy and delivery (O20-O29, O60-O63, O67-O71, O73-O75, O81-O84)\nภาวะแทรกซ้อนอื่น ๆของการตั้งครรภ์ และการคลอด',
 'Fetus and newborn affected by maternal factors and by complications of pregnancy, labour and delivery (P00-P04)\nทารกในครรภ์และแรกเกิดที่ได้รับผลจากปัจจัยทางมารดา และโรคแทรกในระยะตั้งครรภ์ เจ็บครรภ์ และคลอด',
 'Slow fetal growth, fetal malnutrition and disorders related to short gestation and low birth weight (P05-P07)\nทารกในครรภ์โตช้า ทารกในครรภ์ขาดสารอาหาร และความผิดปกติเกี่ยวกับการตั้งครรภ์ระยะสั้น และน้ำหนักทารกแรกเกิดน้อย',
 'Intrauterine hypoxia and birth asphyxia (P20-P21)\nขาดออกซิเจนขณะอยู่ในโพรงมดลูก และภาวะแอสฟิกเซียเมื่อแรกเกิด',
 'Other infections specIfic to the perinatal period (P38-P39)\nการติดเชื้อเฉพาะอื่น ๆ ในระยะปริกำเนิด',
 'Haemolytic disease of fetus and newborn (P55)\nโรคเม็ดเลือดแตกของทารกในครรภ์และแรกเกิด',
 'Other conditions originating in the perinatal period (P08, P29, P50-P54, P56-P96)\nภาวะอื่น ๆ ในระยะปริกำเนิด',
 'Other congenital malformations of the nervous system (Q00-Q04, Q06-Q07)\nความผิดปกติอื่น ๆ แต่กำเนิดของระบบประสาท',
 'Congenital malformation of the circulatory system (Q20-Q28)\nความผิดปกติแต่กำเนิดของระบบไหลเวียนโลหิต',
 'Other congenital malformations of the digestive system (Q38-Q40, Q42-Q45)\nความผิดปกติแต่กำเนิดอื่น ๆ ของระบบย่อยอาหาร',
 'Congenital deformities of hip (Q65)\nความพิการแต่กำเนิดของสะโพก',
 'Congenital deformities of feet (Q66)\nความพิการแต่กำเนิดของเท้า',
 'Other congenital malformations and deformations of the musculoskeletal system (Q67-Q79)\nความผิดปกติและความพิการแต่กำเนิดอื่น ๆ ของระบบกล้ามเนื้อและโครงร่าง',
 'Other congenital malformations (Q10-Q18, Q30-Q34, Q80-Q89)\nความผิดปกติแต่กำเนิดอื่น ๆ']

# %%
# global average
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
in_pat_3reg = in_pat[in_pat['region'].isin(region_to_compare)]

# calculate the rate by cause_of_dead by year, gender, region
in_pat_3reg = in_pat_3reg.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
in_pat_3reg['rate'] = in_pat_3reg['number']/in_pat_3reg['birth_number']

# calculate average over the years
in_pat_3reg = in_pat_3reg.reset_index()
#in_pat_3reg_global = in_pat_3reg.groupby([ 'gender', 'disease', 'region' ], as_index=False).mean() 

in_pat_3reg_global = in_pat_3reg[in_pat_3reg['disease'].isin(birth_defect)]

# %%
# selected provinces in near income range
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
in_pat_3reg = in_pat[in_pat['region'].isin(region_to_compare) & in_pat['province'].isin(near_income_list)]

# calculate the rate by cause_of_dead by year, gender, region
in_pat_3reg = in_pat_3reg.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
in_pat_3reg['rate'] = in_pat_3reg['number']/in_pat_3reg['birth_number']

# calculate average over the years
in_pat_3reg = in_pat_3reg.reset_index()
#in_pat_3reg_spec = in_pat_3reg.groupby([ 'gender', 'disease', 'region' ], as_index=False).mean() 

# select only birth defect 
in_pat_3reg_spec = in_pat_3reg[in_pat_3reg['disease'].isin(birth_defect)]

# %%
significant_df1 = []
for year, gender, cause in zip(in_pat_3reg_global['year'], in_pat_3reg_global['gender'], in_pat_3reg_global['disease']):
    temp = in_pat_3reg_global[(in_pat_3reg_global['year']==year) & (in_pat_3reg_global['gender']==gender) & (in_pat_3reg_global['disease']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        significant_df1.append([year, gender, cause, z1, z2, z3, row_n['rate']/row_s['rate'], row_ne['rate']/row_s['rate'], row_c['rate']/row_s['rate']] )
        
significant_df1 = pd.DataFrame(significant_df1, columns=['year', 'gender', 'disease', 'z_NE', 'z_N', 'z_C', 'ratio_north_south', 'ratio_northeast_south',  'ratio_central_south'])

# %%
significant_df2 = []
for year, gender, cause in zip(in_pat_3reg_spec['year'], in_pat_3reg_spec['gender'], in_pat_3reg_spec['disease']):
    temp = in_pat_3reg_spec[(in_pat_3reg_spec['year']==year) & (in_pat_3reg_spec['gender']==gender) & (in_pat_3reg_spec['disease']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        significant_df2.append([year, gender, cause, z1, z2, z3]  )
        
significant_df2 = pd.DataFrame(significant_df2, columns=['year', 'gender', 'disease', 'z_NE_spec', 'z_N_spec', 'z_C_spec' ])

# %%
significant_df = significant_df1.merge(significant_df2, on=['year','gender','disease'])

# %%
significant_avg = significant_df.groupby(['gender','disease'], as_index=False).mean()

# %%
significant_avg[significant_avg['ratio_north_south'] > 1]['disease'].unique().tolist()
# Out:
# ['Congenital deformities of hip (Q65)\nความพิการแต่กำเนิดของสะโพก',
#  'Other congenital malformations of the digestive system (Q38-Q40, Q42-Q45)\nความผิดปกติแต่กำเนิดอื่น ๆ ของระบบย่อยอาหาร',
#  'Other congenital malformations of the nervous system (Q00-Q04, Q06-Q07)\nความผิดปกติอื่น ๆ แต่กำเนิดของระบบประสาท',
#  'Other conditions originating in the perinatal period (P08, P29, P50-P54, P56-P96)\nภาวะอื่น ๆ ในระยะปริกำเนิด',
#  'Other congenital malformations and deformations of the musculoskeletal system (Q67-Q79)\nความผิดปกติและความพิการแต่กำเนิดอื่น ๆ ของระบบกล้ามเนื้อและโครงร่าง']

# %%
significant_avg[(significant_avg['z_N_spec']> 1.96) & (significant_avg['z_NE_spec']> 1.96) & (significant_avg['z_C_spec']> 1.96)]['disease'].unique().tolist()
# Out:
# ['Haemolytic disease of fetus and newborn (P55)\nโรคเม็ดเลือดแตกของทารกในครรภ์และแรกเกิด',
#  'Other conditions originating in the perinatal period (P08, P29, P50-P54, P56-P96)\nภาวะอื่น ๆ ในระยะปริกำเนิด',
#  'Other congenital malformations (Q10-Q18, Q30-Q34, Q80-Q89)\nความผิดปกติแต่กำเนิดอื่น ๆ',
#  'Other pregnancies with abortive outcome (O00-O02, O05-O08)\nการตั้งครรภ์อื่น ๆ ที่สิ้นสุดโดยการแท้ง',
#  'Other infections specIfic to the perinatal period (P38-P39)\nการติดเชื้อเฉพาะอื่น ๆ ในระยะปริกำเนิด']

# %%
significant_avg[significant_avg['disease'].isin(['Haemolytic disease of fetus and newborn (P55)\nโรคเม็ดเลือดแตกของทารกในครรภ์และแรกเกิด',
 'Other conditions originating in the perinatal period (P08, P29, P50-P54, P56-P96)\nภาวะอื่น ๆ ในระยะปริกำเนิด',
 'Other congenital malformations (Q10-Q18, Q30-Q34, Q80-Q89)\nความผิดปกติแต่กำเนิดอื่น ๆ',
 'Other pregnancies with abortive outcome (O00-O02, O05-O08)\nการตั้งครรภ์อื่น ๆ ที่สิ้นสุดโดยการแท้ง',
 'Other infections specIfic to the perinatal period (P38-P39)\nการติดเชื้อเฉพาะอื่น ๆ ในระยะปริกำเนิด'])]
# Out:
#     gender                                            disease         year  \
# 4   Female  Haemolytic disease of fetus and newborn (P55)\...  2012.727273
# 8   Female  Other conditions originating in the perinatal ...  2012.727273
# 9   Female  Other congenital malformations (Q10-Q18, Q30-Q...  2012.727273
# 13  Female  Other infections specIfic to the perinatal per...  2012.727273
# 15  Female  Other pregnancies with abortive outcome (O00-O...  2012.727273
# 21    Male  Haemolytic disease of fetus and newborn (P55)\...  2012.727273
# 25    Male  Other conditions originating in the perinatal ...  2012.727273
# 26    Male  Other congenital malformations (Q10-Q18, Q30-Q...  2012.727273
# 30    Male  Other infections specIfic to the perinatal per...  2012.727273
# 32    Male  Other pregnancies with abortive outcome (O00-O...  2012.500000
#
#           z_NE         z_N         z_C  ratio_north_south  \
# 4    24.365610   -8.733381   25.128026           0.925125
# 8   266.326318  216.204502  107.577207           1.578406
# 9     4.562897   12.168843  -22.561935           1.157979
# 13    7.692395    7.061355   17.849751           1.121127
# 15 -140.831689  -55.109038 -173.093127           0.866207
# 21   22.373217   -9.326228   26.911152           0.928711
# 25  285.387910  251.175266  118.762341           1.634647
# 26   12.462524   20.449501  -17.072334           1.286327
# 30   12.838307   14.119168   25.843502           1.228555
# 32         NaN         NaN         NaN                NaN
#
#     ratio_northeast_south  ratio_central_south   z_NE_spec    z_N_spec  \
# 4                1.281418             1.310414   25.504767   14.443992
# 8                1.676735             1.263399  146.958417   97.751837
# 9                1.053166             0.762427   11.495065   35.932012
# 13               1.112992             1.303081    0.864230   12.903559
# 15               0.709879             0.614523   43.826011   56.296522
# 21               1.292654             1.369625   19.248862   12.542688
# 25               1.673471             1.272994  152.500054  112.259057
# 26               1.157953             0.810070   16.382514   41.641854
# 30               1.184399             1.432046    2.188610   18.097442
# 32                    NaN                  NaN         NaN         NaN
#
#       z_C_spec
# 4    36.078251
# 8   111.531149
# 9     6.804605
# 13   22.729601
# 15   43.684768
# 21   29.399478
# 25  112.263862
# 26   14.946958
# 30   26.955453
# 32         NaN

# %%
significant_avg[significant_avg['disease'].isin(['Congenital deformities of hip (Q65)\nความพิการแต่กำเนิดของสะโพก',
 'Other congenital malformations of the digestive system (Q38-Q40, Q42-Q45)\nความผิดปกติแต่กำเนิดอื่น ๆ ของระบบย่อยอาหาร',
 'Other congenital malformations of the nervous system (Q00-Q04, Q06-Q07)\nความผิดปกติอื่น ๆ แต่กำเนิดของระบบประสาท',
 'Other conditions originating in the perinatal period (P08, P29, P50-P54, P56-P96)\nภาวะอื่น ๆ ในระยะปริกำเนิด',
 'Other congenital malformations and deformations of the musculoskeletal system (Q67-Q79)\nความผิดปกติและความพิการแต่กำเนิดอื่น ๆ ของระบบกล้ามเนื้อและโครงร่าง'])]
# Out:
#     gender                                            disease         year  \
# 1   Female  Congenital deformities of hip (Q65)\nความพิการ...  2012.500000
# 8   Female  Other conditions originating in the perinatal ...  2012.727273
# 10  Female  Other congenital malformations and deformation...  2012.727273
# 11  Female  Other congenital malformations of the digestiv...  2012.727273
# 12  Female  Other congenital malformations of the nervous ...  2012.727273
# 18    Male  Congenital deformities of hip (Q65)\nความพิการ...  2012.500000
# 25    Male  Other conditions originating in the perinatal ...  2012.727273
# 27    Male  Other congenital malformations and deformation...  2012.727273
# 28    Male  Other congenital malformations of the digestiv...  2012.727273
# 29    Male  Other congenital malformations of the nervous ...  2012.727273
#
#          z_NE       z_N       z_C  ratio_north_south  ratio_northeast_south  \
# 1   -0.207854 -0.270470 -1.476543           1.062832               1.123069
# 8   10.352102 -0.965765  5.404155           0.988691               1.156234
# 10  -0.381376 -0.445119 -2.948039           0.957886               0.974917
# 11  -2.446309 -1.692092  4.433207           1.037870               0.901686
# 12  -0.859456  0.269661 -0.505386           1.083302               0.891783
# 18  -0.068982 -0.665720 -1.186664           0.713431               1.037227
# 25   9.055654  1.789552  6.969262           1.028054               1.123856
# 27  -0.397996 -0.106491 -2.530668           1.001812               0.971466
# 28  -3.474699 -2.772813  4.819090           0.960364               0.873040
# 29  -0.457134  1.247204 -0.585487           1.282518               0.949537
#
#     ratio_central_south  z_NE_spec   z_N_spec  z_C_spec
# 1              0.606232  -0.776038   1.571441 -0.918018
# 8              1.088723  -3.444969 -10.403323 -0.042650
# 10             0.730791  -1.225034   2.104230 -1.609153
# 11             1.418402  -6.533257   1.605861 -0.974173
# 12             0.934002  -1.544603   0.956582 -1.129397
# 18             0.530503  -0.144048   1.059983 -0.645116
# 25             1.103567  -5.482895  -9.729976  0.588077
# 27             0.777295  -1.697294   2.052717 -1.244227
# 28             1.353196  -7.719477   1.701684 -0.400187
# 29             0.925558  -1.869519   1.251424 -1.273187

# %% [markdown]
# # Out Patient

# %%
population = pd.read_csv(mdataset.health_folder  + 'process/pop_prov.csv')  
population = population.drop(['province_th', 'gender_th'], axis=1)

pop = population.melt(id_vars=['province', 'gender'], var_name='year', value_name='pop')
pop['year'] = pop['year'].astype(int)
out_pat = pd.read_csv(mdataset.health_folder + 'process/out_patient_2007_2019.csv').dropna()
out_pat['gender'] = 'Total'
# add population 
out_pat = out_pat.merge(pop, on=['province', 'gender', 'year'], how='left')

# add birth rate

birth_rate = pd.read_csv(mdataset.health_folder  + 'process/birth_prov.csv')
birth_rate = birth_rate.rename(columns={'number':'birth_number'})

out_pat = out_pat.merge(birth_rate, on=['province',  'year'], how='left')

# load provinces & region information 
provinces = mdataset.prov_map[['region', 'province']]

region_list = ['Northern Region', 'Northeastern Region', 'Central Region','Greater Bangkok','Southern Region']

# add region
out_pat = out_pat.merge(provinces, on='province', how='left')

# %%
out_pat['disease'].unique().shape
# Out:
# (21,)

# %%
birth_defect = ['ภาวะแทรกในการตั้งครรภ์ การคลอด และระยะหลังคลอด (O00-O99) ยกเว้น (080-084)',
       'ภาวะผิดปกติของทารกที่เกิดขึ้นในระยะปริกำเนิด (อายุครรภ์ 22 สัปดาห์ขึ้นไปจนถึง 7 วันหลังคลอด) (P00-P96) Certain conditions originating in the perinatal period ',
       'รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำเนิดและโครโมโซม  ผิดปกติ (Q00-Q99) Congenital malformations, deformations and chromosomal abnormalities']

# %% [markdown]
# ## Compare Region

# %%
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
out_pat_3reg = out_pat[out_pat['region'].isin(region_to_compare)]

# calculate the rate by cause_of_dead by year, gender, region
out_pat_3reg = out_pat_3reg.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
out_pat_3reg['rate'] = out_pat_3reg['number']/out_pat_3reg['pop']

# %%
# calculate average over the years
out_pat_3reg = out_pat_3reg.reset_index()
out_pat_3reg = out_pat_3reg.groupby([ 'gender', 'disease', 'region' ], as_index=False).mean()

# %%
out_pat_3reg
# Out:
#    gender                                            disease  \
# 0   Total  การเป็นพิษและผลที่ตามมา (X40-X49, X60-X69, X85...
# 1   Total  การเป็นพิษและผลที่ตามมา (X40-X49, X60-X69, X85...
# 2   Total  การเป็นพิษและผลที่ตามมา (X40-X49, X60-X69, X85...
# 3   Total  การเป็นพิษและผลที่ตามมา (X40-X49, X60-X69, X85...
# 4   Total  ภาวะผิดปกติของทารกที่เกิดขึ้นในระยะปริกำเนิด (...
# ..    ...                                                ...
# 79  Total  โรคเกี่ยวกับต่อมไร้ท่อ โภชนการ และเมตะบอลิสัม(...
# 80  Total  โรคเลือดและอวัยวะสร้างเลือด และความผิดปกติเกี่...
# 81  Total  โรคเลือดและอวัยวะสร้างเลือด และความผิดปกติเกี่...
# 82  Total  โรคเลือดและอวัยวะสร้างเลือด และความผิดปกติเกี่...
# 83  Total  โรคเลือดและอวัยวะสร้างเลือด และความผิดปกติเกี่...
#
#                  region         year        code        number           pop  \
# 0        Central Region  2011.222222  836.000000  7.788990e+04  2.552825e+07
# 1   Northeastern Region  2011.222222  705.111111  6.717051e+04  4.135143e+07
# 2       Northern Region  2011.222222  646.000000  1.325694e+05  2.370353e+07
# 3       Southern Region  2011.222222  523.555556  2.671060e+04  1.774826e+07
# 4        Central Region  2011.222222  704.000000  3.975607e+04  2.552825e+07
# ..                  ...          ...         ...           ...           ...
# 79      Southern Region  2011.222222  110.222222  2.587803e+06  1.774826e+07
# 80       Central Region  2011.222222  132.000000  2.586651e+05  2.552825e+07
# 81  Northeastern Region  2011.222222  111.333333  4.155870e+05  4.135143e+07
# 82      Northern Region  2011.222222  102.000000  2.655913e+05  2.370353e+07
# 83      Southern Region  2011.222222   82.666667  1.411453e+05  1.774826e+07
#
#         rate
# 0   0.003095
# 1   0.001654
# 2   0.005611
# 3   0.001546
# 4   0.001554
# ..       ...
# 79  0.143853
# 80  0.010095
# 81  0.009995
# 82  0.011194
# 83  0.007897
#
# [84 rows x 8 columns]

# %%
significant_df1 = []
for gender, cause in zip(out_pat_3reg['gender'], out_pat_3reg['disease']):
    temp = out_pat_3reg[(out_pat_3reg['gender']==gender) & (out_pat_3reg['disease']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        if (z1 >= 1.96) & (z2>= 1.96) & (z3>= 1.96):
            significant_df1.append([gender, cause, z1, z2, z3, row_n['rate']/row_s['rate'], row_ne['rate']/row_s['rate'], row_c['rate']/row_s['rate']] )
        
significant_df1 = pd.DataFrame(significant_df1, columns=['gender', 'disease', 'z_NE', 'z_N', 'z_C', 'ratio_north_south', 'ratio_northeast_south',  'ratio_central_south'])

# z2 should be more than z1
significant_df1['north_higher_than_ne_c'] =  (significant_df1['z_N'] > significant_df1['z_NE']) & (significant_df1['z_N'] > significant_df1['z_C']) 
significant_df1 = significant_df1[significant_df1['north_higher_than_ne_c'] == True]
significant_df1 = significant_df1.drop_duplicates()

# %%
significant_df1['disease'].unique()
# Out:
# array(['การเป็นพิษและผลที่ตามมา (X40-X49, X60-X69, X85-X90) Poisoning, toxic effect, and their sequelae',
#        'สาเหตุจากภายนอกอื่นๆ ที่ทำให้ป่วยหรือตาย (W00-W99, X00-X19, X20-X29, X30-X39, X50-X59, X70-X84, X91-X99, Y00-Y09, Y20-Y36, Y40-Y84, Y86-Y89) Other external causes of morbidity and mortality (eg: accidents, injuries, intentional self-harm, assault, animals and plants, complications of medical and surgical care and other unspecified causes)',
#        'เนื้องอก (รวมมะเร็ง) (C00-C97, D00-D48) Neoplasms',
#        'โรคระบบกล้ามเนื้อ รวมโครงร่าง และเนื้อยึดเสริม (M00-M99) Diseases of the musculoskeletal system and connective tissue',
#        'โรคระบบประสาท (G00-G99) Diseases of the mervous system',
#        'โรคระบบย่อยอาหาร รวมโรคในช่องปาก (K00-K93) Diseases of the digestive system',
#        'โรคระบบสืบพันธุ์ร่วมปัสสาวะ (N00-N99) Diseases of the genitourinary system',
#        'โรคเกี่ยวกับต่อมไร้ท่อ โภชนการ และเมตะบอลิสัม(E00-E90) Endocrine, mutritional and metabolic diseases',
#        'โรคเลือดและอวัยวะสร้างเลือด และความผิดปกติเกี่ยวกับภูมิคุ้มกัน(D50-D89) Diseases of the blood and blood forming organs andcertain disorders involving tne immune mechanism'],
#       dtype=object)

# %%
remove_list = ['การเป็นพิษและผลที่ตามมา (X40-X49, X60-X69, X85-X90) Poisoning, toxic effect, and their sequelae',       'สาเหตุจากภายนอกอื่นๆ ที่ทำให้ป่วยหรือตาย (W00-W99, X00-X19, X20-X29, X30-X39, X50-X59, X70-X84, X91-X99, Y00-Y09, Y20-Y36, Y40-Y84, Y86-Y89) Other external causes of morbidity and mortality (eg: accidents, injuries, intentional self-harm, assault, animals and plants, complications of medical and surgical care and other unspecified causes)',
       'โรคติดเชื้อและปรสิต (A00-A99, B00-B99 )Certain infectious and parasitic diseases',
       'โรคระบบกล้ามเนื้อ รวมโครงร่าง และเนื้อยึดเสริม (M00-M99) Diseases of the musculoskeletal system and connective tissue',
        'โรคระบบย่อยอาหาร รวมโรคในช่องปาก (K00-K93) Diseases of the digestive system',
       'โรคระบบสืบพันธุ์ร่วมปัสสาวะ (N00-N99) Diseases of the genitourinary system',
       'โรคเกี่ยวกับต่อมไร้ท่อ โภชนการ และเมตะบอลิสัม(E00-E90) Endocrine, mutritional and metabolic diseases' ]

significant_df1 = significant_df1[~significant_df1['disease'].isin(remove_list)]

# %% [markdown]
#  ## Compare Provinces with similar income

# %%
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
out_pat_3reg = out_pat[out_pat['region'].isin(region_to_compare) & out_pat['province'].isin(near_income_list) ]

# calculate the rate by cause_of_dead by year, gender, region
out_pat_3reg = out_pat_3reg.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
out_pat_3reg['rate'] = out_pat_3reg['number']/out_pat_3reg['pop']

# %%
# calculate average over the years
out_pat_3reg = out_pat_3reg.reset_index()
out_pat_3reg = out_pat_3reg.groupby([ 'gender', 'disease', 'region' ], as_index=False).mean()

# %%
significant_df2 = []
for gender, cause in zip(out_pat_3reg['gender'], out_pat_3reg['disease']):
    temp = out_pat_3reg[(out_pat_3reg['gender']==gender) & (out_pat_3reg['disease']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        if (z1 >= 1.96) & (z2>= 1.96) & (z3>= 1.96):
            significant_df2.append([gender, cause, z1, z2, z3 ] )
        
significant_df2 = pd.DataFrame(significant_df2, columns=['gender', 'disease', 'z_NE_income', 'z_N_income', 'z_C_income' ])

significant_df2 = significant_df2.drop_duplicates()

# %%
remove_list = ['การเป็นพิษและผลที่ตามมา (X40-X49, X60-X69, X85-X90) Poisoning, toxic effect, and their sequelae',       'สาเหตุจากภายนอกอื่นๆ ที่ทำให้ป่วยหรือตาย (W00-W99, X00-X19, X20-X29, X30-X39, X50-X59, X70-X84, X91-X99, Y00-Y09, Y20-Y36, Y40-Y84, Y86-Y89) Other external causes of morbidity and mortality (eg: accidents, injuries, intentional self-harm, assault, animals and plants, complications of medical and surgical care and other unspecified causes)',
       'โรคติดเชื้อและปรสิต (A00-A99, B00-B99 )Certain infectious and parasitic diseases',
       'โรคระบบกล้ามเนื้อ รวมโครงร่าง และเนื้อยึดเสริม (M00-M99) Diseases of the musculoskeletal system and connective tissue',
        'โรคระบบย่อยอาหาร รวมโรคในช่องปาก (K00-K93) Diseases of the digestive system',
       'โรคระบบสืบพันธุ์ร่วมปัสสาวะ (N00-N99) Diseases of the genitourinary system',
       'โรคเกี่ยวกับต่อมไร้ท่อ โภชนการ และเมตะบอลิสัม(E00-E90) Endocrine, mutritional and metabolic diseases' ]

significant_df2 = significant_df2[~significant_df2['disease'].isin(remove_list)]

# %%
significant_df1.shape
# Out:
# (3, 9)

# %%
significant_df2.shape
# Out:
# (9, 5)

# %%
significant_df_merge = significant_df1.merge(significant_df2, on=['gender', 'disease'], how='inner')
significant_df_merge.shape
# Out:
# (3, 12)

# %%
significant_df_merge.to_csv(mdataset.health_folder  + 'process/' + 'out_patient_narrow.csv', index=False, encoding='utf-8')

# %%
significant_df_merge
# Out:
#   gender                                            disease       z_NE  \
# 0  Total  เนื้องอก (รวมมะเร็ง) (C00-C97, D00-D48) Neoplasms  96.180588
# 1  Total  โรคระบบประสาท (G00-G99) Diseases of the mervou...  21.354010
# 2  Total  โรคเลือดและอวัยวะสร้างเลือด และความผิดปกติเกี่...  76.757368
#
#           z_N         z_C  ratio_north_south  ratio_northeast_south  \
# 0  175.703333  129.085686           1.696929               1.323174
# 1  233.173837  224.021617           1.585392               1.042707
# 2  106.710433   74.489633           1.417447               1.265658
#
#    ratio_central_south  north_higher_than_ne_c  z_NE_income  z_N_income  \
# 0             1.483509                    True    89.783196  147.929569
# 1             1.551883                    True    85.582229  175.371400
# 2             1.278217                    True    86.759639  103.600696
#
#    z_C_income
# 0  110.074564
# 1  186.856497
# 2   65.540236

# %% [markdown]
# ## Vis Birth Defect

# %%
birth_defect = ['ภาวะแทรกในการตั้งครรภ์ การคลอด และระยะหลังคลอด (O00-O99) ยกเว้น (080-084)',
       'ภาวะผิดปกติของทารกที่เกิดขึ้นในระยะปริกำเนิด (อายุครรภ์ 22 สัปดาห์ขึ้นไปจนถึง 7 วันหลังคลอด) (P00-P96) Certain conditions originating in the perinatal period ',
       'รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำเนิดและโครโมโซม  ผิดปกติ (Q00-Q99) Congenital malformations, deformations and chromosomal abnormalities']

# %%
# global average
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
out_pat_3reg = out_pat[out_pat['region'].isin(region_to_compare)]
out_pat_3reg = out_pat_3reg.dropna()

# calculate the rate by cause_of_dead by year, gender, region
out_pat_3reg = out_pat_3reg.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
out_pat_3reg['rate'] = out_pat_3reg['number']/out_pat_3reg['birth_number']

# calculate average over the years
out_pat_3reg = out_pat_3reg.reset_index()
#out_pat_3reg_global = out_pat_3reg.groupby([ 'gender', 'disease', 'region' ], as_index=False).mean() 

out_pat_3reg_global = out_pat_3reg[out_pat_3reg['disease'].isin(birth_defect)]

# %%
# selected provinces in near income range
region_to_compare = ['Northern Region', 'Northeastern Region', 'Southern Region', 'Central Region']

# pick only three regions
out_pat_3reg = out_pat[out_pat['region'].isin(region_to_compare) & out_pat['province'].isin(near_income_list)]
out_pat_3reg = out_pat_3reg.dropna()

# calculate the rate by cause_of_dead by year, gender, region
out_pat_3reg = out_pat_3reg.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
out_pat_3reg['rate'] = out_pat_3reg['number']/out_pat_3reg['birth_number']

# calculate average over the years
out_pat_3reg = out_pat_3reg.reset_index()
#out_pat_3reg_spec = out_pat_3reg.groupby([ 'gender', 'disease', 'region' ], as_index=False).mean() 

# select only birth defect 
out_pat_3reg_spec = out_pat_3reg[out_pat_3reg['disease'].isin(birth_defect)]

# %%
significant_df1 = []

for year, gender, cause in zip(out_pat_3reg_global['year'], out_pat_3reg_global['gender'], out_pat_3reg_global['disease']):
    temp = out_pat_3reg_global[(out_pat_3reg_global['year']==year) & (out_pat_3reg_global['gender']==gender) & (out_pat_3reg_global['disease']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        significant_df1.append([year, gender, cause, z1, z2, z3, row_n['rate']/row_s['rate'], row_ne['rate']/row_s['rate'], row_c['rate']/row_s['rate']] )
        
significant_df1 = pd.DataFrame(significant_df1, columns=['year', 'gender', 'disease', 'z_NE', 'z_N', 'z_C', 'ratio_north_south', 'ratio_northeast_south',  'ratio_central_south'])

# %%
significant_df2 = []

for year, gender, cause in zip(out_pat_3reg_spec['year'], out_pat_3reg_spec['gender'], out_pat_3reg_spec['disease']):
    temp = out_pat_3reg_spec[(out_pat_3reg_spec['year']==year) & (out_pat_3reg_spec['gender']==gender) & (out_pat_3reg_spec['disease']==cause )]
    temp = temp.set_index('region')
    if len(temp) == 4:
        row_ne = temp.loc['Northeastern Region']
        row_s = temp.loc['Southern Region']
        z1 = cal_1z_test(row_ne, row_s) 
        
        row_n = temp.loc['Northern Region']
        
        z2 = cal_1z_test(row_n, row_s) 
        
        row_c = temp.loc['Central Region']
      
        z3 = cal_1z_test(row_c, row_s) 
        
        significant_df2.append([year, gender, cause, z1, z2, z3]  )
        
significant_df2 = pd.DataFrame(significant_df2, columns=['year', 'gender', 'disease', 'z_NE_spec', 'z_N_spec', 'z_C_spec' ])

# %%
significant_df = significant_df1.merge(significant_df2, on=['year','gender','disease'])

# %%
significant_avg = significant_df.groupby(['gender','disease'], as_index=False).mean()

# %%
significant_avg[significant_avg['ratio_north_south'] > 1]['disease'].unique().tolist()
# Out:
# ['ภาวะผิดปกติของทารกที่เกิดขึ้นในระยะปริกำเนิด (อายุครรภ์ 22 สัปดาห์ขึ้นไปจนถึง 7 วันหลังคลอด) (P00-P96) Certain conditions originating in the perinatal period ',
#  'รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำเนิดและโครโมโซม  ผิดปกติ (Q00-Q99) Congenital malformations, deformations and chromosomal abnormalities']

# %%
significant_avg[(significant_avg['z_N']> 1.96) | (significant_avg['z_N_spec']> 1.96)]['disease'].unique().tolist()
# Out:
# ['ภาวะผิดปกติของทารกที่เกิดขึ้นในระยะปริกำเนิด (อายุครรภ์ 22 สัปดาห์ขึ้นไปจนถึง 7 วันหลังคลอด) (P00-P96) Certain conditions originating in the perinatal period ',
#  'รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำเนิดและโครโมโซม  ผิดปกติ (Q00-Q99) Congenital malformations, deformations and chromosomal abnormalities']

# %%
significant_avg[['disease','ratio_north_south',
       'ratio_northeast_south', 'ratio_central_south']]
# Out:
#                                              disease  ratio_north_south  \
# 0  ภาวะผิดปกติของทารกที่เกิดขึ้นในระยะปริกำเนิด (...           2.173845
# 1  ภาวะแทรกในการตั้งครรภ์ การคลอด และระยะหลังคลอด...           0.794386
# 2  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...           1.429420
#
#    ratio_northeast_south  ratio_central_south
# 0               2.196286             1.412691
# 1               0.832294             0.913451
# 2               1.260865             1.050223

# %%
significant_avg
# Out:
#   gender                                            disease         year  \
# 0  Total  ภาวะผิดปกติของทารกที่เกิดขึ้นในระยะปริกำเนิด (...  2012.285714
# 1  Total  ภาวะแทรกในการตั้งครรภ์ การคลอด และระยะหลังคลอด...  2012.285714
# 2  Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...  2012.285714
#
#          z_NE         z_N         z_C  ratio_north_south  \
# 0  942.320347  941.441028  370.729482           2.173845
# 1 -933.377998 -957.199587 -464.210954           0.794386
# 2  345.180795  525.229772   62.320043           1.429420
#
#    ratio_northeast_south  ratio_central_south   z_NE_spec    z_N_spec  \
# 0               2.196286             1.412691  601.250987  637.872608
# 1               0.832294             0.913451 -427.880943 -269.568315
# 2               1.260865             1.050223  210.887342  343.282089
#
#      z_C_spec
# 0  250.667188
# 1  310.142331
# 2  154.460962

# %% [markdown]
# ## Visualization

# %%
dis = 'ภาวะผิดปกติของทารกที่เกิดขึ้นในระยะปริกำเนิด (อายุครรภ์ 22 สัปดาห์ขึ้นไปจนถึง 7 วันหลังคลอด) (P00-P96) Certain conditions originating in the perinatal period '
#dis = 'รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำเนิดและโครโมโซม  ผิดปกติ (Q00-Q99) Congenital malformations, deformations and chromosomal abnormalities'

# %%
# calculate the rate by cause_of_out_pat by year, gender, region
out_pat_reg = out_pat.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
out_pat_reg['rate'] = out_pat_reg['number']/out_pat_reg['birth_number']

# reset index
out_pat_reg = out_pat_reg.reset_index()

one_disease = out_pat_reg[out_pat_reg['disease'] == dis]

# %%
_, ax = plt.subplots(1,1, figsize=(14,4))

df = one_disease[one_disease['gender']=='Total']
df = df[df['region'] !='Greater Bangkok']
sns.lineplot(data=df, x='year', y='rate', hue='region', ax=ax , marker='o')

title = dis = '(P00-P96) Certain conditions originating in the perinatal period '

ax.set_title(dis + '(Total)')
ax.legend(bbox_to_anchor=(1.05, 1.05))
    
plt.tight_layout()

# %%
# select year 
temp = out_pat[out_pat['year'].isin([2017])]
mean_rate = temp.groupby(['year', 'gender', 'disease', 'province']).sum()

# calcule rate
mean_rate['rate'] = mean_rate['number']/mean_rate['birth_number']*1000

# reset index
mean_rate = mean_rate.reset_index()
mean_rate = mean_rate[mean_rate['disease'] == dis]
 
# average of the rate
std_rate = mean_rate.groupby([ 'gender', 'disease', 'province'], as_index=False).std()

mean_rate = mean_rate.groupby([ 'gender', 'disease', 'province'], as_index=False).mean()


mean_rate = mean_rate.merge(std_rate, on=[ 'gender', 'disease', 'province'], suffixes=('', '_std'))

# create a map of pollution by merging with the shape file 
plot_map = mdataset.prov_map.merge(mean_rate, on='province', how='left')
plot_map
# Out:
#     admin1Name_en  admin1Name_th admin1Pcode admin1RefName admin1AltName1_en  \
# 0   Amnat Charoen     อำนาจเจริญ        TH37          None              None
# 1       Ang Thong        อ่างทอง        TH15          None              None
# 2         Bangkok  กรุงเทพมหานคร        TH10          None              None
# 3       Bueng Kan         บึงกาฬ        TH38          None              None
# 4        Buri Ram      บุรีรัมย์        TH31          None              None
# ..            ...            ...         ...           ...               ...
# 72     Udon Thani       อุดรธานี        TH41          None              None
# 73    Uthai Thani      อุทัยธานี        TH61          None              None
# 74      Uttaradit      อุตรดิตถ์        TH53          None              None
# 75           Yala           ยะลา        TH95          None              None
# 76       Yasothon          ยโสธร        TH35          None              None
#
#    admin1AltName2_en admin1AltName1_th admin1AltName2_th admin0Name_en  \
# 0               None              None              None      Thailand
# 1               None              None              None      Thailand
# 2               None              None              None      Thailand
# 3               None              None              None      Thailand
# 4               None              None              None      Thailand
# ..               ...               ...               ...           ...
# 72              None              None              None      Thailand
# 73              None              None              None      Thailand
# 74              None              None              None      Thailand
# 75              None              None              None      Thailand
# 76              None              None              None      Thailand
#
#    admin0Name_th  ...       number        pop birth_number        rate  \
# 0      ประเทศไทย  ...  2207.005857   756214.0       6062.0  364.072230
# 1      ประเทศไทย  ...   744.002644   562374.0       4056.0  183.432604
# 2      ประเทศไทย  ...          NaN        NaN          NaN         NaN
# 3      ประเทศไทย  ...  3545.008406   846064.0       7396.0  479.314279
# 4      ประเทศไทย  ...  7638.004809  3183810.0      26604.0  287.099865
# ..           ...  ...          ...        ...          ...         ...
# 72     ประเทศไทย  ...  4992.003169  3166184.0      28130.0  177.461897
# 73     ประเทศไทย  ...  2155.006537   659884.0       4954.0  435.003338
# 74     ประเทศไทย  ...  1533.003357   914184.0       6194.0  247.498120
# 75     ประเทศไทย  ...  2448.004677  1054590.0      20926.0  116.983880
# 76     ประเทศไทย  ...  2310.004282  1079084.0       7556.0  305.717878
#
#     year_std  code_std number_std pop_std birth_number_std rate_std
# 0        NaN       NaN        NaN     NaN              NaN      NaN
# 1        NaN       NaN        NaN     NaN              NaN      NaN
# 2        NaN       NaN        NaN     NaN              NaN      NaN
# 3        NaN       NaN        NaN     NaN              NaN      NaN
# 4        NaN       NaN        NaN     NaN              NaN      NaN
# ..       ...       ...        ...     ...              ...      ...
# 72       NaN       NaN        NaN     NaN              NaN      NaN
# 73       NaN       NaN        NaN     NaN              NaN      NaN
# 74       NaN       NaN        NaN     NaN              NaN      NaN
# 75       NaN       NaN        NaN     NaN              NaN      NaN
# 76       NaN       NaN        NaN     NaN              NaN      NaN
#
# [77 rows x 33 columns]

# %%
_, ax = plt.subplots(1, 1, figsize=(5,10))

df = plot_map[plot_map['gender']=='Total']

df.plot(column='rate',
           ax=ax,legend=True,
           legend_kwds={'label': "number per 1000 birth",
                       'orientation': "horizontal"},  cmap='RdYlGn_r',
             missing_kwds={
         "color": "lightgrey",
         "edgecolor": "red",
            "hatch": "///",
           "label": "Missing values" })

 
df.boundary.plot(ax=ax, color='black')


ax.set_title("Birth Defect (P00-P96)(Total)");

# %%
# select year 
temp = out_pat[out_pat['year'].isin(np.arange(2007,2020))]
mean_rate = temp.groupby(['year', 'gender', 'disease', 'province']).sum()
mean_rate = mean_rate[mean_rate['birth_number'] > 0]

# calcule rate
mean_rate['rate'] = mean_rate['number']/mean_rate['birth_number']*1000

# reset index
mean_rate = mean_rate.reset_index()
mean_rate = mean_rate[mean_rate['disease'] == dis]
 
# average of the rate
std_rate = mean_rate.groupby([ 'gender', 'disease', 'province'], as_index=False).std()

mean_rate = mean_rate.groupby([ 'gender', 'disease', 'province'], as_index=False).mean()


mean_rate = mean_rate.merge(std_rate, on=[ 'gender', 'disease', 'province'], suffixes=('', '_std'))
mean_rate
# Out:
#    gender                                            disease       province  \
# 0   Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...  Amnat Charoen
# 1   Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...      Ang Thong
# 2   Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...      Bueng Kan
# 3   Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...       Buri Ram
# 4   Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...   Chachoengsao
# ..    ...                                                ...            ...
# 71  Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...     Udon Thani
# 72  Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...    Uthai Thani
# 73  Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...      Uttaradit
# 74  Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...           Yala
# 75  Total  รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำ...       Yasothon
#
#            year  code       number           pop  birth_number        rate  \
# 0   2012.285714    34   703.144743  7.476746e+05   6932.571429  102.522046
# 1   2012.285714    34   625.287915  5.674877e+05   5307.428571  118.749361
# 2   2013.400000    34   916.202204  8.312324e+05   8920.800000  107.669318
# 3   2012.285714    34  4620.717240  3.134561e+06  31325.142857  149.781226
# 4   2012.285714    34  1395.716336  1.372457e+06  16208.285714   88.084223
# ..          ...   ...          ...           ...           ...         ...
# 71  2012.285714    34  4834.860252  3.116139e+06  32271.142857  153.401271
# 72  2012.285714    34  1094.717612  6.578489e+05   6059.714286  181.927429
# 73  2012.285714    34  1941.004195  9.218257e+05   7438.000000  263.162701
# 74  2012.285714    34  2772.148457  1.002183e+06  21393.714286  128.835160
# 75  2012.285714    34  1985.289384  1.079328e+06   9097.142857  212.619841
#
#     year_std  code_std   number_std       pop_std  birth_number_std  \
# 0   2.690371       0.0   175.163659   4906.391982        560.256744
# 1   2.690371       0.0   143.508594   2492.916212        694.792741
# 2   2.302173       0.0   328.169464  11696.764031       1301.874495
# 3   2.690371       0.0   936.314755  31174.086198       2489.825391
# 4   2.690371       0.0   687.094301  27775.717041       1061.694513
# ..       ...       ...          ...           ...               ...
# 71  2.690371       0.0  1978.379828  31120.106338       2137.632291
# 72  2.690371       0.0   284.654300   1969.551847        591.883354
# 73  2.690371       0.0   222.927993   3837.680971        629.442081
# 74  2.690371       0.0  1880.648759  31641.286314       1179.216366
# 75  2.690371       0.0  1062.206384   1237.991076        846.767860
#
#       rate_std
# 0    30.151793
# 1    29.313868
# 2    53.412919
# 3    39.861517
# 4    50.792796
# ..         ...
# 71   76.202111
# 72   48.034703
# 73   41.147198
# 74   84.968470
# 75  103.537162
#
# [76 rows x 15 columns]

# %%
fig, ax = plt.subplots(1,1, figsize=(14, 7), sharex=True)
#ax.bar(pm10_short_list['province'], pm10_short_list['avgPM10'])


for region in region_list:
    # select province
    prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
    # select only province near Chiang Mai
    # use province_list to keep the bar plot in the same order

    prov_in_region = [s for s in near_income_list if s in prov_in_region]
    df = mean_rate[mean_rate['province'].isin(prov_in_region) & (mean_rate['gender'] == 'Total')]
     
    if len(df) > 0:
        ax.bar(df['province'], df['rate'], yerr=df['rate_std'], label=region, edgecolor='black', capsize=10)
        
        
# highlight Chiang Mai
#df = dead_male_short.loc[['Chiang Mai']]
#ax[0].bar(df.index, df['lung_dead'], color='magenta', label='Chiang Mai', edgecolor='black')

#df = dead_female_short.loc[['Chiang Mai']]
#ax[1].bar(df.index, df['lung_dead'], color='magenta', label='Chiang Mai', edgecolor='black')

 
ax.legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()
ax.set_title('Birth Defect (P00-P96)(Total)')
ax.set_ylabel('rate per 1000 birth')
 
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);
ax.set_ylim([-10, 320])

plt.tight_layout()

# %%
dis = 'รูปร่างผิดปกติแต่กำเนิด  การพิการจนผิดรูปแต่กำเนิดและโครโมโซม  ผิดปกติ (Q00-Q99) Congenital malformations, deformations and chromosomal abnormalities'

# %%
# calculate the rate by cause_of_out_pat by year, gender, region
out_pat_reg = out_pat.groupby(['year', 'gender', 'disease', 'region' ]).sum()

# calcule rate
out_pat_reg['rate'] = out_pat_reg['number']/out_pat_reg['birth_number']

# reset index
out_pat_reg = out_pat_reg.reset_index()

one_disease = out_pat_reg[out_pat_reg['disease'] == dis]

# %%
_, ax = plt.subplots(1,1, figsize=(14,4))

df = one_disease[one_disease['gender']=='Total']
df = df[df['region'] !='Greater Bangkok']
sns.lineplot(data=df, x='year', y='rate', hue='region', ax=ax , marker='o')

title = dis = '(Q00-Q99) Congenital malformations,\n deformations and chromosomal abnormalities '

ax.set_title(dis + '(Total)')
ax.legend(bbox_to_anchor=(1.05, 1.05))
    
plt.tight_layout()

# %%
# select year 
temp = out_pat[out_pat['year'].isin([2017])]
mean_rate = temp.groupby(['year', 'gender', 'disease', 'province']).sum()

# calcule rate
mean_rate['rate'] = mean_rate['number']/mean_rate['birth_number']*1000

# reset index
mean_rate = mean_rate.reset_index()
mean_rate = mean_rate[mean_rate['disease'] == dis]
 
# average of the rate
std_rate = mean_rate.groupby([ 'gender', 'disease', 'province'], as_index=False).std()

mean_rate = mean_rate.groupby([ 'gender', 'disease', 'province'], as_index=False).mean()


mean_rate = mean_rate.merge(std_rate, on=[ 'gender', 'disease', 'province'], suffixes=('', '_std'))

# create a map of pollution by merging with the shape file 
plot_map = mdataset.prov_map.merge(mean_rate, on='province', how='left')
plot_map
# Out:
#     admin1Name_en  admin1Name_th admin1Pcode admin1RefName admin1AltName1_en  \
# 0   Amnat Charoen     อำนาจเจริญ        TH37          None              None
# 1       Ang Thong        อ่างทอง        TH15          None              None
# 2         Bangkok  กรุงเทพมหานคร        TH10          None              None
# 3       Bueng Kan         บึงกาฬ        TH38          None              None
# 4        Buri Ram      บุรีรัมย์        TH31          None              None
# ..            ...            ...         ...           ...               ...
# 72     Udon Thani       อุดรธานี        TH41          None              None
# 73    Uthai Thani      อุทัยธานี        TH61          None              None
# 74      Uttaradit      อุตรดิตถ์        TH53          None              None
# 75           Yala           ยะลา        TH95          None              None
# 76       Yasothon          ยโสธร        TH35          None              None
#
#    admin1AltName2_en admin1AltName1_th admin1AltName2_th admin0Name_en  \
# 0               None              None              None      Thailand
# 1               None              None              None      Thailand
# 2               None              None              None      Thailand
# 3               None              None              None      Thailand
# 4               None              None              None      Thailand
# ..               ...               ...               ...           ...
# 72              None              None              None      Thailand
# 73              None              None              None      Thailand
# 74              None              None              None      Thailand
# 75              None              None              None      Thailand
# 76              None              None              None      Thailand
#
#    admin0Name_th  ...       number        pop birth_number        rate  \
# 0      ประเทศไทย  ...   944.002505   756214.0       6062.0  155.724597
# 1      ประเทศไทย  ...   665.002363   562374.0       4056.0  163.955218
# 2      ประเทศไทย  ...          NaN        NaN          NaN         NaN
# 3      ประเทศไทย  ...  1463.003469   846064.0       7396.0  197.810096
# 4      ประเทศไทย  ...  5469.003443  3183810.0      26604.0  205.570720
# ..           ...  ...          ...        ...          ...         ...
# 72     ประเทศไทย  ...  8852.005620  3166184.0      28130.0  314.682034
# 73     ประเทศไทย  ...  1175.003564   659884.0       4954.0  237.182795
# 74     ประเทศไทย  ...  1990.004358   914184.0       6194.0  321.279360
# 75     ประเทศไทย  ...  4518.008632  1054590.0      20926.0  215.904073
# 76     ประเทศไทย  ...   870.001613  1079084.0       7556.0  115.140499
#
#     year_std  code_std number_std pop_std birth_number_std rate_std
# 0        NaN       NaN        NaN     NaN              NaN      NaN
# 1        NaN       NaN        NaN     NaN              NaN      NaN
# 2        NaN       NaN        NaN     NaN              NaN      NaN
# 3        NaN       NaN        NaN     NaN              NaN      NaN
# 4        NaN       NaN        NaN     NaN              NaN      NaN
# ..       ...       ...        ...     ...              ...      ...
# 72       NaN       NaN        NaN     NaN              NaN      NaN
# 73       NaN       NaN        NaN     NaN              NaN      NaN
# 74       NaN       NaN        NaN     NaN              NaN      NaN
# 75       NaN       NaN        NaN     NaN              NaN      NaN
# 76       NaN       NaN        NaN     NaN              NaN      NaN
#
# [77 rows x 33 columns]

# %%
_, ax = plt.subplots(1, 1, figsize=(5,10))

df = plot_map[plot_map['gender']=='Total']

df.plot(column='rate',
           ax=ax,legend=True,
           legend_kwds={'label': "number per 1000 birth",
                       'orientation': "horizontal"},  cmap='RdYlGn_r',
             missing_kwds={
         "color": "lightgrey",
         "edgecolor": "red",
            "hatch": "///",
           "label": "Missing values" })

 
df.boundary.plot(ax=ax, color='black')


ax.set_title("Birth Defect 2017 (Q00-Q99)(Total)");

# %%
# select year 
temp = out_pat[out_pat['year'].isin(np.arange(2007,2020))]
mean_rate = temp.groupby(['year', 'gender', 'disease', 'province']).sum()
mean_rate = mean_rate[mean_rate['birth_number'] > 0]


# calcule rate
mean_rate['rate'] = mean_rate['number']/mean_rate['birth_number']*1000

# reset index
mean_rate = mean_rate.reset_index()
mean_rate = mean_rate[mean_rate['disease'] == dis]
 
# average of the rate
std_rate = mean_rate.groupby([ 'gender', 'disease', 'province'], as_index=False).std()

mean_rate = mean_rate.groupby([ 'gender', 'disease', 'province'], as_index=False).mean()


mean_rate = mean_rate.merge(std_rate, on=[ 'gender', 'disease', 'province'], suffixes=('', '_std'))

# %%
fig, ax = plt.subplots(1,1, figsize=(14, 7), sharex=True)
#ax.bar(pm10_short_list['province'], pm10_short_list['avgPM10'])


for region in region_list:
    # select province
    prov_in_region = provinces[provinces['region'] == region]['province'].to_list()
    # select only province near Chiang Mai
    # use province_list to keep the bar plot in the same order

    prov_in_region = [s for s in near_income_list if s in prov_in_region]
    df = mean_rate[mean_rate['province'].isin(prov_in_region) & (mean_rate['gender'] == 'Total')]
     
    if len(df) > 0:
        ax.bar(df['province'], df['rate'], yerr=df['rate_std'], label=region, edgecolor='black', capsize=10)
        
        
# highlight Chiang Mai
#df = dead_male_short.loc[['Chiang Mai']]
#ax[0].bar(df.index, df['lung_dead'], color='magenta', label='Chiang Mai', edgecolor='black')

#df = dead_female_short.loc[['Chiang Mai']]
#ax[1].bar(df.index, df['lung_dead'], color='magenta', label='Chiang Mai', edgecolor='black')

 
ax.legend(bbox_to_anchor=(1.05, 1.0))
plt.draw()
ax.set_title('Birth Defect (Q00-Q99)(Total)')
ax.set_ylabel('rate per 1000 birth')
 
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);
ax.set_ylim([-10, 400])

plt.tight_layout()

# %% [markdown]
# # Data For Modeling (Lung Cancer)

# %% [markdown]
# - Yearly average PM2.5 pollution level by province. Fill the value of the missing province with the near by provinces.
# - Gender
# - Literacy rate : educated people tend to avoid going outside during the pollution season
# - Average income (scaled by the average of the same year)
# - Smoking rate : for lung-related illness
# - Population ratio breakdown by ages (need to put together the data first)

# %%
mdataset = MapDataset('Thailand')
mdataset.load_()

# build or load pollution by province and add as .poll attribute
mdataset.load_poll_prov(pollutant='PM2.5')

# calculate the yearly average only during the winter season
#poll attributes 
poll = mdataset.poll
poll = add_season(poll, start_month='-10-01', end_month='-04-30')
# keep only winter season 
poll = poll[poll['season'] != 'other']

# %%
poll['year'].unique()
# Out:
# array([2004, 2005, 2006, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020])

# %%
mean_poll = poll.groupby('year').mean()

# %%
# calcuale mean 
fill_mean = mean_poll.mean(axis=0).round(0)
#fill_mean = fill_mean.to_dict()

# %%
missing_list1 = (['Amnat Charoen', 'Ang Thong', 'Bueng Kan', 'Buri Ram', 'Chachoengsao',
       'Chai Nat', 'Lamphun', 'Mae Hong Son', 'Mukdahan', 'Nakhon Nayok',
       'Nakhon Phanom', 'Narathiwat', 'Nong Bua Lam Phu', 'Nonthaburi',
       'Pathum Thani', 'Phayao', 'Phetchaburi', 'Phichit', 'Phrae',
       'Prachuap Khiri Khan', 'Roi Et', 'Samut Songkhram', 'Satun',
       'Si Sa Ket', 'Sukhothai', 'Trat', 'Ubon Ratchathani', 'Udon Thani',
       'Uthai Thani', 'Yasothon'])
# Out:
# {'Amnat Charoen',
#  'Ang Thong',
#  'Bueng Kan',
#  'Chai Nat',
#  'Kanchanaburi',
#  'Mukdahan',
#  'Nakhon Nayok',
#  'Nakhon Pathom',
#  'Nakhon Phanom',
#  'Nakhon Si Thammarat',
#  'Nong Bua Lam Phu',
#  'Nong Khai',
#  'Phetchaburi',
#  'Phitsanulok',
#  'Sakon Nakhon',
#  'Samut Songkhram',
#  'Satun',
#  'Si Sa Ket',
#  'Sukhothai',
#  'Suphan Buri',
#  'Trat',
#  'Ubon Ratchathani',
#  'Yasothon'}

# %%
interpo_dict = { 'Bueng Kan': [],
                'Buri Ram': ['Nakhon Ratchasima', 'Khon Kaen', 'Maha Sarakham',  'Surin'], 
                'Chachoengsao': [],
                'Chai Nat': [],
                'Chaiyaphum': ['Khon Kaen', 'Nakhon Ratchasima', 'Lopburi', 'Phetchabun'],
                'Chanthaburi': ['Trat', 'Rayong', 'Chonburi', 'Chachoengsao', 'Sa Kaeo'],
                'Chumphon': ['Prachuap Khiri Khan', 'Surat Thani',  'Ranong'],
                 'Kalasin': ["Sakon Nakhon", "Mukdahan",  , "Maha Sarakham", "Khon Kaen", "Udon Thani"],
                 'Kamphaeng Phet': ["Sukhothai", "Phitsanulok", "Phichit", "Nakhon Sawan"],
                 'Lop Buri': ["Phetchabun", "Chaiyaphum", "Nakhon Ratchasima", "Saraburi", "Phranakhon Si Ayutthaya", "Ang Thong", "Sing Buri"],
                 'Lamphun': [],
                  'Mae Hong Son':[],
                'Mukdahan':[],
                'Maha Sarakham': ["Kalasin", "Roi Et", "Surin", "Buriram", "Khon Kaen"],
                 'Phetchabun': ["Loei", "Khon Kaen", "Chaiyaphum", "Lopburi", "Nakhon Sawan", "Phichit", "Phitsanulok"],
                 'Phichit': [ "Phitsanulok", "Nakhon Sawan",  "Kamphaeng Phet"],
                 'Prachuap Khiri Khan': ["Phetchaburi", "Chumphon"],
                'Nakhon Nayok':[],
                 'Nong Khai':['Nong Khai'],
                'Nakhon Phanom':[], 
                'Narathiwat':[],
                'Nonthaburi':[],
                 'Roi Et': ["Mukdahan", "Yasothon", "Sisaket", "Surin", "Maha Sarakham"],
                 'Trang': ["Krabi", "Nakhon Si Thammarat", "Phatthalung",  "Satun"],
                 'Udon Thani': ["Nong Khai",  'Khon Kaen',  'Loei', 'Nong Bua Lamphu'],
                 'Uthai Thani': ['Nakhon Sawan', 'Chai Nat', 'Suphan Buri', 'Kanchanaburi',  'Tak'],
                 'Uttaradit': [ 'Phitsanulok', 'Sukhothai', 'Phrae' , 'Nan']
                'Amnat Charoen': ['Ubon Ratchathani', 'Yasothon',  'Mukdahan'],
                'Ang Thong',    
        'Nong Bua Lam Phu', 
       'Pathum Thani', 'Phayao', 'Phetchaburi', 'Phichit', 'Phrae',
       'Prachuap Khiri Khan', 'Roi Et', 'Samut Songkhram', 'Satun',
       'Si Sa Ket', 'Sukhothai', 'Trat', 'Ubon Ratchathani', 'Udon Thani',
       'Uthai Thani', 'Yasothon'
    
               }

# %%
rolling_mean = mean_poll.rolling(window=5, min_periods=0).mean().round()
rolling_mean
# Out:
#       Amnat Charoen  Ang Thong  Bangkok  Bueng Kan  Buri Ram  Chachoengsao  \
# year
# 2004            NaN        NaN      NaN        NaN       NaN           NaN
# 2005            NaN        NaN     78.0        NaN       NaN           NaN
# 2006            NaN        NaN     79.0        NaN       NaN           NaN
# 2011            NaN        NaN     66.0        NaN       NaN           NaN
# 2012            NaN        NaN     60.0        NaN       NaN           NaN
# 2013            NaN        NaN     57.0        NaN       NaN           NaN
# 2014            NaN        NaN     48.0        NaN       NaN           NaN
# 2015            NaN        NaN     40.0        NaN       NaN           NaN
# 2016            NaN        NaN     38.0        NaN       NaN           NaN
# 2017            NaN        NaN     36.0        NaN       NaN           NaN
# 2018            NaN        NaN     35.0        NaN       NaN          15.0
# 2019           41.0       50.0     34.0       43.0     165.0          21.0
# 2020           32.0       38.0     33.0       34.0      91.0          23.0
#
#       Chai Nat  Chaiyaphum  Chanthaburi  Chiang Mai  ...  Surat Thani   Tak  \
# year                                                 ...
# 2004       NaN         NaN          NaN        34.0  ...          NaN   NaN
# 2005       NaN         NaN          NaN        39.0  ...          NaN   NaN
# 2006       NaN         NaN          NaN        44.0  ...          NaN   NaN
# 2011       NaN         NaN          NaN        42.0  ...          NaN   NaN
# 2012       NaN         NaN          NaN        42.0  ...          NaN   NaN
# 2013       NaN         NaN          NaN        44.0  ...          NaN   NaN
# 2014       NaN         NaN          NaN        45.0  ...          NaN   NaN
# 2015       NaN        47.0         30.0        43.0  ...         26.0   NaN
# 2016       NaN        40.0         27.0        43.0  ...         23.0  31.0
# 2017       NaN        39.0         27.0        41.0  ...         22.0  36.0
# 2018       NaN        38.0         26.0        41.0  ...         21.0  37.0
# 2019      46.0        37.0         26.0        41.0  ...         20.0  39.0
# 2020      44.0        34.0         24.0        37.0  ...         18.0  37.0
#
#       Trang  Trat  Ubon Ratchathani  Udon Thani  Uthai Thani  Uttaradit  Yala  \
# year
# 2004    NaN   NaN               NaN         NaN          NaN        NaN   NaN
# 2005    NaN   NaN               NaN         NaN          NaN        NaN   NaN
# 2006    NaN   NaN               NaN         NaN          NaN        NaN   NaN
# 2011    NaN   NaN               NaN         NaN          NaN        NaN   NaN
# 2012    NaN   NaN               NaN         NaN          NaN        NaN   NaN
# 2013    NaN   NaN               NaN         NaN          NaN        NaN   NaN
# 2014    NaN   NaN               NaN         NaN          NaN        NaN   NaN
# 2015   26.0   NaN               NaN         NaN          NaN       59.0  28.0
# 2016   22.0   NaN               NaN         NaN          NaN       45.0  25.0
# 2017   21.0   NaN               NaN         NaN          NaN       41.0  23.0
# 2018   19.0   NaN               NaN         NaN          NaN       40.0  22.0
# 2019   18.0   NaN              59.0         NaN         53.0       40.0  20.0
# 2020   14.0  30.0              40.0         NaN         40.0       33.0  17.0
#
#       Yasothon
# year
# 2004       NaN
# 2005       NaN
# 2006       NaN
# 2011       NaN
# 2012       NaN
# 2013       NaN
# 2014       NaN
# 2015       NaN
# 2016       NaN
# 2017       NaN
# 2018       NaN
# 2019      41.0
# 2020      33.0
#
# [13 rows x 70 columns]

# %%
rolling_mean['Nonthaburi']
# Out:
# year
# 2004     NaN
# 2005     NaN
# 2006     NaN
# 2011     NaN
# 2012     NaN
# 2013     NaN
# 2014     NaN
# 2015     NaN
# 2016     NaN
# 2017     NaN
# 2018    34.0
# 2019    32.0
# 2020    31.0
# Name: Nonthaburi, dtype: float64

# %%
rolling_mean.count()[rolling_mean.count() < 5].index
# Out:
# Index(['Amnat Charoen', 'Ang Thong', 'Bueng Kan', 'Buri Ram', 'Chachoengsao',
#        'Chai Nat', 'Lamphun', 'Mae Hong Son', 'Mukdahan', 'Nakhon Nayok',
#        'Nakhon Phanom', 'Narathiwat', 'Nong Bua Lam Phu', 'Nonthaburi',
#        'Pathum Thani', 'Phayao', 'Phetchaburi', 'Phichit', 'Phrae',
#        'Prachuap Khiri Khan', 'Roi Et', 'Samut Songkhram', 'Satun',
#        'Si Sa Ket', 'Sukhothai', 'Trat', 'Ubon Ratchathani', 'Udon Thani',
#        'Uthai Thani', 'Yasothon'],
#       dtype='object')

# %%
poll_filename = mdataset.map_folder + 'data.csv'

# %%
temp = mdataset.stations_info[mdataset.stations_info['province'] == 'Nonthaburi']
if len(temp)> 0:
    df = []
    for chunk in pd.read_csv(poll_filename, chunksize=100000):
        # keep only data with stations id 
        df.append(chunk[chunk['stationid'].str.contains('berk')][['datetime', 'PM2.5', 'stationid']])
    df = pd.concat(df)   
    df['datetime'] = pd.to_datetime(df['datetime'])
    df = df.sort_values('datetime')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-d98fa4772362> in <module>
#       4     for chunk in pd.read_csv(poll_filename, chunksize=100000):
#       5         # keep only data with stations id
# ----> 6         df.append(chunk[chunk['stationid'].str.contains('berk')][['datetime', 'PM2.5', 'stationid']])
#       7     df = pd.concat(df)
#       8     df['datetime'] = pd.to_datetime(df['datetime'])
#
# c:\users\benny\pyenv\geo\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2890
#    2891         # Do we have a (boolean) 1d indexer?
# -> 2892         if com.is_bool_indexer(key):
#    2893             return self._getitem_bool_array(key)
#    2894
#
# c:\users\benny\pyenv\geo\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
temp
# Out:
#            id                         nameTH  \
# 28        13t                   กรมควบคุมโรค
# 29        22t  มหาวิทยาลัยสุโขทัยธรรมาธิราช
# 168      4077                            NaN
# 173      4067                            NaN
# 180      4061                            NaN
# 182      4062                            NaN
# 184      4066                            NaN
# 192      4063                            NaN
# 193      4065                            NaN
# 197      4068                            NaN
# 198      4076                            NaN
# 200      4074                            NaN
# 201      4078                            NaN
# 203      4070                            NaN
# 205      4069                            NaN
# 206      4075                            NaN
# 207      4080                            NaN
# 209      4073                            NaN
# 212      4071                            NaN
# 214      4072                            NaN
# 215      4079                            NaN
# 217      4064                            NaN
# 322      5241                            NaN
# 325      5240                            NaN
# 327      5242                            NaN
# 331      5243                            NaN
# 417      5239                            NaN
# 461      6000                            NaN
# 553   berk123                            NaN
# 577  berk1217                            NaN
# 583  berk1335                            NaN
#
#                                      nameEN                        areaTH  \
# 28            Department of Disease Control   ต.ตลาดขวัญ อ.เมือง, นนทบุรี
# 29   Sukhothai Thammathirat Open University  ต.บางพูด อ.ปากเกร็ด, นนทบุรี
# 168                                     NaN                           NaN
# 173                                     NaN                           NaN
# 180                                     NaN                           NaN
# 182                                     NaN                           NaN
# 184                                     NaN                           NaN
# 192                                     NaN                           NaN
# 193                                     NaN                           NaN
# 197                                     NaN                           NaN
# 198                                     NaN                           NaN
# 200                                     NaN                           NaN
# 201                                     NaN                           NaN
# 203                                     NaN                           NaN
# 205                                     NaN                           NaN
# 206                                     NaN                           NaN
# 207                                     NaN                           NaN
# 209                                     NaN                           NaN
# 212                                     NaN                           NaN
# 214                                     NaN                           NaN
# 215                                     NaN                           NaN
# 217                                     NaN                           NaN
# 322                                     NaN                           NaN
# 325                                     NaN                           NaN
# 327                                     NaN                           NaN
# 331                                     NaN                           NaN
# 417                                     NaN                           NaN
# 461                                     NaN                           NaN
# 553                                     NaN                           NaN
# 577                                     NaN                           NaN
# 583                                     NaN                           NaN
#
#                                 areaEN stationType   Latitude   Longitude  \
# 28    Talat Khwan , Mueang, Nonthaburi      GROUND  13.852778  100.529444
# 29     Bang Phut, Pak Kret, Nonthaburi      GROUND  13.907861  100.535641
# 168                                NaN         NaN  13.911404  100.497929
# 173                                NaN         NaN  13.897897  100.546433
# 180                                NaN         NaN  13.890862  100.510166
# 182                                NaN         NaN  13.904530  100.527630
# 184                                NaN         NaN  13.908208  100.502886
# 192                                NaN         NaN  13.904651  100.492257
# 193                                NaN         NaN  13.938596  100.517700
# 197                                NaN         NaN  13.931635  100.507440
# 198                                NaN         NaN  13.931456  100.550647
# 200                                NaN         NaN  13.941530  100.542490
# 201                                NaN         NaN  13.899630  100.541560
# 203                                NaN         NaN  13.937500  100.546800
# 205                                NaN         NaN  13.906450  100.514730
# 206                                NaN         NaN  13.909020  100.557490
# 207                                NaN         NaN  13.915147  100.524006
# 209                                NaN         NaN  13.914112  100.495417
# 212                                NaN         NaN  13.902550  100.533410
# 214                                NaN         NaN  13.890772  100.513852
# 215                                NaN         NaN  13.924443  100.523624
# 217                                NaN         NaN  13.901940  100.505710
# 322                                NaN         NaN  13.856857  100.540961
# 325                                NaN         NaN  13.870878  100.532687
# 327                                NaN         NaN  13.842249  100.492429
# 331                                NaN         NaN  13.861455  100.499456
# 417                                NaN         NaN  13.861863  100.513605
# 461                                NaN         NaN  13.850034  100.527053
# 553                                NaN         NaN  13.805000  100.472800
# 577                                NaN         NaN  13.860700  100.514800
# 583                                NaN         NaN  13.913000  100.498800
#
#     forecast                                         LastUpdate  ...  \
# 28        []  {'date': '2021-02-05', 'time': '16:00', 'PM25'...  ...
# 29        []  {'date': '2021-02-05', 'time': '16:00', 'PM25'...  ...
# 168      NaN                                                NaN  ...
# 173      NaN                                                NaN  ...
# 180      NaN                                                NaN  ...
# 182      NaN                                                NaN  ...
# 184      NaN                                                NaN  ...
# 192      NaN                                                NaN  ...
# 193      NaN                                                NaN  ...
# 197      NaN                                                NaN  ...
# 198      NaN                                                NaN  ...
# 200      NaN                                                NaN  ...
# 201      NaN                                                NaN  ...
# 203      NaN                                                NaN  ...
# 205      NaN                                                NaN  ...
# 206      NaN                                                NaN  ...
# 207      NaN                                                NaN  ...
# 209      NaN                                                NaN  ...
# 212      NaN                                                NaN  ...
# 214      NaN                                                NaN  ...
# 215      NaN                                                NaN  ...
# 217      NaN                                                NaN  ...
# 322      NaN                                                NaN  ...
# 325      NaN                                                NaN  ...
# 327      NaN                                                NaN  ...
# 331      NaN                                                NaN  ...
# 417      NaN                                                NaN  ...
# 461      NaN                                                NaN  ...
# 553      NaN                                                NaN  ...
# 577      NaN                                                NaN  ...
# 583      NaN                                                NaN  ...
#
#      dustboy_uri                                    dustboy_name_th  \
# 28           NaN                                                NaN
# 29           NaN                                                NaN
# 168  dbp20190077                  หน้าโรงเรียนปากเกร็ด ทน. ปากเกร็ด
# 173  dbp20190067                   ร้านเย็นตาโฟโลกันต์ ทน. ปากเกร็ด
# 180  dbp20190061                     ตลาดสดกรมชลประทาน ทน. ปากเกร็ด
# 182  dbp20190062                 หน้าเซ็นทรัลแจ้งวัฒนะ ทน. ปากเกร็ด
# 184  dbp20190066          ป้ายรถเมล์หน้าเมเจอร์ฮอลิวูด ทน. ปากเกร็ด
# 192  dbp20190063              หน้าโรงเรียนวัดกลางเกร็ด ทน. ปากเกร็ด
# 193  dbp20190065            ซอยสุขาประชาสวรรค์ 2 ตัด 3 ทน. ปากเกร็ด
# 197  dbp20190068                  ปากซอยโรงเรียนวัดกู้ ทน. ปากเกร็ด
# 198  dbp20190076               สวนสมเด็จพระศรีนครินทร์ ทน. ปากเกร็ด
# 200  dbp20190074            แยกสวนสมเด็จพระศรีนครินทร์ ทน. ปากเกร็ด
# 201  dbp20190078                 หน้าโรงเรียนคลองเกลือ ทน. ปากเกร็ด
# 203  dbp20190070  หน้าโรงเรียนนวมินทราชินูทิศ หอวัง นนทบุรี ทน. ...
# 205  dbp20190069                   หน้าบิ๊กชีแจ้งวัฒนะ ทน. ปากเกร็ด
# 206  dbp20190075                 ถนนแจ้งวัฒนะคลองประปา ทน. ปากเกร็ด
# 207  dbp20190080       สี่แยกสหกรณ์ 3 (ถนนเลี่ยงเมือง) ทน. ปากเกร็ด
# 209  dbp20190073                    หน้าโรงเรียนวัดบ่อ ทน. ปากเกร็ด
# 212  dbp20190071       หน้าสถาบันการจัดการปัญญาภิวัฒน์ ทน. ปากเกร็ด
# 214  dbp20190072             สามแยกติวานนท์-ปากเกร็ด 2 ทน. ปากเกร็ด
# 215  dbp20190079  ซอยสุขาประชาสวรรค์3 ซอย26 (รร. อัมพรไพศาล) ทน....
# 217  dbp20190064       ซอยสถานสงเคราะห์คนพิการปากเกร็ด ทน. ปากเกร็ด
# 322        N-091         ร้านขนมปัง Victory Bakery เทศบาลนครนนทบุรี
# 325        N-090              สำนักงานแขวงท่าทราย เทศบาลนครนนทบุรี
# 327        N-092        ศูนย์บริการสาธารณสุขที่ 2 เทศบาลนครนนทบุรี
# 331        N-093  ศูนย์บริการสาธารณสุขที่ 4 (วัดสมรโกฏิ) เทศบาลน...
# 417        N-089                  สำนักงานเทศบาลนครนนทบุรี อาคาร 2
# 461         moph                                 กระทรวงสาธารณสุข
# 553          NaN                                                NaN
# 577          NaN                                                NaN
# 583          NaN                                                NaN
#
#                                        dustboy_name_en dustboy_version  \
# 28                                                 NaN             NaN
# 29                                                 NaN             NaN
# 168                  Pakkred Secondary School, Pakkret             NaN
# 173                         Logun Noodle Shop, Pakkret             NaN
# 180                 Chonlapratan Fresh Market, Pakkret             NaN
# 182                     Central Chaengwattana, Pakkret             NaN
# 184                           Major Hollywood, Pakkret             NaN
# 192                       Watklangkred School, Pakkret             NaN
# 193          Soi Sukaprachasawan 2 and 3, Pakkret City             NaN
# 197                                    Wat Ku, Pakkret             NaN
# 198         Somdet Phra Srinagarindra Park 02, Pakkret             NaN
# 200            Somdet Phra Srinagarindra Park, Pakkret             NaN
# 201                          Klongklau School, Pakkret             NaN
# 203  Nawamintharachinuthit Horwang Nonthaburi Schoo...             NaN
# 205                    Big C, Chaeng Watthana, Pakkret             NaN
# 206  Chaeng Watthana - Khlong Prapa Intersection, P...             NaN
# 207      Sahakorn Intersection 3 (Local road), Pakkret             NaN
# 209            Wat Boa (Nanthawithaya) School, Pakkret             NaN
# 212        Panyapiwat Institute of Management, Pakkret             NaN
# 214                         Tiwanont-Pakkret2, Pakkret             NaN
# 215  Soi Sukaprachasawan3 Soi 26 (Ampornpaisan Scho...             NaN
# 217        FOUNDATION FOR THE DISABLED PERSON, Pakkret             NaN
# 322            Victory Bakery, Nonthaburi Municipality            mini
# 325                  Tha Sai Municipal District Office            mini
# 327  Public Health Service Center 2, Nonthabuti Mun...            mini
# 331  Public Health Service Center 4 (Samonkot Templ...            mini
# 417              Nakorn Nonthaburi Municipality Office            mini
# 461                          Ministry of Public Health            mini
# 553                                                NaN             NaN
# 577                                                NaN             NaN
# 583                                                NaN             NaN
#
#           City (ASCII)      Region Region (ASCII) Population     Time Zone  \
# 28                 NaN         NaN            NaN        NaN           NaN
# 29                 NaN         NaN            NaN        NaN           NaN
# 168                NaN         NaN            NaN        NaN           NaN
# 173                NaN         NaN            NaN        NaN           NaN
# 180                NaN         NaN            NaN        NaN           NaN
# 182                NaN         NaN            NaN        NaN           NaN
# 184                NaN         NaN            NaN        NaN           NaN
# 192                NaN         NaN            NaN        NaN           NaN
# 193                NaN         NaN            NaN        NaN           NaN
# 197                NaN         NaN            NaN        NaN           NaN
# 198                NaN         NaN            NaN        NaN           NaN
# 200                NaN         NaN            NaN        NaN           NaN
# 201                NaN         NaN            NaN        NaN           NaN
# 203                NaN         NaN            NaN        NaN           NaN
# 205                NaN         NaN            NaN        NaN           NaN
# 206                NaN         NaN            NaN        NaN           NaN
# 207                NaN         NaN            NaN        NaN           NaN
# 209                NaN         NaN            NaN        NaN           NaN
# 212                NaN         NaN            NaN        NaN           NaN
# 214                NaN         NaN            NaN        NaN           NaN
# 215                NaN         NaN            NaN        NaN           NaN
# 217                NaN         NaN            NaN        NaN           NaN
# 322                NaN         NaN            NaN        NaN           NaN
# 325                NaN         NaN            NaN        NaN           NaN
# 327                NaN         NaN            NaN        NaN           NaN
# 331                NaN         NaN            NaN        NaN           NaN
# 417                NaN         NaN            NaN        NaN           NaN
# 461                NaN         NaN            NaN        NaN           NaN
# 553         Bang Kruai  Nonthaburi     Nonthaburi    78305.0  Asia/Bangkok
# 577  Mueang Nonthaburi  Nonthaburi     Nonthaburi   291555.0  Asia/Bangkok
# 583           Pak Kret  Nonthaburi     Nonthaburi   182926.0  Asia/Bangkok
#
#        province
# 28   Nonthaburi
# 29   Nonthaburi
# 168  Nonthaburi
# 173  Nonthaburi
# 180  Nonthaburi
# 182  Nonthaburi
# 184  Nonthaburi
# 192  Nonthaburi
# 193  Nonthaburi
# 197  Nonthaburi
# 198  Nonthaburi
# 200  Nonthaburi
# 201  Nonthaburi
# 203  Nonthaburi
# 205  Nonthaburi
# 206  Nonthaburi
# 207  Nonthaburi
# 209  Nonthaburi
# 212  Nonthaburi
# 214  Nonthaburi
# 215  Nonthaburi
# 217  Nonthaburi
# 322  Nonthaburi
# 325  Nonthaburi
# 327  Nonthaburi
# 331  Nonthaburi
# 417  Nonthaburi
# 461  Nonthaburi
# 553  Nonthaburi
# 577  Nonthaburi
# 583  Nonthaburi
#
# [31 rows x 25 columns]
